# %%
#Reading input feature values using numpy
import numpy as np
from igraph import *
global num_of_feat
num_of_feat=347

# %%
def load_dataset(fileName,g):
    fileNums=[0]
    for i,eachNum in enumerate(fileNums):
        print(eachNum)
        print('fileName=',fileName)
        f=open(fileName)
        line=f.readline()
        while(line!=''):
            c=(line.split())
            g=addVertex(g,c[0])
            g=addVertex(g,c[1])
            print('Adding ',c[0],'-->',c[1])
            g.add_edge(c[0],c[1]) 
            line=f.readline()
    g.simplify()    
    return

def load_neg_dataset(fileName,g):
    fileNums=[0]
    for i,eachNum in enumerate(fileNums):
        print(eachNum)
        print('fileName=',fileName)
        f=open(fileName)
        nodeID=eachNum
        line=f.readline()
        while(line!=''):
            c=(line.split())
            g=addVertex(g,c[0])
            g=addVertex(g,c[1])
            print('Adding ',c[0],'-->',c[1])
            g.add_edge(c[0],c[1]) 
            line=f.readline()
    g.simplify()    
    return

def load_and_shape_input(file_name):
    a=np.loadtxt(fname=file_name)
    slice_D =[a[i][1:] for i in range(0,num_of_feat)]
    c=np.asarray(slice_D)
    return c

def load_shape_input(file_name_array):
    features=dict()
    b=[file_name_array]
    for eachname in b:
        file_name="C://Users//Admin//Downloads//facebook//facebook//"+str(eachname)+".feat"
        f=open(file_name)
        a=np.loadtxt(f)
        for eachFeat in a:
            features[eachFeat[0]]=np.asarray(eachFeat[1:])
    return features

def addVertex(g,name_str):
    try:
        if(name_str not in g.vs['name']):
            print('Inserted node ',name_str)
            g.add_vertex(name=name_str)
        else:
            print ('Node ',name_str,' already present')
            print(g.vs.find(name_str).index)   
    except KeyError:
        g.add_vertex(name=name_str)
    return g
   


def write_tuple_to_file(f,t):
    string=str(t[0])+' '+str(t[1])+'\n'
    f.write(string)

def retrieve_edge_name_tuple(g,t):
    a=(g.vs[t[0]]['name'],g.vs[t[1]]['name'])
    return a

# %%
li=[0]
node_feat=load_shape_input(li[0])

# %%
g=Graph()
load_dataset('C://Users//Admin//Downloads//facebook//Self_Datasets//sample_train.edges',g)


not_g=Graph()
load_dataset('C://Users//Admin//Downloads//facebook//Self_Datasets//negative_train.edges',not_g)
# Out:
# 0
# fileName= C://Users//Admin//Downloads//facebook//Self_Datasets//sample_train.edges
# Inserted node  196
# Adding  194 --> 196
# Inserted node  252
# Inserted node  67
# Adding  252 --> 67
# Inserted node  17
# Inserted node  41
# Adding  17 --> 41
# Inserted node  186
# Inserted node  122
# Adding  186 --> 122
# Inserted node  188
# Inserted node  291
# Adding  188 --> 291
# Inserted node  302
# Inserted node  101
# Adding  302 --> 101
# Inserted node  170
# Inserted node  142
# Adding  170 --> 142
# Inserted node  9
# Inserted node  203
# Adding  9 --> 203
# Inserted node  285
# Node  142  already present
# 13
# Adding  285 --> 142
# Inserted node  21
# Inserted node  197
# Adding  21 --> 197
# Node  67  already present
# 3
# Inserted node  334
# Adding  67 --> 334
# Inserted node  249
# Node  196  already present
# 1
# Adding  249 --> 196
# Inserted node  271
# Inserted node  261
# Adding  271 --> 261
# Inserted node  136
# Inserted node  125
# Adding  136 --> 125
# Node  67  already present
# 3
# Inserted node  109
# Adding  67 --> 109
# Inserted node  280
# Inserted node  169
# Adding  280 --> 169
# Inserted node  313
# Inserted node  128
# Adding  313 --> 128
# Inserted node  141
# Inserted node  25
# Adding  141 --> 25
# Inserted node  343
# Inserted node  115
# Adding  343 --> 115
# Inserted node  148
# Inserted node  229
# Adding  148 --> 229
# Inserted node  7
# Inserted node  347
# Adding  7 --> 347
# Inserted node  176
# Inserted node  239
# Adding  176 --> 239
# Inserted node  306
# Inserted node  4
# Adding  306 --> 4
# Inserted node  117
# Inserted node  38
# Adding  117 --> 38
# Node  170  already present
# 12
# Inserted node  55
# Adding  170 --> 55
# Node  285  already present
# 16
# Node  67  already present
# 3
# Adding  285 --> 67
# Inserted node  277
# Inserted node  324
# Adding  277 --> 324
# Node  188  already present
# 8
# Inserted node  156
# Adding  188 --> 156
# Node  21  already present
# 17
# Inserted node  281
# Adding  21 --> 281
# Node  194  already present
# 0
# Inserted node  92
# Adding  194 --> 92
# Node  186  already present
# 6
# Node  203  already present
# 15
# Adding  186 --> 203
# Inserted node  211
# Node  128  already present
# 29
# Adding  211 --> 128
# Inserted node  95
# Inserted node  147
# Adding  95 --> 147
# Node  186  already present
# 6
# Inserted node  199
# Adding  186 --> 199
# Inserted node  77
# Inserted node  294
# Adding  77 --> 294
# Node  188  already present
# 8
# Inserted node  208
# Adding  188 --> 208
# Node  343  already present
# 32
# Inserted node  2
# Adding  343 --> 2
# Inserted node  272
# Node  156  already present
# 47
# Adding  272 --> 156
# Inserted node  238
# Node  261  already present
# 22
# Adding  238 --> 261
# Node  252  already present
# 2
# Node  188  already present
# 8
# Adding  252 --> 188
# Node  188  already present
# 8
# Inserted node  30
# Adding  188 --> 30
# Node  280  already present
# 26
# Node  272  already present
# 58
# Adding  280 --> 272
# Inserted node  274
# Inserted node  40
# Adding  274 --> 40
# Inserted node  53
# Node  101  already present
# 11
# Adding  53 --> 101
# Inserted node  91
# Inserted node  201
# Adding  91 --> 201
# Inserted node  8
# Node  91  already present
# 64
# Adding  8 --> 91
# Inserted node  133
# Inserted node  315
# Adding  133 --> 315
# Inserted node  227
# Inserted node  143
# Adding  227 --> 143
# Inserted node  28
# Inserted node  310
# Adding  28 --> 310
# Inserted node  84
# Inserted node  224
# Adding  84 --> 224
# Inserted node  329
# Node  315  already present
# 68
# Adding  329 --> 315
# Inserted node  339
# Inserted node  31
# Adding  339 --> 31
# Node  84  already present
# 73
# Inserted node  265
# Adding  84 --> 265
# Node  9  already present
# 14
# Node  156  already present
# 47
# Adding  9 --> 156
# Inserted node  135
# Inserted node  284
# Adding  135 --> 284
# Inserted node  62
# Inserted node  56
# Adding  62 --> 56
# Inserted node  48
# Node  30  already present
# 60
# Adding  48 --> 30
# Inserted node  111
# Inserted node  93
# Adding  111 --> 93
# Inserted node  23
# Inserted node  237
# Adding  23 --> 237
# Inserted node  236
# Node  62  already present
# 81
# Adding  236 --> 62
# Node  315  already present
# 68
# Node  249  already present
# 20
# Adding  315 --> 249
# Inserted node  98
# Node  265  already present
# 78
# Adding  98 --> 265
# Node  169  already present
# 27
# Inserted node  165
# Adding  169 --> 165
# Node  271  already present
# 21
# Inserted node  72
# Adding  271 --> 72
# Inserted node  116
# Inserted node  226
# Adding  116 --> 226
# Node  285  already present
# 16
# Inserted node  323
# Adding  285 --> 323
# Node  53  already present
# 63
# Inserted node  54
# Adding  53 --> 54
# Inserted node  346
# Inserted node  180
# Adding  346 --> 180
# Inserted node  322
# Inserted node  161
# Adding  322 --> 161
# Node  25  already present
# 31
# Inserted node  336
# Adding  25 --> 336
# Node  322  already present
# 98
# Node  30  already present
# 60
# Adding  322 --> 30
# Node  277  already present
# 45
# Node  55  already present
# 44
# Adding  277 --> 55
# Node  56  already present
# 82
# Inserted node  207
# Adding  56 --> 207
# Inserted node  200
# Inserted node  104
# Adding  200 --> 104
# Node  280  already present
# 26
# Node  141  already present
# 30
# Adding  280 --> 141
# Node  322  already present
# 98
# Inserted node  232
# Adding  322 --> 232
# Node  56  already present
# 82
# Node  109  already present
# 25
# Adding  56 --> 109
# Node  271  already present
# 21
# Node  277  already present
# 45
# Adding  271 --> 277
# Node  133  already present
# 67
# Inserted node  1
# Adding  133 --> 1
# Node  302  already present
# 10
# Inserted node  94
# Adding  302 --> 94
# Node  98  already present
# 89
# Inserted node  223
# Adding  98 --> 223
# Inserted node  65
# Inserted node  13
# Adding  65 --> 13
# Node  200  already present
# 102
# Node  232  already present
# 104
# Adding  200 --> 232
# Node  323  already present
# 94
# Inserted node  75
# Adding  323 --> 75
# Node  56  already present
# 82
# Inserted node  88
# Adding  56 --> 88
# Node  280  already present
# 26
# Node  25  already present
# 31
# Adding  280 --> 25
# Inserted node  3
# Node  72  already present
# 91
# Adding  3 --> 72
# Node  271  already present
# 21
# Node  291  already present
# 9
# Adding  271 --> 291
# Node  122  already present
# 7
# Inserted node  344
# Adding  122 --> 344
# Inserted node  299
# Inserted node  330
# Adding  299 --> 330
# Node  23  already present
# 86
# Node  116  already present
# 92
# Adding  23 --> 116
# Inserted node  204
# Node  196  already present
# 1
# Adding  204 --> 196
# Node  200  already present
# 102
# Node  203  already present
# 15
# Adding  200 --> 203
# Inserted node  82
# Node  238  already present
# 59
# Adding  82 --> 238
# Inserted node  26
# Inserted node  66
# Adding  26 --> 66
# Inserted node  102
# Node  227  already present
# 69
# Adding  102 --> 227
# Node  272  already present
# 58
# Node  277  already present
# 45
# Adding  272 --> 277
# Inserted node  64
# Inserted node  217
# Adding  64 --> 217
# Node  122  already present
# 7
# Node  281  already present
# 48
# Adding  122 --> 281
# Node  272  already present
# 58
# Node  281  already present
# 48
# Adding  272 --> 281
# Inserted node  266
# Node  180  already present
# 97
# Adding  266 --> 180
# Inserted node  260
# Inserted node  160
# Adding  260 --> 160
# Node  9  already present
# 14
# Node  133  already present
# 67
# Adding  9 --> 133
# Inserted node  304
# Inserted node  69
# Adding  304 --> 69
# Node  252  already present
# 2
# Inserted node  118
# Adding  252 --> 118
# Node  92  already present
# 49
# Node  266  already present
# 123
# Adding  92 --> 266
# Inserted node  213
# Node  224  already present
# 74
# Adding  213 --> 224
# Inserted node  119
# Inserted node  171
# Adding  119 --> 171
# Node  56  already present
# 82
# Node  75  already present
# 110
# Adding  56 --> 75
# Inserted node  332
# Node  109  already present
# 25
# Adding  332 --> 109
# Node  217  already present
# 122
# Inserted node  189
# Adding  217 --> 189
# Node  211  already present
# 50
# Inserted node  331
# Adding  211 --> 331
# Node  23  already present
# 86
# Inserted node  230
# Adding  23 --> 230
# Node  304  already present
# 126
# Node  136  already present
# 23
# Adding  304 --> 136
# Node  26  already present
# 118
# Inserted node  325
# Adding  26 --> 325
# Node  197  already present
# 18
# Inserted node  309
# Adding  197 --> 309
# Node  285  already present
# 16
# Inserted node  10
# Adding  285 --> 10
# Node  329  already present
# 75
# Node  324  already present
# 46
# Adding  329 --> 324
# Inserted node  137
# Inserted node  32
# Adding  137 --> 32
# Node  92  already present
# 49
# Node  330  already present
# 115
# Adding  92 --> 330
# Node  48  already present
# 83
# Node  88  already present
# 111
# Adding  48 --> 88
# Node  304  already present
# 126
# Node  325  already present
# 136
# Adding  304 --> 325
# Node  53  already present
# 63
# Inserted node  317
# Adding  53 --> 317
# Node  133  already present
# 67
# Node  232  already present
# 104
# Adding  133 --> 232
# Node  203  already present
# 15
# Node  25  already present
# 31
# Adding  203 --> 25
# Node  239  already present
# 39
# Node  13  already present
# 109
# Adding  239 --> 13
# Node  188  already present
# 8
# Node  119  already present
# 130
# Adding  188 --> 119
# Node  271  already present
# 21
# Node  30  already present
# 60
# Adding  271 --> 30
# Inserted node  36
# Node  309  already present
# 137
# Adding  36 --> 309
# Node  56  already present
# 82
# Inserted node  222
# Adding  56 --> 222
# Node  280  already present
# 26
# Node  315  already present
# 68
# Adding  280 --> 315
# Inserted node  185
# Node  55  already present
# 44
# Adding  185 --> 55
# Node  188  already present
# 8
# Node  334  already present
# 19
# Adding  188 --> 334
# Node  304  already present
# 126
# Inserted node  168
# Adding  304 --> 168
# Inserted node  242
# Inserted node  158
# Adding  242 --> 158
# Node  67  already present
# 3
# Node  161  already present
# 99
# Adding  67 --> 161
# Node  98  already present
# 89
# Node  104  already present
# 103
# Adding  98 --> 104
# Node  186  already present
# 6
# Node  223  already present
# 107
# Adding  186 --> 223
# Node  67  already present
# 3
# Inserted node  113
# Adding  67 --> 113
# Node  84  already present
# 73
# Inserted node  51
# Adding  84 --> 51
# Node  280  already present
# 26
# Node  119  already present
# 130
# Adding  280 --> 119
# Node  119  already present
# 130
# Inserted node  342
# Adding  119 --> 342
# Node  9  already present
# 14
# Node  69  already present
# 127
# Adding  9 --> 69
# Node  277  already present
# 45
# Inserted node  120
# Adding  277 --> 120
# Node  236  already present
# 88
# Node  69  already present
# 127
# Adding  236 --> 69
# Node  342  already present
# 150
# Node  165  already present
# 90
# Adding  342 --> 165
# Node  252  already present
# 2
# Node  119  already present
# 130
# Adding  252 --> 119
# Node  72  already present
# 91
# Node  165  already present
# 90
# Adding  72 --> 165
# Node  169  already present
# 27
# Inserted node  106
# Adding  169 --> 106
# Node  137  already present
# 139
# Node  111  already present
# 84
# Adding  137 --> 111
# Node  3  already present
# 112
# Inserted node  283
# Adding  3 --> 283
# Node  26  already present
# 118
# Node  185  already present
# 144
# Adding  26 --> 185
# Inserted node  123
# Node  104  already present
# 103
# Adding  123 --> 104
# Inserted node  233
# Inserted node  256
# Adding  233 --> 256
# Inserted node  134
# Node  334  already present
# 19
# Adding  134 --> 334
# Node  315  already present
# 68
# Node  7  already present
# 36
# Adding  315 --> 7
# Node  304  already present
# 126
# Node  315  already present
# 68
# Adding  304 --> 315
# Node  309  already present
# 137
# Inserted node  251
# Adding  309 --> 251
# Node  122  already present
# 7
# Node  322  already present
# 98
# Adding  122 --> 322
# Node  239  already present
# 39
# Node  169  already present
# 27
# Adding  239 --> 169
# Node  31  already present
# 77
# Inserted node  338
# Adding  31 --> 338
# Node  31  already present
# 77
# Node  7  already present
# 36
# Adding  31 --> 7
# Node  26  already present
# 118
# Node  21  already present
# 17
# Adding  26 --> 21
# Node  119  already present
# 130
# Inserted node  50
# Adding  119 --> 50
# Inserted node  174
# Inserted node  293
# Adding  174 --> 293
# Inserted node  19
# Inserted node  289
# Adding  19 --> 289
# Inserted node  175
# Inserted node  321
# Adding  175 --> 321
# Inserted node  177
# Node  227  already present
# 69
# Adding  177 --> 227
# Node  236  already present
# 88
# Node  315  already present
# 68
# Adding  236 --> 315
# Node  133  already present
# 67
# Inserted node  96
# Adding  133 --> 96
# Inserted node  121
# Inserted node  206
# Adding  121 --> 206
# Node  26  already present
# 118
# Node  72  already present
# 91
# Adding  26 --> 72
# Node  26  already present
# 118
# Node  334  already present
# 19
# Adding  26 --> 334
# Node  82  already present
# 117
# Inserted node  172
# Adding  82 --> 172
# Inserted node  149
# Inserted node  14
# Adding  149 --> 14
# Inserted node  312
# Inserted node  44
# Adding  312 --> 44
# Node  203  already present
# 15
# Inserted node  29
# Adding  203 --> 29
# Inserted node  214
# Node  111  already present
# 84
# Adding  214 --> 111
# Inserted node  27
# Node  54  already present
# 95
# Adding  27 --> 54
# Node  312  already present
# 174
# Node  214  already present
# 177
# Adding  312 --> 214
# Node  118  already present
# 128
# Node  265  already present
# 78
# Adding  118 --> 265
# Node  271  already present
# 21
# Node  82  already present
# 117
# Adding  271 --> 82
# Node  62  already present
# 81
# Node  239  already present
# 39
# Adding  62 --> 239
# Inserted node  139
# Inserted node  320
# Adding  139 --> 320
# Node  122  already present
# 7
# Inserted node  5
# Adding  122 --> 5
# Node  175  already present
# 165
# Inserted node  46
# Adding  175 --> 46
# Inserted node  20
# Node  115  already present
# 33
# Adding  20 --> 115
# Node  170  already present
# 12
# Node  21  already present
# 17
# Adding  170 --> 21
# Node  226  already present
# 93
# Node  343  already present
# 32
# Adding  226 --> 343
# Node  137  already present
# 139
# Node  115  already present
# 33
# Adding  137 --> 115
# Node  32  already present
# 140
# Inserted node  167
# Adding  32 --> 167
# Node  119  already present
# 130
# Node  27  already present
# 178
# Adding  119 --> 27
# Node  170  already present
# 12
# Inserted node  85
# Adding  170 --> 85
# Node  280  already present
# 26
# Node  98  already present
# 89
# Adding  280 --> 98
# Node  26  already present
# 118
# Node  55  already present
# 44
# Adding  26 --> 55
# Node  176  already present
# 38
# Node  85  already present
# 185
# Adding  176 --> 85
# Node  122  already present
# 7
# Node  323  already present
# 94
# Adding  122 --> 323
# Node  339  already present
# 76
# Node  334  already present
# 19
# Adding  339 --> 334
# Node  252  already present
# 2
# Node  29  already present
# 176
# Adding  252 --> 29
# Node  104  already present
# 103
# Node  55  already present
# 44
# Adding  104 --> 55
# Inserted node  140
# Node  115  already present
# 33
# Adding  140 --> 115
# Node  175  already present
# 165
# Inserted node  263
# Adding  175 --> 263
# Node  213  already present
# 129
# Node  40  already present
# 62
# Adding  213 --> 40
# Node  134  already present
# 157
# Inserted node  248
# Adding  134 --> 248
# Node  277  already present
# 45
# Inserted node  159
# Adding  277 --> 159
# Node  213  already present
# 129
# Inserted node  303
# Adding  213 --> 303
# Node  315  already present
# 68
# Inserted node  80
# Adding  315 --> 80
# Inserted node  144
# Node  14  already present
# 173
# Adding  144 --> 14
# Node  98  already present
# 89
# Node  128  already present
# 29
# Adding  98 --> 128
# Inserted node  245
# Node  91  already present
# 64
# Adding  245 --> 91
# Node  7  already present
# 36
# Inserted node  22
# Adding  7 --> 22
# Node  271  already present
# 21
# Inserted node  276
# Adding  271 --> 276
# Node  98  already present
# 89
# Node  291  already present
# 9
# Adding  98 --> 291
# Node  9  already present
# 14
# Node  141  already present
# 30
# Adding  9 --> 141
# Node  325  already present
# 136
# Node  277  already present
# 45
# Adding  325 --> 277
# Node  25  already present
# 31
# Inserted node  257
# Adding  25 --> 257
# Node  19  already present
# 163
# Inserted node  112
# Adding  19 --> 112
# Node  277  already present
# 45
# Node  22  already present
# 194
# Adding  277 --> 22
# Inserted node  307
# Node  230  already present
# 135
# Adding  307 --> 230
# Node  277  already present
# 45
# Node  13  already present
# 109
# Adding  277 --> 13
# Node  188  already present
# 8
# Node  75  already present
# 110
# Adding  188 --> 75
# Node  285  already present
# 16
# Node  211  already present
# 50
# Adding  285 --> 211
# Node  203  already present
# 15
# Node  40  already present
# 62
# Adding  203 --> 40
# Node  172  already present
# 171
# Inserted node  103
# Adding  172 --> 103
# Node  119  already present
# 130
# Node  125  already present
# 24
# Adding  119 --> 125
# Node  271  already present
# 21
# Node  280  already present
# 26
# Adding  271 --> 280
# Node  238  already present
# 59
# Node  13  already present
# 109
# Adding  238 --> 13
# Node  283  already present
# 153
# Inserted node  228
# Adding  283 --> 228
# Inserted node  231
# Inserted node  178
# Adding  231 --> 178
# Node  194  already present
# 0
# Node  101  already present
# 11
# Adding  194 --> 101
# Node  200  already present
# 102
# Inserted node  39
# Adding  200 --> 39
# Node  56  already present
# 82
# Node  313  already present
# 28
# Adding  56 --> 313
# Node  82  already present
# 117
# Node  84  already present
# 73
# Adding  82 --> 84
# Node  214  already present
# 177
# Node  230  already present
# 135
# Adding  214 --> 230
# Node  172  already present
# 171
# Node  98  already present
# 89
# Adding  172 --> 98
# Node  249  already present
# 20
# Node  180  already present
# 97
# Adding  249 --> 180
# Node  332  already present
# 132
# Node  280  already present
# 26
# Adding  332 --> 280
# Node  313  already present
# 28
# Node  203  already present
# 15
# Adding  313 --> 203
# Node  188  already present
# 8
# Node  165  already present
# 90
# Adding  188 --> 165
# Node  186  already present
# 6
# Inserted node  341
# Adding  186 --> 341
# Node  280  already present
# 26
# Node  277  already present
# 45
# Adding  280 --> 277
# Node  98  already present
# 89
# Node  67  already present
# 3
# Adding  98 --> 67
# Inserted node  275
# Inserted node  78
# Adding  275 --> 78
# Node  239  already present
# 39
# Node  55  already present
# 44
# Adding  239 --> 55
# Inserted node  262
# Inserted node  220
# Adding  262 --> 220
# Node  329  already present
# 75
# Node  30  already present
# 60
# Adding  329 --> 30
# Node  200  already present
# 102
# Node  40  already present
# 62
# Adding  200 --> 40
# Node  312  already present
# 174
# Node  343  already present
# 32
# Adding  312 --> 343
# Node  285  already present
# 16
# Node  304  already present
# 126
# Adding  285 --> 304
# Node  239  already present
# 39
# Node  325  already present
# 136
# Adding  239 --> 325
# Node  323  already present
# 94
# Node  200  already present
# 102
# Adding  323 --> 200
# Node  252  already present
# 2
# Node  261  already present
# 22
# Adding  252 --> 261
# Node  346  already present
# 96
# Inserted node  300
# Adding  346 --> 300
# Node  332  already present
# 132
# Node  224  already present
# 74
# Adding  332 --> 224
# Node  274  already present
# 61
# Node  185  already present
# 144
# Adding  274 --> 185
# Inserted node  258
# Node  75  already present
# 110
# Adding  258 --> 75
# Node  313  already present
# 28
# Node  339  already present
# 76
# Adding  313 --> 339
# Node  186  already present
# 6
# Node  325  already present
# 136
# Adding  186 --> 325
# Node  304  already present
# 126
# Node  257  already present
# 196
# Adding  304 --> 257
# Node  172  already present
# 171
# Node  231  already present
# 201
# Adding  172 --> 231
# Node  236  already present
# 88
# Inserted node  318
# Adding  236 --> 318
# Node  330  already present
# 115
# Node  249  already present
# 20
# Adding  330 --> 249
# Node  277  already present
# 45
# Node  10  already present
# 138
# Adding  277 --> 10
# Node  23  already present
# 86
# Node  227  already present
# 69
# Adding  23 --> 227
# Node  116  already present
# 92
# Node  14  already present
# 173
# Adding  116 --> 14
# Node  200  already present
# 102
# Node  325  already present
# 136
# Adding  200 --> 325
# Node  122  already present
# 7
# Node  325  already present
# 136
# Adding  122 --> 325
# Node  265  already present
# 78
# Node  203  already present
# 15
# Adding  265 --> 203
# Node  186  already present
# 6
# Node  113  already present
# 148
# Adding  186 --> 113
# Node  122  already present
# 7
# Inserted node  235
# Adding  122 --> 235
# Node  332  already present
# 132
# Node  40  already present
# 62
# Adding  332 --> 40
# Node  203  already present
# 15
# Inserted node  268
# Adding  203 --> 268
# Node  26  already present
# 118
# Node  133  already present
# 67
# Adding  26 --> 133
# Node  64  already present
# 121
# Inserted node  100
# Adding  64 --> 100
# Node  38  already present
# 43
# Node  7  already present
# 36
# Adding  38 --> 7
# Node  213  already present
# 129
# Inserted node  340
# Adding  213 --> 340
# Inserted node  259
# Node  201  already present
# 65
# Adding  259 --> 201
# Inserted node  16
# Node  29  already present
# 176
# Adding  16 --> 29
# Node  213  already present
# 129
# Node  239  already present
# 39
# Adding  213 --> 239
# Node  122  already present
# 7
# Node  284  already present
# 80
# Adding  122 --> 284
# Node  186  already present
# 6
# Node  170  already present
# 12
# Adding  186 --> 170
# Node  144  already present
# 192
# Node  17  already present
# 4
# Adding  144 --> 17
# Inserted node  33
# Inserted node  42
# Adding  33 --> 42
# Node  252  already present
# 2
# Node  342  already present
# 150
# Adding  252 --> 342
# Inserted node  308
# Node  334  already present
# 19
# Adding  308 --> 334
# Node  188  already present
# 8
# Node  113  already present
# 148
# Adding  188 --> 113
# Node  322  already present
# 98
# Node  303  already present
# 190
# Adding  322 --> 303
# Node  53  already present
# 63
# Node  302  already present
# 10
# Adding  53 --> 302
# Inserted node  89
# Inserted node  319
# Adding  89 --> 319
# Node  21  already present
# 17
# Node  235  already present
# 212
# Adding  21 --> 235
# Node  21  already present
# 17
# Node  334  already present
# 19
# Adding  21 --> 334
# Inserted node  127
# Inserted node  108
# Adding  127 --> 108
# Node  271  already present
# 21
# Node  224  already present
# 74
# Adding  271 --> 224
# Node  3  already present
# 112
# Node  188  already present
# 8
# Adding  3 --> 188
# Node  84  already present
# 73
# Inserted node  83
# Adding  84 --> 83
# Node  25  already present
# 31
# Node  51  already present
# 149
# Adding  25 --> 51
# Node  315  already present
# 68
# Inserted node  132
# Adding  315 --> 132
# Node  36  already present
# 142
# Node  197  already present
# 18
# Adding  36 --> 197
# Node  98  already present
# 89
# Inserted node  59
# Adding  98 --> 59
# Node  231  already present
# 201
# Node  291  already present
# 9
# Adding  231 --> 291
# Node  199  already present
# 53
# Node  223  already present
# 107
# Adding  199 --> 223
# Node  59  already present
# 227
# Inserted node  250
# Adding  59 --> 250
# Node  224  already present
# 74
# Node  25  already present
# 31
# Adding  224 --> 25
# Node  310  already present
# 72
# Node  41  already present
# 5
# Adding  310 --> 41
# Node  194  already present
# 0
# Node  1  already present
# 105
# Adding  194 --> 1
# Node  271  already present
# 21
# Node  85  already present
# 185
# Adding  271 --> 85
# Node  304  already present
# 126
# Node  21  already present
# 17
# Adding  304 --> 21
# Node  200  already present
# 102
# Node  248  already present
# 188
# Adding  200 --> 248
# Node  199  already present
# 53
# Node  56  already present
# 82
# Adding  199 --> 56
# Node  300  already present
# 209
# Node  94  already present
# 106
# Adding  300 --> 94
# Node  239  already present
# 39
# Node  67  already present
# 3
# Adding  239 --> 67
# Node  265  already present
# 78
# Inserted node  311
# Adding  265 --> 311
# Node  127  already present
# 223
# Node  197  already present
# 18
# Adding  127 --> 197
# Node  111  already present
# 84
# Inserted node  279
# Adding  111 --> 279
# Node  175  already present
# 165
# Inserted node  68
# Adding  175 --> 68
# Node  211  already present
# 50
# Node  261  already present
# 22
# Adding  211 --> 261
# Node  339  already present
# 76
# Node  136  already present
# 23
# Adding  339 --> 136
# Node  339  already present
# 76
# Node  148  already present
# 34
# Adding  339 --> 148
# Node  200  already present
# 102
# Node  113  already present
# 148
# Adding  200 --> 113
# Node  347  already present
# 37
# Inserted node  129
# Adding  347 --> 129
# Node  108  already present
# 224
# Node  320  already present
# 180
# Adding  108 --> 320
# Node  7  already present
# 36
# Node  129  already present
# 232
# Adding  7 --> 129
# Node  122  already present
# 7
# Node  55  already present
# 44
# Adding  122 --> 55
# Node  199  already present
# 53
# Node  203  already present
# 15
# Adding  199 --> 203
# Node  236  already present
# 88
# Node  25  already present
# 31
# Adding  236 --> 25
# Node  322  already present
# 98
# Inserted node  45
# Adding  322 --> 45
# Node  136  already present
# 23
# Node  324  already present
# 46
# Adding  136 --> 324
# Node  172  already present
# 171
# Node  128  already present
# 29
# Adding  172 --> 128
# Node  346  already present
# 96
# Inserted node  184
# Adding  346 --> 184
# Node  56  already present
# 82
# Node  323  already present
# 94
# Adding  56 --> 323
# Node  23  already present
# 86
# Inserted node  124
# Adding  23 --> 124
# Node  325  already present
# 136
# Node  59  already present
# 227
# Adding  325 --> 59
# Node  170  already present
# 12
# Node  188  already present
# 8
# Adding  170 --> 188
# Node  223  already present
# 107
# Node  342  already present
# 150
# Adding  223 --> 342
# Node  26  already present
# 118
# Node  170  already present
# 12
# Adding  26 --> 170
# Node  285  already present
# 16
# Node  117  already present
# 42
# Adding  285 --> 117
# Node  118  already present
# 128
# Node  203  already present
# 15
# Adding  118 --> 203
# Inserted node  254
# Node  330  already present
# 115
# Adding  254 --> 330
# Node  89  already present
# 221
# Node  147  already present
# 52
# Adding  89 --> 147
# Node  8  already present
# 66
# Inserted node  110
# Adding  8 --> 110
# Node  172  already present
# 171
# Node  232  already present
# 104
# Adding  172 --> 232
# Node  56  already present
# 82
# Node  25  already present
# 31
# Adding  56 --> 25
# Node  98  already present
# 89
# Node  148  already present
# 34
# Adding  98 --> 148
# Node  291  already present
# 9
# Node  232  already present
# 104
# Adding  291 --> 232
# Node  119  already present
# 130
# Node  229  already present
# 35
# Adding  119 --> 229
# Node  325  already present
# 136
# Node  40  already present
# 62
# Adding  325 --> 40
# Inserted node  49
# Inserted node  241
# Adding  49 --> 241
# Inserted node  218
# Inserted node  195
# Adding  218 --> 195
# Node  236  already present
# 88
# Node  213  already present
# 129
# Adding  236 --> 213
# Node  26  already present
# 118
# Node  224  already present
# 74
# Adding  26 --> 224
# Node  285  already present
# 16
# Node  232  already present
# 104
# Adding  285 --> 232
# Inserted node  24
# Node  94  already present
# 106
# Adding  24 --> 94
# Node  21  already present
# 17
# Inserted node  297
# Adding  21 --> 297
# Node  186  already present
# 6
# Node  21  already present
# 17
# Adding  186 --> 21
# Node  82  already present
# 117
# Node  119  already present
# 130
# Adding  82 --> 119
# Node  271  already present
# 21
# Node  141  already present
# 30
# Adding  271 --> 141
# Node  25  already present
# 31
# Inserted node  221
# Adding  25 --> 221
# Node  161  already present
# 99
# Inserted node  314
# Adding  161 --> 314
# Node  103  already present
# 199
# Node  7  already present
# 36
# Adding  103 --> 7
# Node  285  already present
# 16
# Node  185  already present
# 144
# Adding  285 --> 185
# Node  252  already present
# 2
# Node  250  already present
# 228
# Adding  252 --> 250
# Node  277  already present
# 45
# Node  21  already present
# 17
# Adding  277 --> 21
# Node  194  already present
# 0
# Node  302  already present
# 10
# Adding  194 --> 302
# Node  303  already present
# 190
# Node  45  already present
# 233
# Adding  303 --> 45
# Node  271  already present
# 21
# Node  176  already present
# 38
# Adding  271 --> 176
# Node  188  already present
# 8
# Node  185  already present
# 144
# Adding  188 --> 185
# Node  174  already present
# 161
# Node  112  already present
# 197
# Adding  174 --> 112
# Node  236  already present
# 88
# Node  200  already present
# 102
# Adding  236 --> 200
# Node  53  already present
# 63
# Node  88  already present
# 111
# Adding  53 --> 88
# Inserted node  130
# Node  257  already present
# 196
# Adding  130 --> 257
# Node  312  already present
# 174
# Node  17  already present
# 4
# Adding  312 --> 17
# Node  325  already present
# 136
# Node  109  already present
# 25
# Adding  325 --> 109
# Node  133  already present
# 67
# Node  322  already present
# 98
# Adding  133 --> 322
# Node  36  already present
# 142
# Node  108  already present
# 224
# Adding  36 --> 108
# Node  211  already present
# 50
# Node  59  already present
# 227
# Adding  211 --> 59
# Node  322  already present
# 98
# Node  170  already present
# 12
# Adding  322 --> 170
# Inserted node  57
# Node  242  already present
# 146
# Adding  57 --> 242
# Node  339  already present
# 76
# Node  129  already present
# 232
# Adding  339 --> 129
# Node  26  already present
# 118
# Node  3  already present
# 112
# Adding  26 --> 3
# Node  80  already present
# 191
# Inserted node  187
# Adding  80 --> 187
# Node  91  already present
# 64
# Inserted node  193
# Adding  91 --> 193
# Node  92  already present
# 49
# Node  101  already present
# 11
# Adding  92 --> 101
# Node  200  already present
# 102
# Node  21  already present
# 17
# Adding  200 --> 21
# Inserted node  326
# Node  137  already present
# 139
# Adding  326 --> 137
# Node  115  already present
# 33
# Node  262  already present
# 207
# Adding  115 --> 262
# Node  285  already present
# 16
# Inserted node  60
# Adding  285 --> 60
# Node  271  already present
# 21
# Node  161  already present
# 99
# Adding  271 --> 161
# Node  141  already present
# 30
# Node  38  already present
# 43
# Adding  141 --> 38
# Node  80  already present
# 191
# Node  249  already present
# 20
# Adding  80 --> 249
# Node  118  already present
# 128
# Node  342  already present
# 150
# Adding  118 --> 342
# Node  236  already present
# 88
# Node  84  already present
# 73
# Adding  236 --> 84
# Node  32  already present
# 140
# Inserted node  337
# Adding  32 --> 337
# Node  24  already present
# 242
# Node  180  already present
# 97
# Adding  24 --> 180
# Node  312  already present
# 174
# Node  149  already present
# 172
# Adding  312 --> 149
# Node  186  already present
# 6
# Node  323  already present
# 94
# Adding  186 --> 323
# Node  40  already present
# 62
# Node  77  already present
# 54
# Adding  40 --> 77
# Inserted node  278
# Inserted node  225
# Adding  278 --> 225
# Node  53  already present
# 63
# Node  48  already present
# 83
# Adding  53 --> 48
# Node  9  already present
# 14
# Node  200  already present
# 102
# Adding  9 --> 200
# Node  200  already present
# 102
# Node  165  already present
# 90
# Adding  200 --> 165
# Node  21  already present
# 17
# Node  121  already present
# 169
# Adding  21 --> 121
# Node  309  already present
# 137
# Node  281  already present
# 48
# Adding  309 --> 281
# Node  56  already present
# 82
# Node  60  already present
# 251
# Adding  56 --> 60
# Node  170  already present
# 12
# Node  98  already present
# 89
# Adding  170 --> 98
# Node  109  already present
# 25
# Node  148  already present
# 34
# Adding  109 --> 148
# Node  82  already present
# 117
# Node  222  already present
# 143
# Adding  82 --> 222
# Node  285  already present
# 16
# Node  272  already present
# 58
# Adding  285 --> 272
# Node  242  already present
# 146
# Node  94  already present
# 106
# Adding  242 --> 94
# Node  211  already present
# 50
# Node  238  already present
# 59
# Adding  211 --> 238
# Node  106  already present
# 152
# Node  29  already present
# 176
# Adding  106 --> 29
# Node  275  already present
# 205
# Inserted node  273
# Adding  275 --> 273
# Node  82  already present
# 117
# Node  203  already present
# 15
# Adding  82 --> 203
# Node  169  already present
# 27
# Node  125  already present
# 24
# Adding  169 --> 125
# Node  285  already present
# 16
# Node  313  already present
# 28
# Adding  285 --> 313
# Node  5  already present
# 181
# Inserted node  316
# Adding  5 --> 316
# Node  242  already present
# 146
# Node  80  already present
# 191
# Adding  242 --> 80
# Inserted node  99
# Inserted node  296
# Adding  99 --> 296
# Node  17  already present
# 4
# Node  310  already present
# 72
# Adding  17 --> 310
# Node  236  already present
# 88
# Node  224  already present
# 74
# Adding  236 --> 224
# Node  239  already present
# 39
# Inserted node  212
# Adding  239 --> 212
# Inserted node  105
# Node  39  already present
# 203
# Adding  105 --> 39
# Node  122  already present
# 7
# Node  272  already present
# 58
# Adding  122 --> 272
# Node  223  already present
# 107
# Node  13  already present
# 109
# Adding  223 --> 13
# Node  122  already present
# 7
# Node  274  already present
# 61
# Adding  122 --> 274
# Inserted node  146
# Node  148  already present
# 34
# Adding  146 --> 148
# Node  239  already present
# 39
# Node  25  already present
# 31
# Adding  239 --> 25
# Node  304  already present
# 126
# Node  341  already present
# 204
# Adding  304 --> 341
# Node  36  already present
# 142
# Node  320  already present
# 180
# Adding  36 --> 320
# Node  272  already present
# 58
# Node  25  already present
# 31
# Adding  272 --> 25
# Node  329  already present
# 75
# Node  322  already present
# 98
# Adding  329 --> 322
# Node  315  already present
# 68
# Node  142  already present
# 13
# Adding  315 --> 142
# Node  203  already present
# 15
# Node  104  already present
# 103
# Adding  203 --> 104
# Node  214  already present
# 177
# Inserted node  333
# Adding  214 --> 333
# Node  104  already present
# 103
# Node  45  already present
# 233
# Adding  104 --> 45
# Node  21  already present
# 17
# Inserted node  345
# Adding  21 --> 345
# Node  239  already present
# 39
# Node  323  already present
# 94
# Adding  239 --> 323
# Node  194  already present
# 0
# Node  80  already present
# 191
# Adding  194 --> 80
# Node  214  already present
# 177
# Node  17  already present
# 4
# Adding  214 --> 17
# Node  271  already present
# 21
# Node  322  already present
# 98
# Adding  271 --> 322
# Node  3  already present
# 112
# Node  228  already present
# 200
# Adding  3 --> 228
# Node  272  already present
# 58
# Node  75  already present
# 110
# Adding  272 --> 75
# Node  169  already present
# 27
# Node  248  already present
# 188
# Adding  169 --> 248
# Node  239  already present
# 39
# Node  338  already present
# 159
# Adding  239 --> 338
# Node  322  already present
# 98
# Inserted node  87
# Adding  322 --> 87
# Node  169  already present
# 27
# Node  121  already present
# 169
# Adding  169 --> 121
# Node  272  already present
# 58
# Node  184  already present
# 234
# Adding  272 --> 184
# Node  285  already present
# 16
# Node  277  already present
# 45
# Adding  285 --> 277
# Node  98  already present
# 89
# Node  277  already present
# 45
# Adding  98 --> 277
# Node  109  already present
# 25
# Node  314  already present
# 245
# Adding  109 --> 314
# Node  302  already present
# 10
# Node  330  already present
# 115
# Adding  302 --> 330
# Node  204  already present
# 116
# Node  180  already present
# 97
# Adding  204 --> 180
# Node  21  already present
# 17
# Node  159  already present
# 189
# Adding  21 --> 159
# Node  53  already present
# 63
# Node  249  already present
# 20
# Adding  53 --> 249
# Node  9  already present
# 14
# Node  85  already present
# 185
# Adding  9 --> 85
# Node  82  already present
# 117
# Node  231  already present
# 201
# Adding  82 --> 231
# Node  236  already present
# 88
# Node  133  already present
# 67
# Adding  236 --> 133
# Node  211  already present
# 50
# Node  223  already present
# 107
# Adding  211 --> 223
# Node  9  already present
# 14
# Node  224  already present
# 74
# Adding  9 --> 224
# Node  200  already present
# 102
# Node  75  already present
# 110
# Adding  200 --> 75
# Node  242  already present
# 146
# Node  92  already present
# 49
# Adding  242 --> 92
# Node  122  already present
# 7
# Node  277  already present
# 45
# Adding  122 --> 277
# Node  122  already present
# 7
# Node  252  already present
# 2
# Adding  122 --> 252
# Node  322  already present
# 98
# Node  88  already present
# 111
# Adding  322 --> 88
# Node  26  already present
# 118
# Node  223  already present
# 107
# Adding  26 --> 223
# Node  98  already present
# 89
# Node  113  already present
# 148
# Adding  98 --> 113
# Node  21  already present
# 17
# Node  39  already present
# 203
# Adding  21 --> 39
# Node  67  already present
# 3
# Node  185  already present
# 144
# Adding  67 --> 185
# Node  141  already present
# 30
# Node  72  already present
# 91
# Adding  141 --> 72
# Node  186  already present
# 6
# Node  67  already present
# 3
# Adding  186 --> 67
# Node  111  already present
# 84
# Node  44  already present
# 175
# Adding  111 --> 44
# Node  284  already present
# 80
# Node  281  already present
# 48
# Adding  284 --> 281
# Node  31  already present
# 77
# Node  129  already present
# 232
# Adding  31 --> 129
# Node  291  already present
# 9
# Node  258  already present
# 210
# Adding  291 --> 258
# Node  187  already present
# 248
# Node  249  already present
# 20
# Adding  187 --> 249
# Node  135  already present
# 79
# Node  320  already present
# 180
# Adding  135 --> 320
# Node  276  already present
# 195
# Node  56  already present
# 82
# Adding  276 --> 56
# Node  320  already present
# 180
# Node  309  already present
# 137
# Adding  320 --> 309
# Node  118  already present
# 128
# Node  268  already present
# 213
# Adding  118 --> 268
# Node  17  already present
# 4
# Node  19  already present
# 163
# Adding  17 --> 19
# Node  67  already present
# 3
# Node  303  already present
# 190
# Adding  67 --> 303
# Node  119  already present
# 130
# Node  324  already present
# 46
# Adding  119 --> 324
# Node  313  already present
# 28
# Node  118  already present
# 128
# Adding  313 --> 118
# Node  116  already present
# 92
# Node  214  already present
# 177
# Adding  116 --> 214
# Node  231  already present
# 201
# Node  117  already present
# 42
# Adding  231 --> 117
# Node  252  already present
# 2
# Node  66  already present
# 119
# Adding  252 --> 66
# Node  199  already present
# 53
# Node  232  already present
# 104
# Adding  199 --> 232
# Node  291  already present
# 9
# Node  31  already present
# 77
# Adding  291 --> 31
# Node  9  already present
# 14
# Node  232  already present
# 104
# Adding  9 --> 232
# Node  310  already present
# 72
# Node  337  already present
# 252
# Adding  310 --> 337
# Node  213  already present
# 129
# Node  80  already present
# 191
# Adding  213 --> 80
# Node  104  already present
# 103
# Inserted node  295
# Adding  104 --> 295
# Node  334  already present
# 19
# Node  123  already present
# 154
# Adding  334 --> 123
# Node  137  already present
# 139
# Node  337  already present
# 252
# Adding  137 --> 337
# Node  271  already present
# 21
# Node  172  already present
# 171
# Adding  271 --> 172
# Node  116  already present
# 92
# Node  17  already present
# 4
# Adding  116 --> 17
# Node  204  already present
# 116
# Node  254  already present
# 236
# Adding  204 --> 254
# Node  82  already present
# 117
# Node  59  already present
# 227
# Adding  82 --> 59
# Node  271  already present
# 21
# Node  109  already present
# 25
# Adding  271 --> 109
# Node  144  already present
# 192
# Node  41  already present
# 5
# Adding  144 --> 41
# Node  239  already present
# 39
# Node  238  already present
# 59
# Adding  239 --> 238
# Node  186  already present
# 6
# Node  55  already present
# 44
# Adding  186 --> 55
# Node  278  already present
# 253
# Inserted node  86
# Adding  278 --> 86
# Node  271  already present
# 21
# Node  119  already present
# 130
# Adding  271 --> 119
# Node  285  already present
# 16
# Node  188  already present
# 8
# Adding  285 --> 188
# Node  170  already present
# 12
# Node  200  already present
# 102
# Adding  170 --> 200
# Node  40  already present
# 62
# Node  258  already present
# 210
# Adding  40 --> 258
# Node  88  already present
# 111
# Node  1  already present
# 105
# Adding  88 --> 1
# Node  67  already present
# 3
# Node  25  already present
# 31
# Adding  67 --> 25
# Node  186  already present
# 6
# Node  9  already present
# 14
# Adding  186 --> 9
# Node  344  already present
# 113
# Node  212  already present
# 259
# Adding  344 --> 212
# Node  98  already present
# 89
# Node  325  already present
# 136
# Adding  98 --> 325
# Node  236  already present
# 88
# Node  276  already present
# 195
# Adding  236 --> 276
# Node  3  already present
# 112
# Node  85  already present
# 185
# Adding  3 --> 85
# Node  122  already present
# 7
# Node  45  already present
# 233
# Adding  122 --> 45
# Node  170  already present
# 12
# Node  313  already present
# 28
# Adding  170 --> 313
# Node  118  already present
# 128
# Node  331  already present
# 134
# Adding  118 --> 331
# Node  62  already present
# 81
# Node  261  already present
# 22
# Adding  62 --> 261
# Node  200  already present
# 102
# Node  142  already present
# 13
# Adding  200 --> 142
# Node  332  already present
# 132
# Node  170  already present
# 12
# Adding  332 --> 170
# Node  20  already present
# 183
# Node  149  already present
# 172
# Adding  20 --> 149
# Node  23  already present
# 86
# Node  99  already present
# 257
# Adding  23 --> 99
# Node  236  already present
# 88
# Node  322  already present
# 98
# Adding  236 --> 322
# Node  239  already present
# 39
# Node  203  already present
# 15
# Adding  239 --> 203
# Node  28  already present
# 71
# Node  326  already present
# 250
# Adding  28 --> 326
# Node  315  already present
# 68
# Node  40  already present
# 62
# Adding  315 --> 40
# Node  78  already present
# 206
# Node  218  already present
# 240
# Adding  78 --> 218
# Node  80  already present
# 191
# Node  180  already present
# 97
# Adding  80 --> 180
# Node  200  already present
# 102
# Node  31  already present
# 77
# Adding  200 --> 31
# Node  200  already present
# 102
# Node  185  already present
# 144
# Adding  200 --> 185
# Inserted node  150
# Node  189  already present
# 133
# Adding  150 --> 189
# Node  94  already present
# 106
# Node  80  already present
# 191
# Adding  94 --> 80
# Node  170  already present
# 12
# Node  25  already present
# 31
# Adding  170 --> 25
# Node  144  already present
# 192
# Node  115  already present
# 33
# Adding  144 --> 115
# Node  25  already present
# 31
# Inserted node  79
# Adding  25 --> 79
# Node  188  already present
# 8
# Node  142  already present
# 13
# Adding  188 --> 142
# Node  9  already present
# 14
# Node  128  already present
# 29
# Adding  9 --> 128
# Node  171  already present
# 131
# Inserted node  107
# Adding  171 --> 107
# Node  84  already present
# 73
# Node  237  already present
# 87
# Adding  84 --> 237
# Node  334  already present
# 19
# Node  203  already present
# 15
# Adding  334 --> 203
# Node  113  already present
# 148
# Node  148  already present
# 34
# Adding  113 --> 148
# Node  158  already present
# 147
# Node  5  already present
# 181
# Adding  158 --> 5
# Node  304  already present
# 126
# Node  280  already present
# 26
# Adding  304 --> 280
# Node  323  already present
# 94
# Node  67  already present
# 3
# Adding  323 --> 67
# Node  277  already present
# 45
# Node  339  already present
# 76
# Adding  277 --> 339
# Node  257  already present
# 196
# Node  295  already present
# 265
# Adding  257 --> 295
# Node  118  already present
# 128
# Node  161  already present
# 99
# Adding  118 --> 161
# Node  200  already present
# 102
# Node  297  already present
# 243
# Adding  200 --> 297
# Node  26  already present
# 118
# Node  239  already present
# 39
# Adding  26 --> 239
# Node  56  already present
# 82
# Inserted node  298
# Adding  56 --> 298
# Node  204  already present
# 116
# Node  249  already present
# 20
# Adding  204 --> 249
# Node  332  already present
# 132
# Node  77  already present
# 54
# Adding  332 --> 77
# Node  276  already present
# 195
# Node  62  already present
# 81
# Adding  276 --> 62
# Node  175  already present
# 165
# Node  296  already present
# 258
# Adding  175 --> 296
# Node  199  already present
# 53
# Node  25  already present
# 31
# Adding  199 --> 25
# Node  313  already present
# 28
# Node  314  already present
# 245
# Adding  313 --> 314
# Node  48  already present
# 83
# Node  180  already present
# 97
# Adding  48 --> 180
# Node  272  already present
# 58
# Node  203  already present
# 15
# Adding  272 --> 203
# Node  80  already present
# 191
# Node  92  already present
# 49
# Adding  80 --> 92
# Node  227  already present
# 69
# Node  225  already present
# 254
# Adding  227 --> 225
# Node  323  already present
# 94
# Node  277  already present
# 45
# Adding  323 --> 277
# Node  19  already present
# 163
# Node  41  already present
# 5
# Adding  19 --> 41
# Node  186  already present
# 6
# Node  26  already present
# 118
# Adding  186 --> 26
# Node  315  already present
# 68
# Node  257  already present
# 196
# Adding  315 --> 257
# Node  346  already present
# 96
# Node  254  already present
# 236
# Adding  346 --> 254
# Node  314  already present
# 245
# Node  50  already present
# 160
# Adding  314 --> 50
# Node  322  already present
# 98
# Node  200  already present
# 102
# Adding  322 --> 200
# Node  26  already present
# 118
# Node  298  already present
# 270
# Adding  26 --> 298
# Node  319  already present
# 222
# Inserted node  219
# Adding  319 --> 219
# Node  299  already present
# 114
# Node  187  already present
# 248
# Adding  299 --> 187
# Node  278  already present
# 253
# Node  99  already present
# 257
# Adding  278 --> 99
# Node  189  already present
# 133
# Node  100  already present
# 214
# Adding  189 --> 100
# Node  56  already present
# 82
# Node  303  already present
# 190
# Adding  56 --> 303
# Node  31  already present
# 77
# Node  51  already present
# 149
# Adding  31 --> 51
# Node  252  already present
# 2
# Node  169  already present
# 27
# Adding  252 --> 169
# Node  57  already present
# 247
# Node  302  already present
# 10
# Adding  57 --> 302
# Node  213  already present
# 129
# Node  30  already present
# 60
# Adding  213 --> 30
# Node  299  already present
# 114
# Node  101  already present
# 11
# Adding  299 --> 101
# Node  82  already present
# 117
# Node  325  already present
# 136
# Adding  82 --> 325
# Node  28  already present
# 71
# Node  115  already present
# 33
# Adding  28 --> 115
# Node  48  already present
# 83
# Node  302  already present
# 10
# Adding  48 --> 302
# Node  223  already present
# 107
# Inserted node  246
# Adding  223 --> 246
# Node  122  already present
# 7
# Node  345  already present
# 263
# Adding  122 --> 345
# Node  123  already present
# 154
# Node  55  already present
# 44
# Adding  123 --> 55
# Node  25  already present
# 31
# Node  94  already present
# 106
# Adding  25 --> 94
# Node  17  already present
# 4
# Node  115  already present
# 33
# Adding  17 --> 115
# Inserted node  76
# Node  25  already present
# 31
# Adding  76 --> 25
# Node  315  already present
# 68
# Node  5  already present
# 181
# Adding  315 --> 5
# Node  303  already present
# 190
# Node  132  already present
# 226
# Adding  303 --> 132
# Node  272  already present
# 58
# Node  98  already present
# 89
# Adding  272 --> 98
# Node  13  already present
# 109
# Node  59  already present
# 227
# Adding  13 --> 59
# Node  9  already present
# 14
# Node  252  already present
# 2
# Adding  9 --> 252
# Node  185  already present
# 144
# Node  148  already present
# 34
# Adding  185 --> 148
# Node  272  already present
# 58
# Node  159  already present
# 189
# Adding  272 --> 159
# Node  280  already present
# 26
# Node  31  already present
# 77
# Adding  280 --> 31
# Node  62  already present
# 81
# Node  161  already present
# 99
# Adding  62 --> 161
# Node  252  already present
# 2
# Node  25  already present
# 31
# Adding  252 --> 25
# Node  56  already present
# 82
# Node  169  already present
# 27
# Adding  56 --> 169
# Node  225  already present
# 254
# Inserted node  131
# Adding  225 --> 131
# Inserted node  166
# Inserted node  202
# Adding  166 --> 202
# Node  304  already present
# 126
# Node  332  already present
# 132
# Adding  304 --> 332
# Node  21  already present
# 17
# Node  161  already present
# 99
# Adding  21 --> 161
# Node  159  already present
# 189
# Node  284  already present
# 80
# Adding  159 --> 284
# Node  299  already present
# 114
# Node  302  already present
# 10
# Adding  299 --> 302
# Node  24  already present
# 242
# Node  187  already present
# 248
# Adding  24 --> 187
# Node  26  already present
# 118
# Node  128  already present
# 29
# Adding  26 --> 128
# Node  45  already present
# 233
# Node  221  already present
# 244
# Adding  45 --> 221
# Node  135  already present
# 79
# Node  281  already present
# 48
# Adding  135 --> 281
# Node  122  already present
# 7
# Node  169  already present
# 27
# Adding  122 --> 169
# Node  329  already present
# 75
# Node  231  already present
# 201
# Adding  329 --> 231
# Node  343  already present
# 32
# Node  111  already present
# 84
# Adding  343 --> 111
# Node  142  already present
# 13
# Node  66  already present
# 119
# Adding  142 --> 66
# Node  258  already present
# 210
# Node  295  already present
# 265
# Adding  258 --> 295
# Node  118  already present
# 128
# Node  222  already present
# 143
# Adding  118 --> 222
# Node  304  already present
# 126
# Node  141  already present
# 30
# Adding  304 --> 141
# Node  291  already present
# 9
# Node  10  already present
# 138
# Adding  291 --> 10
# Node  252  already present
# 2
# Node  82  already present
# 117
# Adding  252 --> 82
# Node  177  already present
# 167
# Node  131  already present
# 274
# Adding  177 --> 131
# Node  271  already present
# 21
# Node  265  already present
# 78
# Adding  271 --> 265
# Node  159  already present
# 189
# Node  320  already present
# 180
# Adding  159 --> 320
# Node  134  already present
# 157
# Node  132  already present
# 226
# Adding  134 --> 132
# Node  188  already present
# 8
# Node  341  already present
# 204
# Adding  188 --> 341
# Node  169  already present
# 27
# Node  40  already present
# 62
# Adding  169 --> 40
# Node  67  already present
# 3
# Node  72  already present
# 91
# Adding  67 --> 72
# Node  93  already present
# 85
# Node  41  already present
# 5
# Adding  93 --> 41
# Node  82  already present
# 117
# Node  16  already present
# 217
# Adding  82 --> 16
# Node  172  already present
# 171
# Node  265  already present
# 78
# Adding  172 --> 265
# Node  103  already present
# 199
# Node  339  already present
# 76
# Adding  103 --> 339
# Node  272  already present
# 58
# Node  257  already present
# 196
# Adding  272 --> 257
# Node  273  already present
# 255
# Node  306  already present
# 40
# Adding  273 --> 306
# Node  271  already present
# 21
# Node  170  already present
# 12
# Adding  271 --> 170
# Node  118  already present
# 128
# Node  261  already present
# 22
# Adding  118 --> 261
# Node  39  already present
# 203
# Node  121  already present
# 169
# Adding  39 --> 121
# Node  144  already present
# 192
# Node  343  already present
# 32
# Adding  144 --> 343
# Node  53  already present
# 63
# Node  260  already present
# 124
# Adding  53 --> 260
# Node  128  already present
# 29
# Node  203  already present
# 15
# Adding  128 --> 203
# Node  214  already present
# 177
# Node  343  already present
# 32
# Adding  214 --> 343
# Node  308  already present
# 220
# Node  66  already present
# 119
# Adding  308 --> 66
# Node  24  already present
# 242
# Node  57  already present
# 247
# Adding  24 --> 57
# Node  130  already present
# 246
# Node  300  already present
# 209
# Adding  130 --> 300
# Node  200  already present
# 102
# Node  277  already present
# 45
# Adding  200 --> 277
# Node  56  already present
# 82
# Node  342  already present
# 150
# Adding  56 --> 342
# Node  239  already present
# 39
# Node  21  already present
# 17
# Adding  239 --> 21
# Node  137  already present
# 139
# Inserted node  243
# Adding  137 --> 243
# Node  82  already present
# 117
# Node  199  already present
# 53
# Adding  82 --> 199
# ...
# 91
# Node  249  already present
# 216
# Adding  102 --> 249
# Node  169  already present
# 125
# Node  96  already present
# 285
# Adding  169 --> 96
# Node  255  already present
# 69
# Node  231  already present
# 261
# Adding  255 --> 231
# Node  128  already present
# 43
# Node  285  already present
# 163
# Adding  128 --> 285
# Node  133  already present
# 59
# Node  250  already present
# 45
# Adding  133 --> 250
# Node  103  already present
# 217
# Node  1  already present
# 28
# Adding  103 --> 1
# Node  57  already present
# 331
# Node  269  already present
# 315
# Adding  57 --> 269
# Node  181  already present
# 190
# Node  189  already present
# 239
# Adding  181 --> 189
# Node  129  already present
# 166
# Node  94  already present
# 304
# Adding  129 --> 94
# Node  38  already present
# 243
# Node  182  already present
# 236
# Adding  38 --> 182
# Node  311  already present
# 211
# Node  223  already present
# 235
# Adding  311 --> 223
# Node  15  already present
# 209
# Node  53  already present
# 257
# Adding  15 --> 53
# Node  327  already present
# 271
# Node  288  already present
# 191
# Adding  327 --> 288
# Node  298  already present
# 328
# Node  172  already present
# 35
# Adding  298 --> 172
# Node  149  already present
# 248
# Node  15  already present
# 209
# Adding  149 --> 15
# Node  280  already present
# 66
# Node  279  already present
# 242
# Adding  280 --> 279
# Node  108  already present
# 121
# Node  287  already present
# 196
# Adding  108 --> 287
# Node  172  already present
# 35
# Node  211  already present
# 119
# Adding  172 --> 211
# Node  36  already present
# 198
# Node  66  already present
# 228
# Adding  36 --> 66
# Node  307  already present
# 5
# Node  286  already present
# 293
# Adding  307 --> 286
# Node  147  already present
# 220
# Node  105  already present
# 307
# Adding  147 --> 105
# Node  280  already present
# 66
# Node  283  already present
# 249
# Adding  280 --> 283
# Node  243  already present
# 210
# Node  318  already present
# 280
# Adding  243 --> 318
# Node  166  already present
# 245
# Node  136  already present
# 61
# Adding  166 --> 136
# Node  89  already present
# 4
# Node  300  already present
# 269
# Adding  89 --> 300
# Node  96  already present
# 285
# Node  226  already present
# 93
# Adding  96 --> 226
# Node  214  already present
# 274
# Node  310  already present
# 291
# Adding  214 --> 310
# Node  283  already present
# 249
# Node  47  already present
# 62
# Adding  283 --> 47
# Node  332  already present
# 320
# Node  110  already present
# 131
# Adding  332 --> 110
# Node  218  already present
# 95
# Node  149  already present
# 248
# Adding  218 --> 149
# Node  229  already present
# 170
# Node  241  already present
# 240
# Adding  229 --> 241
# Node  58  already present
# 124
# Node  33  already present
# 54
# Adding  58 --> 33
# Node  120  already present
# 212
# Node  18  already present
# 37
# Adding  120 --> 18
# Node  106  already present
# 266
# Node  309  already present
# 168
# Adding  106 --> 309
# Node  217  already present
# 30
# Node  167  already present
# 50
# Adding  217 --> 167
# Node  87  already present
# 44
# Node  272  already present
# 102
# Adding  87 --> 272
# Node  198  already present
# 330
# Node  155  already present
# 224
# Adding  198 --> 155
# Node  141  already present
# 250
# Node  167  already present
# 50
# Adding  141 --> 167
# Node  228  already present
# 67
# Node  172  already present
# 35
# Adding  228 --> 172
# Node  223  already present
# 235
# Node  192  already present
# 147
# Adding  223 --> 192
# Node  221  already present
# 26
# Node  215  already present
# 308
# Adding  221 --> 215
# Node  77  already present
# 22
# Node  84  already present
# 139
# Adding  77 --> 84
# Node  102  already present
# 91
# Node  284  already present
# 90
# Adding  102 --> 284
# Node  49  already present
# 258
# Node  62  already present
# 133
# Adding  49 --> 62
# Node  68  already present
# 68
# Node  39  already present
# 49
# Adding  68 --> 39
# Node  153  already present
# 16
# Node  81  already present
# 149
# Adding  153 --> 81
# Node  237  already present
# 60
# Node  91  already present
# 310
# Adding  237 --> 91
# Node  219  already present
# 110
# Node  106  already present
# 266
# Adding  219 --> 106
# Node  41  already present
# 201
# Node  309  already present
# 168
# Adding  41 --> 309
# Node  88  already present
# 313
# Node  134  already present
# 41
# Adding  88 --> 134
# Node  188  already present
# 11
# Node  160  already present
# 13
# Adding  188 --> 160
# Node  253  already present
# 195
# Node  327  already present
# 271
# Adding  253 --> 327
# Node  125  already present
# 252
# Node  186  already present
# 71
# Adding  125 --> 186
# Node  39  already present
# 49
# Node  172  already present
# 35
# Adding  39 --> 172
# Node  271  already present
# 311
# Node  288  already present
# 191
# Adding  271 --> 288
# Node  235  already present
# 106
# Node  312  already present
# 65
# Adding  235 --> 312
# Node  64  already present
# 31
# Node  165  already present
# 183
# Adding  64 --> 165
# Node  62  already present
# 133
# Node  308  already present
# 141
# Adding  62 --> 308
# Node  286  already present
# 293
# Node  229  already present
# 170
# Adding  286 --> 229
# Node  153  already present
# 16
# Node  251  already present
# 80
# Adding  153 --> 251
# Node  112  already present
# 12
# Node  27  already present
# 317
# Adding  112 --> 27
# Node  252  already present
# 192
# Node  327  already present
# 271
# Adding  252 --> 327
# Node  207  already present
# 237
# Node  252  already present
# 192
# Adding  207 --> 252
# Node  310  already present
# 291
# Node  192  already present
# 147
# Adding  310 --> 192
# Node  266  already present
# 14
# Node  68  already present
# 68
# Adding  266 --> 68
# Node  231  already present
# 261
# Node  81  already present
# 149
# Adding  231 --> 81
# Node  225  already present
# 34
# Node  178  already present
# 232
# Adding  225 --> 178
# Node  72  already present
# 158
# Node  207  already present
# 237
# Adding  72 --> 207
# Node  76  already present
# 33
# Node  90  already present
# 111
# Adding  76 --> 90
# Node  5  already present
# 48
# Node  217  already present
# 30
# Adding  5 --> 217
# Node  234  already present
# 89
# Node  113  already present
# 87
# Adding  234 --> 113
# Node  41  already present
# 201
# Node  283  already present
# 249
# Adding  41 --> 283
# Node  211  already present
# 119
# Node  320  already present
# 159
# Adding  211 --> 320
# Node  112  already present
# 12
# Node  75  already present
# 256
# Adding  112 --> 75
# Node  12  already present
# 143
# Node  253  already present
# 195
# Adding  12 --> 253
# Node  68  already present
# 68
# Node  204  already present
# 292
# Adding  68 --> 204
# Node  305  already present
# 279
# Node  190  already present
# 286
# Adding  305 --> 190
# Node  152  already present
# 281
# Node  230  already present
# 294
# Adding  152 --> 230
# Node  324  already present
# 142
# Node  13  already present
# 104
# Adding  324 --> 13
# Node  167  already present
# 50
# Node  72  already present
# 158
# Adding  167 --> 72
# Node  60  already present
# 289
# Node  168  already present
# 84
# Adding  60 --> 168
# Node  134  already present
# 41
# Node  8  already present
# 181
# Adding  134 --> 8
# Node  145  already present
# 241
# Node  286  already present
# 293
# Adding  145 --> 286
# Node  30  already present
# 118
# Node  116  already present
# 98
# Adding  30 --> 116
# Node  152  already present
# 281
# Node  255  already present
# 69
# Adding  152 --> 255
# Node  142  already present
# 264
# Node  197  already present
# 40
# Adding  142 --> 197
# Node  248  already present
# 193
# Node  157  already present
# 214
# Adding  248 --> 157
# Node  190  already present
# 286
# Node  136  already present
# 61
# Adding  190 --> 136
# Node  209  already present
# 128
# Node  291  already present
# 72
# Adding  209 --> 291
# Node  123  already present
# 287
# Node  88  already present
# 313
# Adding  123 --> 88
# Node  68  already present
# 68
# Node  288  already present
# 191
# Adding  68 --> 288
# Node  290  already present
# 174
# Node  277  already present
# 312
# Adding  290 --> 277
# Node  225  already present
# 34
# Node  83  already present
# 182
# Adding  225 --> 83
# Node  88  already present
# 313
# Node  107  already present
# 38
# Adding  88 --> 107
# Node  129  already present
# 166
# Node  162  already present
# 329
# Adding  129 --> 162
# Node  75  already present
# 256
# Node  102  already present
# 91
# Adding  75 --> 102
# Node  90  already present
# 111
# Node  206  already present
# 146
# Adding  90 --> 206
# Node  285  already present
# 163
# Node  5  already present
# 48
# Adding  285 --> 5
# Node  130  already present
# 223
# Node  117  already present
# 107
# Adding  130 --> 117
# Node  269  already present
# 315
# Node  213  already present
# 7
# Adding  269 --> 213
# Node  179  already present
# 306
# Node  265  already present
# 2
# Adding  179 --> 265
# Node  186  already present
# 71
# Node  10  already present
# 56
# Adding  186 --> 10
# Node  187  already present
# 202
# Node  65  already present
# 205
# Adding  187 --> 65
# Node  1  already present
# 28
# Node  302  already present
# 319
# Adding  1 --> 302
# Node  1  already present
# 28
# Node  185  already present
# 148
# Adding  1 --> 185
# Node  332  already present
# 320
# Node  251  already present
# 80
# Adding  332 --> 251
# Node  160  already present
# 13
# Node  153  already present
# 16
# Adding  160 --> 153
# Node  98  already present
# 176
# Node  73  already present
# 234
# Adding  98 --> 73
# Node  223  already present
# 235
# Node  190  already present
# 286
# Adding  223 --> 190
# Node  194  already present
# 1
# Node  214  already present
# 274
# Adding  194 --> 214
# Node  47  already present
# 62
# Node  326  already present
# 219
# Adding  47 --> 326
# Node  63  already present
# 115
# Node  141  already present
# 250
# Adding  63 --> 141
# Node  123  already present
# 287
# Node  129  already present
# 166
# Adding  123 --> 129
# Node  33  already present
# 54
# Node  119  already present
# 273
# Adding  33 --> 119
# Node  147  already present
# 220
# Node  93  already present
# 208
# Adding  147 --> 93
# Node  200  already present
# 113
# Node  316  already present
# 25
# Adding  200 --> 316
# Node  245  already present
# 231
# Node  272  already present
# 102
# Adding  245 --> 272
# Node  14  already present
# 100
# Node  312  already present
# 65
# Adding  14 --> 312
# Node  45  already present
# 63
# Node  221  already present
# 26
# Adding  45 --> 221
# Node  191  already present
# 18
# Node  115  already present
# 295
# Adding  191 --> 115
# Node  34  already present
# 120
# Node  193  already present
# 19
# Adding  34 --> 193
# Node  228  already present
# 67
# Node  75  already present
# 256
# Adding  228 --> 75
# Node  224  already present
# 272
# Node  121  already present
# 144
# Adding  224 --> 121
# Node  196  already present
# 309
# Node  327  already present
# 271
# Adding  196 --> 327
# Node  66  already present
# 228
# Node  96  already present
# 285
# Adding  66 --> 96
# Node  223  already present
# 235
# Node  134  already present
# 41
# Adding  223 --> 134
# Node  77  already present
# 22
# Node  315  already present
# 297
# Adding  77 --> 315
# Node  148  already present
# 127
# Node  48  already present
# 290
# Adding  148 --> 48
# Node  8  already present
# 181
# Node  129  already present
# 166
# Adding  8 --> 129
# Node  245  already present
# 231
# Node  37  already present
# 167
# Adding  245 --> 37
# Node  96  already present
# 285
# Node  26  already present
# 175
# Adding  96 --> 26
# Node  152  already present
# 281
# Node  264  already present
# 152
# Adding  152 --> 264
# Node  319  already present
# 109
# Node  81  already present
# 149
# Adding  319 --> 81
# Node  83  already present
# 182
# Node  82  already present
# 70
# Adding  83 --> 82
# Node  180  already present
# 230
# Node  242  already present
# 254
# Adding  180 --> 242
# Node  124  already present
# 156
# Node  239  already present
# 247
# Adding  124 --> 239
# Node  215  already present
# 308
# Node  97  already present
# 126
# Adding  215 --> 97
# Node  137  already present
# 316
# Node  50  already present
# 221
# Adding  137 --> 50
# Node  114  already present
# 165
# Node  91  already present
# 310
# Adding  114 --> 91
# Node  27  already present
# 317
# Node  291  already present
# 72
# Adding  27 --> 291
# Node  189  already present
# 239
# Node  133  already present
# 59
# Adding  189 --> 133
# Node  326  already present
# 219
# Node  69  already present
# 267
# Adding  326 --> 69
# Node  131  already present
# 55
# Node  56  already present
# 325
# Adding  131 --> 56
# Node  41  already present
# 201
# Node  212  already present
# 160
# Adding  41 --> 212
# Node  252  already present
# 192
# Node  304  already present
# 314
# Adding  252 --> 304
# Node  187  already present
# 202
# Node  54  already present
# 24
# Adding  187 --> 54
# Node  276  already present
# 79
# Node  231  already present
# 261
# Adding  276 --> 231
# Node  130  already present
# 223
# Node  100  already present
# 172
# Adding  130 --> 100
# Node  102  already present
# 91
# Node  302  already present
# 319
# Adding  102 --> 302
# Node  32  already present
# 132
# Node  292  already present
# 288
# Adding  32 --> 292
# Node  251  already present
# 80
# Node  233  already present
# 21
# Adding  251 --> 233
# Node  102  already present
# 91
# Node  81  already present
# 149
# Adding  102 --> 81
# Node  19  already present
# 23
# Node  267  already present
# 17
# Adding  19 --> 267
# Node  54  already present
# 24
# Node  138  already present
# 187
# Adding  54 --> 138
# Node  300  already present
# 269
# Node  170  already present
# 86
# Adding  300 --> 170
# Node  144  already present
# 116
# Node  324  already present
# 142
# Adding  144 --> 324
# Node  219  already present
# 110
# Node  179  already present
# 306
# Adding  219 --> 179
# Node  248  already present
# 193
# Node  250  already present
# 45
# Adding  248 --> 250
# Node  177  already present
# 20
# Node  288  already present
# 191
# Adding  177 --> 288
# Node  221  already present
# 26
# Node  85  already present
# 101
# Adding  221 --> 85
# Node  156  already present
# 284
# Node  297  already present
# 96
# Adding  156 --> 297
# Node  32  already present
# 132
# Node  281  already present
# 275
# Adding  32 --> 281
# Node  103  already present
# 217
# Node  114  already present
# 165
# Adding  103 --> 114
# Node  308  already present
# 141
# Node  319  already present
# 109
# Adding  308 --> 319
# Node  185  already present
# 148
# Node  93  already present
# 208
# Adding  185 --> 93
# Node  8  already present
# 181
# Node  38  already present
# 243
# Adding  8 --> 38
# Node  149  already present
# 248
# Node  96  already present
# 285
# Adding  149 --> 96
# Node  23  already present
# 117
# Node  250  already present
# 45
# Adding  23 --> 250
# Node  172  already present
# 35
# Node  260  already present
# 327
# Adding  172 --> 260
# Node  249  already present
# 216
# Node  0  already present
# 227
# Adding  249 --> 0
# Node  192  already present
# 147
# Node  134  already present
# 41
# Adding  192 --> 134
# Node  286  already present
# 293
# Node  311  already present
# 211
# Adding  286 --> 311
# Node  68  already present
# 68
# Node  214  already present
# 274
# Adding  68 --> 214
# Node  296  already present
# 77
# Node  174  already present
# 8
# Adding  296 --> 174
# Node  28  already present
# 194
# Node  13  already present
# 104
# Adding  28 --> 13
# Node  174  already present
# 8
# Node  86  already present
# 246
# Adding  174 --> 86
# Node  309  already present
# 168
# Node  171  already present
# 171
# Adding  309 --> 171
# Node  137  already present
# 316
# Node  174  already present
# 8
# Adding  137 --> 174
# Node  181  already present
# 190
# Node  145  already present
# 241
# Adding  181 --> 145
# Node  301  already present
# 0
# Node  263  already present
# 154
# Adding  301 --> 263
# Node  252  already present
# 192
# Node  259  already present
# 99
# Adding  252 --> 259
# Node  329  already present
# 137
# Node  91  already present
# 310
# Adding  329 --> 91
# Node  214  already present
# 274
# Node  153  already present
# 16
# Adding  214 --> 153
# Node  126  already present
# 179
# Node  192  already present
# 147
# Adding  126 --> 192
# Node  261  already present
# 332
# Node  181  already present
# 190
# Adding  261 --> 181
# Node  220  already present
# 155
# Node  298  already present
# 328
# Adding  220 --> 298
# Node  20  already present
# 203
# Node  282  already present
# 92
# Adding  20 --> 282
# Node  51  already present
# 46
# Node  297  already present
# 96
# Adding  51 --> 297
# Node  329  already present
# 137
# Node  37  already present
# 167
# Adding  329 --> 37
# Node  105  already present
# 307
# Node  44  already present
# 251
# Adding  105 --> 44
# Node  83  already present
# 182
# Node  81  already present
# 149
# Adding  83 --> 81
# Node  136  already present
# 61
# Node  88  already present
# 313
# Adding  136 --> 88
# Node  225  already present
# 34
# Node  252  already present
# 192
# Adding  225 --> 252
# Node  27  already present
# 317
# Node  301  already present
# 0
# Adding  27 --> 301
# Node  11  already present
# 253
# Node  36  already present
# 198
# Adding  11 --> 36
# Node  143  already present
# 321
# Node  256  already present
# 180
# Adding  143 --> 256
# Node  31  already present
# 283
# Node  330  already present
# 53
# Adding  31 --> 330
# Node  155  already present
# 224
# Node  157  already present
# 214
# Adding  155 --> 157
# Node  39  already present
# 49
# Node  250  already present
# 45
# Adding  39 --> 250
# Node  103  already present
# 217
# Node  28  already present
# 194
# Adding  103 --> 28

# %%
print(type(node_feat))
for eachKey in node_feat.values():
    print(len(eachKey))
    print(type(eachKey))
# Out:
# <class 'dict'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>
# 224
# <class 'numpy.ndarray'>

# %%
def make_class_arrays(g,datalabel):
    output_list=list()
    edgeSet=g.es
    for eachTuple in edgeSet:
        tuple_name=retrieve_edge_name_tuple(g,eachTuple.tuple)
        print('eachTuple=',tuple_name)
        if(tuple_name[1]!='0'):
            output=np.add(node_feat[np.float64(tuple_name[0])],node_feat[np.float64(tuple_name[1])])
            output_list.append(output)
    return np.asarray(output_list)

# %%
valid_g=Graph()
load_dataset('C://Users//Admin//Downloads//facebook//Self_Datasets//sample_valid.edges',valid_g)
node_feat=load_and_shape_input("C://Users//Admin//Downloads//facebook//facebook//0.feat")


valid_not_g=Graph()
load_dataset('C://Users//Admin//Downloads//facebook//Self_Datasets//negative_valid.edges',valid_not_g)
# Out:
# 0
# fileName= C://Users//Admin//Downloads//facebook//Self_Datasets//sample_valid.edges
# Inserted node  144
# Adding  23 --> 144
# Inserted node  6
# Inserted node  95
# Adding  6 --> 95
# Inserted node  296
# Inserted node  68
# Adding  296 --> 68
# Inserted node  290
# Inserted node  342
# Adding  290 --> 342
# Inserted node  315
# Inserted node  223
# Adding  315 --> 223
# Inserted node  199
# Inserted node  313
# Adding  199 --> 313
# Inserted node  317
# Inserted node  40
# Adding  317 --> 40
# Inserted node  239
# Node  40  already present
# 13
# Adding  239 --> 40
# Inserted node  99
# Inserted node  225
# Adding  99 --> 225
# Inserted node  25
# Inserted node  113
# Adding  25 --> 113
# Inserted node  82
# Inserted node  123
# Adding  82 --> 123
# Node  313  already present
# 11
# Inserted node  60
# Adding  313 --> 60
# Inserted node  24
# Inserted node  346
# Adding  24 --> 346
# Node  99  already present
# 15
# Inserted node  102
# Adding  99 --> 102
# Inserted node  72
# Inserted node  298
# Adding  72 --> 298
# Inserted node  26
# Inserted node  248
# Adding  26 --> 248
# Inserted node  310
# Inserted node  243
# Adding  310 --> 243
# Inserted node  278
# Inserted node  131
# Adding  278 --> 131
# Inserted node  98
# Node  25  already present
# 17
# Adding  98 --> 25
# Inserted node  109
# Inserted node  295
# Adding  109 --> 295
# Inserted node  345
# Inserted node  261
# Adding  345 --> 261
# Inserted node  3
# Inserted node  274
# Adding  3 --> 274
# Node  26  already present
# 27
# Inserted node  297
# Adding  26 --> 297
# Node  98  already present
# 33
# Node  123  already present
# 20
# Adding  98 --> 123
# Inserted node  254
# Inserted node  302
# Adding  254 --> 302
# Node  25  already present
# 17
# Inserted node  39
# Adding  25 --> 39
# Inserted node  119
# Inserted node  13
# Adding  119 --> 13
# Inserted node  329
# Node  119  already present
# 44
# Adding  329 --> 119
# Inserted node  285
# Node  239  already present
# 14
# Adding  285 --> 239
# Inserted node  111
# Inserted node  337
# Adding  111 --> 337
# Inserted node  170
# Node  315  already present
# 8
# Adding  170 --> 315
# Inserted node  291
# Inserted node  224
# Adding  291 --> 224
# Inserted node  276
# Inserted node  84
# Adding  276 --> 84
# Inserted node  271
# Inserted node  238
# Adding  271 --> 238
# Node  119  already present
# 44
# Inserted node  185
# Adding  119 --> 185
# Node  315  already present
# 8
# Inserted node  105
# Adding  315 --> 105
# Inserted node  73
# Inserted node  299
# Adding  73 --> 299
# Inserted node  141
# Node  224  already present
# 52
# Adding  141 --> 224
# Inserted node  122
# Inserted node  176
# Adding  122 --> 176
# Node  109  already present
# 34
# Inserted node  303
# Adding  109 --> 303
# Inserted node  9
# Inserted node  277
# Adding  9 --> 277
# Node  122  already present
# 62
# Inserted node  62
# Adding  122 --> 62
# Inserted node  36
# Inserted node  284
# Adding  36 --> 284
# Inserted node  142
# Node  113  already present
# 18
# Adding  142 --> 113
# Inserted node  213
# Inserted node  178
# Adding  213 --> 178
# Inserted node  56
# Node  142  already present
# 70
# Adding  56 --> 142
# Inserted node  322
# Inserted node  48
# Adding  322 --> 48
# Inserted node  343
# Inserted node  19
# Adding  343 --> 19
# Node  9  already present
# 65
# Inserted node  258
# Adding  9 --> 258
# Node  142  already present
# 70
# Inserted node  203
# Adding  142 --> 203
# Inserted node  312
# Inserted node  226
# Adding  312 --> 226
# Inserted node  272
# Node  178  already present
# 72
# Adding  272 --> 178
# Node  24  already present
# 22
# Inserted node  242
# Adding  24 --> 242
# Node  285  already present
# 47
# Inserted node  103
# Adding  285 --> 103
# Inserted node  80
# Inserted node  173
# Adding  80 --> 173
# Node  26  already present
# 27
# Inserted node  172
# Adding  26 --> 172
# Inserted node  204
# Node  277  already present
# 66
# Adding  204 --> 277
# Inserted node  323
# Node  109  already present
# 34
# Adding  323 --> 109
# Node  48  already present
# 75
# Inserted node  330
# Adding  48 --> 330
# Node  98  already present
# 33
# Node  141  already present
# 61
# Adding  98 --> 141
# Node  312  already present
# 80
# Inserted node  140
# Adding  312 --> 140
# Inserted node  116
# Inserted node  28
# Adding  116 --> 28
# Node  299  already present
# 60
# Inserted node  180
# Adding  299 --> 180
# Node  239  already present
# 14
# Node  322  already present
# 74
# Adding  239 --> 322
# Inserted node  161
# Node  258  already present
# 78
# Adding  161 --> 258
# Node  254  already present
# 41
# Inserted node  196
# Adding  254 --> 196
# Node  213  already present
# 71
# Inserted node  128
# Adding  213 --> 128
# Node  103  already present
# 84
# Node  323  already present
# 89
# Adding  103 --> 323
# Inserted node  67
# Inserted node  75
# Adding  67 --> 75
# Node  56  already present
# 73
# Node  261  already present
# 37
# Adding  56 --> 261
# Inserted node  8
# Inserted node  245
# Adding  8 --> 245
# Node  122  already present
# 62
# Inserted node  136
# Adding  122 --> 136
# Node  312  already present
# 80
# Inserted node  2
# Adding  312 --> 2
# Node  285  already present
# 47
# Node  98  already present
# 33
# Adding  285 --> 98
# Node  213  already present
# 71
# Node  315  already present
# 8
# Adding  213 --> 315
# Inserted node  133
# Inserted node  188
# Adding  133 --> 188
# Inserted node  259
# Inserted node  264
# Adding  259 --> 264
# Node  239  already present
# 14
# Inserted node  231
# Adding  239 --> 231
# Node  122  already present
# 62
# Inserted node  156
# Adding  122 --> 156
# Node  346  already present
# 23
# Inserted node  1
# Adding  346 --> 1
# Node  56  already present
# 73
# Inserted node  341
# Adding  56 --> 341
# Inserted node  78
# Inserted node  181
# Adding  78 --> 181
# Node  67  already present
# 98
# Node  224  already present
# 52
# Adding  67 --> 224
# Inserted node  252
# Node  223  already present
# 9
# Adding  252 --> 223
# Node  84  already present
# 54
# Inserted node  31
# Adding  84 --> 31
# Node  39  already present
# 43
# Inserted node  257
# Adding  39 --> 257
# Node  72  already present
# 25
# Inserted node  132
# Adding  72 --> 132
# Node  56  already present
# 73
# Inserted node  212
# Adding  56 --> 212
# Inserted node  115
# Inserted node  14
# Adding  115 --> 14
# Inserted node  143
# Node  225  already present
# 16
# Adding  143 --> 225
# Node  315  already present
# 8
# Node  98  already present
# 33
# Adding  315 --> 98
# Inserted node  186
# Inserted node  88
# Adding  186 --> 88
# Node  26  already present
# 27
# Inserted node  69
# Adding  26 --> 69
# Node  239  already present
# 14
# Node  261  already present
# 37
# Adding  239 --> 261
# Node  26  already present
# 27
# Node  123  already present
# 20
# Adding  26 --> 123
# Inserted node  300
# Node  80  already present
# 85
# Adding  300 --> 80
# Node  345  already present
# 36
# Node  303  already present
# 64
# Adding  345 --> 303
# Node  299  already present
# 60
# Node  300  already present
# 125
# Adding  299 --> 300
# Node  26  already present
# 27
# Node  25  already present
# 17
# Adding  26 --> 25
# Node  346  already present
# 23
# Inserted node  130
# Adding  346 --> 130
# Node  271  already present
# 55
# Inserted node  104
# Adding  271 --> 104
# Node  82  already present
# 19
# Inserted node  158
# Adding  82 --> 158
# Node  213  already present
# 71
# Node  345  already present
# 36
# Adding  213 --> 345
# Inserted node  332
# Node  25  already present
# 17
# Adding  332 --> 25
# Node  82  already present
# 19
# Inserted node  169
# Adding  82 --> 169
# Node  329  already present
# 46
# Inserted node  184
# Adding  329 --> 184
# Inserted node  150
# Inserted node  163
# Adding  150 --> 163
# Node  158  already present
# 128
# Node  25  already present
# 17
# Adding  158 --> 25
# Node  170  already present
# 50
# Inserted node  260
# Adding  170 --> 260
# Inserted node  21
# Node  342  already present
# 7
# Adding  21 --> 342
# Node  56  already present
# 73
# Inserted node  221
# Adding  56 --> 221
# Node  8  already present
# 100
# Inserted node  201
# Adding  8 --> 201
# Node  242  already present
# 83
# Node  302  already present
# 42
# Adding  242 --> 302
# Inserted node  110
# Node  264  already present
# 107
# Adding  110 --> 264
# Node  23  already present
# 0
# Inserted node  240
# Adding  23 --> 240
# Node  172  already present
# 87
# Node  313  already present
# 11
# Adding  172 --> 313
# Node  62  already present
# 67
# Node  142  already present
# 70
# Adding  62 --> 142
# Node  56  already present
# 73
# Inserted node  200
# Adding  56 --> 200
# Node  277  already present
# 66
# Node  25  already present
# 17
# Adding  277 --> 25
# Node  239  already present
# 14
# Node  141  already present
# 61
# Adding  239 --> 141
# Node  252  already present
# 114
# Node  103  already present
# 84
# Adding  252 --> 103
# Node  67  already present
# 98
# Node  297  already present
# 40
# Adding  67 --> 297
# Node  21  already present
# 135
# Node  184  already present
# 131
# Adding  21 --> 184
# Node  346  already present
# 23
# Node  330  already present
# 90
# Adding  346 --> 330
# Inserted node  236
# Node  26  already present
# 27
# Adding  236 --> 26
# Node  67  already present
# 98
# Inserted node  265
# Adding  67 --> 265
# Node  119  already present
# 44
# Node  132  already present
# 117
# Adding  119 --> 132
# Node  329  already present
# 46
# Node  72  already present
# 25
# Adding  329 --> 72
# Node  315  already present
# 8
# Node  185  already present
# 57
# Adding  315 --> 185
# Node  332  already present
# 129
# Inserted node  208
# Adding  332 --> 208
# Inserted node  327
# Inserted node  319
# Adding  327 --> 319
# Node  199  already present
# 10
# Node  113  already present
# 18
# Adding  199 --> 113
# Node  239  already present
# 14
# Node  303  already present
# 64
# Adding  239 --> 303
# Node  315  already present
# 8
# Node  313  already present
# 11
# Adding  315 --> 313
# Node  261  already present
# 37
# Inserted node  314
# Adding  261 --> 314
# Inserted node  280
# Node  291  already present
# 51
# Adding  280 --> 291
# Node  342  already present
# 7
# Node  123  already present
# 20
# Adding  342 --> 123
# Inserted node  65
# Node  25  already present
# 17
# Adding  65 --> 25
# Node  213  already present
# 71
# Node  56  already present
# 73
# Adding  213 --> 56
# Node  88  already present
# 123
# Node  80  already present
# 85
# Adding  88 --> 80
# Node  88  already present
# 123
# Node  178  already present
# 72
# Adding  88 --> 178
# Node  140  already present
# 91
# Inserted node  41
# Adding  140 --> 41
# Inserted node  108
# Inserted node  281
# Adding  108 --> 281
# Node  280  already present
# 147
# Node  67  already present
# 98
# Adding  280 --> 67
# Node  261  already present
# 37
# Inserted node  16
# Adding  261 --> 16
# Node  236  already present
# 141
# Node  272  already present
# 82
# Adding  236 --> 272
# Node  278  already present
# 31
# Inserted node  177
# Adding  278 --> 177
# Node  122  already present
# 62
# Node  297  already present
# 40
# Adding  122 --> 297
# Node  199  already present
# 10
# Node  238  already present
# 56
# Adding  199 --> 238
# Inserted node  46
# Node  278  already present
# 31
# Adding  46 --> 278
# Node  252  already present
# 114
# Node  26  already present
# 27
# Adding  252 --> 26
# Node  271  already present
# 55
# Inserted node  63
# Adding  271 --> 63
# Node  9  already present
# 65
# Node  322  already present
# 74
# Adding  9 --> 322
# Node  199  already present
# 10
# Inserted node  222
# Adding  199 --> 222
# Node  172  already present
# 87
# Inserted node  29
# Adding  172 --> 29
# Node  95  already present
# 3
# Node  319  already present
# 145
# Adding  95 --> 319
# Node  252  already present
# 114
# Node  56  already present
# 73
# Adding  252 --> 56
# Node  322  already present
# 74
# Node  67  already present
# 98
# Adding  322 --> 67
# Node  313  already present
# 11
# Node  13  already present
# 45
# Adding  313 --> 13
# Node  98  already present
# 33
# Node  258  already present
# 78
# Adding  98 --> 258
# Node  272  already present
# 82
# Node  56  already present
# 73
# Adding  272 --> 56
# Node  150  already present
# 132
# Inserted node  100
# Adding  150 --> 100
# Node  186  already present
# 122
# Node  239  already present
# 14
# Adding  186 --> 239
# Node  144  already present
# 1
# Inserted node  326
# Adding  144 --> 326
# Node  185  already present
# 57
# Inserted node  79
# Adding  185 --> 79
# Inserted node  83
# Inserted node  237
# Adding  83 --> 237
# Inserted node  53
# Inserted node  92
# Adding  53 --> 92
# Node  62  already present
# 67
# Node  341  already present
# 111
# Adding  62 --> 341
# Inserted node  328
# Inserted node  306
# Adding  328 --> 306
# Node  48  already present
# 75
# Inserted node  57
# Adding  48 --> 57
# Node  300  already present
# 125
# Inserted node  320
# Adding  300 --> 320
# Node  213  already present
# 71
# Node  136  already present
# 102
# Adding  213 --> 136
# Node  82  already present
# 19
# Inserted node  211
# Adding  82 --> 211
# Node  82  already present
# 19
# Node  261  already present
# 37
# Adding  82 --> 261
# Node  136  already present
# 102
# Inserted node  7
# Adding  136 --> 7
# Node  346  already present
# 23
# Inserted node  127
# Adding  346 --> 127
# Node  204  already present
# 88
# Inserted node  94
# Adding  204 --> 94
# Node  346  already present
# 23
# Node  320  already present
# 168
# Adding  346 --> 320
# Node  332  already present
# 129
# Node  48  already present
# 75
# Adding  332 --> 48
# Node  143  already present
# 121
# Node  131  already present
# 32
# Adding  143 --> 131
# Node  56  already present
# 73
# Inserted node  66
# Adding  56 --> 66
# Node  141  already present
# 61
# Node  39  already present
# 43
# Adding  141 --> 39
# Inserted node  304
# Inserted node  30
# Adding  304 --> 30
# Node  302  already present
# 42
# Inserted node  266
# Adding  302 --> 266
# Node  108  already present
# 150
# Inserted node  251
# Adding  108 --> 251
# Node  188  already present
# 105
# Node  224  already present
# 52
# Adding  188 --> 224
# Inserted node  286
# Inserted node  81
# Adding  286 --> 81
# Node  266  already present
# 176
# Node  330  already present
# 90
# Adding  266 --> 330
# Node  304  already present
# 174
# Node  67  already present
# 98
# Adding  304 --> 67
# Node  104  already present
# 127
# Node  212  already present
# 118
# Adding  104 --> 212
# Inserted node  5
# Node  180  already present
# 94
# Adding  5 --> 180
# Node  213  already present
# 71
# Inserted node  96
# Adding  213 --> 96
# Node  56  already present
# 73
# Node  13  already present
# 45
# Adding  56 --> 13
# Node  26  already present
# 27
# Node  323  already present
# 89
# Adding  26 --> 323
# Node  271  already present
# 55
# Node  40  already present
# 13
# Adding  271 --> 40
# Node  322  already present
# 74
# Node  21  already present
# 135
# Adding  322 --> 21
# Inserted node  293
# Node  19  already present
# 77
# Adding  293 --> 19
# Node  223  already present
# 9
# Node  265  already present
# 142
# Adding  223 --> 265
# Node  239  already present
# 14
# Inserted node  344
# Adding  239 --> 344
# Inserted node  64
# Node  150  already present
# 132
# Adding  64 --> 150
# Inserted node  194
# Inserted node  249
# Adding  194 --> 249
# Node  133  already present
# 104
# Node  141  already present
# 61
# Adding  133 --> 141
# Node  304  already present
# 174
# Node  272  already present
# 82
# Adding  304 --> 272
# Node  158  already present
# 128
# Node  60  already present
# 21
# Adding  158 --> 60
# Node  119  already present
# 44
# Inserted node  325
# Adding  119 --> 325
# Node  6  already present
# 2
# Inserted node  89
# Adding  6 --> 89
# Node  252  already present
# 114
# Node  113  already present
# 18
# Adding  252 --> 113
# Node  158  already present
# 128
# Node  142  already present
# 70
# Adding  158 --> 142
# Inserted node  175
# Node  19  already present
# 77
# Adding  175 --> 19
# Node  304  already present
# 174
# Node  200  already present
# 140
# Adding  304 --> 200
# Node  62  already present
# 67
# Node  170  already present
# 50
# Adding  62 --> 170
# Node  9  already present
# 65
# Node  170  already present
# 50
# Adding  9 --> 170
# Node  26  already present
# 27
# Node  142  already present
# 70
# Adding  26 --> 142
# Node  332  already present
# 129
# Node  203  already present
# 79
# Adding  332 --> 203
# Node  204  already present
# 88
# Node  213  already present
# 71
# Adding  204 --> 213
# Node  249  already present
# 186
# Inserted node  101
# Adding  249 --> 101
# Node  226  already present
# 81
# Node  14  already present
# 120
# Adding  226 --> 14
# Node  322  already present
# 74
# Node  345  already present
# 36
# Adding  322 --> 345
# Node  109  already present
# 34
# Node  13  already present
# 45
# Adding  109 --> 13
# Inserted node  339
# Node  260  already present
# 134
# Adding  339 --> 260
# Node  252  already present
# 114
# Node  161  already present
# 95
# Adding  252 --> 161
# Node  304  already present
# 174
# Node  203  already present
# 79
# Adding  304 --> 203
# Node  252  already present
# 114
# Inserted node  334
# Adding  252 --> 334
# Node  28  already present
# 93
# Inserted node  149
# Adding  28 --> 149
# Node  82  already present
# 19
# Inserted node  268
# Adding  82 --> 268
# Node  122  already present
# 62
# Node  261  already present
# 37
# Adding  122 --> 261
# Node  108  already present
# 150
# Inserted node  159
# Adding  108 --> 159
# Inserted node  27
# Inserted node  324
# Adding  27 --> 324
# Inserted node  146
# Node  136  already present
# 102
# Adding  146 --> 136
# Node  62  already present
# 67
# Node  224  already present
# 52
# Adding  62 --> 224
# Node  156  already present
# 109
# Node  295  already present
# 35
# Adding  156 --> 295
# Node  62  already present
# 67
# Node  98  already present
# 33
# Adding  62 --> 98
# Node  346  already present
# 23
# Node  94  already present
# 172
# Adding  346 --> 94
# Node  261  already present
# 37
# Node  113  already present
# 18
# Adding  261 --> 113
# Node  332  already present
# 129
# Node  324  already present
# 197
# Adding  332 --> 324
# Node  200  already present
# 140
# Inserted node  118
# Adding  200 --> 118
# Node  186  already present
# 122
# Node  109  already present
# 34
# Adding  186 --> 109
# Node  302  already present
# 42
# Inserted node  187
# Adding  302 --> 187
# Node  57  already present
# 167
# Node  108  already present
# 150
# Adding  57 --> 108
# Node  3  already present
# 38
# Node  67  already present
# 98
# Adding  3 --> 67
# Node  56  already present
# 73
# Node  132  already present
# 117
# Adding  56 --> 132
# Node  323  already present
# 89
# Node  142  already present
# 70
# Adding  323 --> 142
# Node  312  already present
# 80
# Node  41  already present
# 149
# Adding  312 --> 41
# Node  149  already present
# 193
# Inserted node  162
# Adding  149 --> 162
# Inserted node  307
# Inserted node  71
# Adding  307 --> 71
# Node  231  already present
# 108
# Node  29  already present
# 157
# Adding  231 --> 29
# Node  14  already present
# 120
# Node  310  already present
# 29
# Adding  14 --> 310
# Inserted node  120
# Inserted node  247
# Adding  120 --> 247
# Inserted node  333
# Node  226  already present
# 81
# Adding  333 --> 226
# Node  315  already present
# 8
# Node  224  already present
# 52
# Adding  315 --> 224
# Node  73  already present
# 59
# Node  88  already present
# 123
# Adding  73 --> 88
# Node  326  already present
# 159
# Node  111  already present
# 48
# Adding  326 --> 111
# Inserted node  214
# Node  115  already present
# 119
# Adding  214 --> 115
# Node  122  already present
# 62
# Node  141  already present
# 61
# Adding  122 --> 141
# Node  170  already present
# 50
# Node  185  already present
# 57
# Adding  170 --> 185
# Node  88  already present
# 123
# Node  303  already present
# 64
# Adding  88 --> 303
# Node  199  already present
# 10
# Node  62  already present
# 67
# Adding  199 --> 62
# Node  175  already present
# 189
# Inserted node  227
# Adding  175 --> 227
# Inserted node  20
# Node  226  already present
# 81
# Adding  20 --> 226
# Inserted node  45
# Node  132  already present
# 117
# Adding  45 --> 132
# Node  304  already present
# 174
# Node  158  already present
# 128
# Adding  304 --> 158
# Node  99  already present
# 15
# Node  227  already present
# 208
# Adding  99 --> 227
# Inserted node  331
# Inserted node  50
# Adding  331 --> 50
# Node  272  already present
# 82
# Node  141  already present
# 61
# Adding  272 --> 141
# Node  143  already present
# 121
# Inserted node  321
# Adding  143 --> 321
# Node  98  already present
# 33
# Node  261  already present
# 37
# Adding  98 --> 261
# Node  122  already present
# 62
# Node  123  already present
# 20
# Adding  122 --> 123
# Node  312  already present
# 80
# Node  162  already present
# 201
# Adding  312 --> 162
# Node  213  already present
# 71
# Node  277  already present
# 66
# Adding  213 --> 277
# Node  67  already present
# 98
# Node  196  already present
# 96
# Adding  67 --> 196
# Node  343  already present
# 76
# Node  41  already present
# 149
# Adding  343 --> 41
# Node  9  already present
# 65
# Node  280  already present
# 147
# Adding  9 --> 280
# Node  284  already present
# 69
# Inserted node  309
# Adding  284 --> 309
# Node  65  already present
# 148
# Node  297  already present
# 40
# Adding  65 --> 297
# Node  211  already present
# 169
# Node  172  already present
# 87
# Adding  211 --> 172
# Node  122  already present
# 62
# Node  342  already present
# 7
# Adding  122 --> 342
# Node  303  already present
# 64
# Node  178  already present
# 72
# Adding  303 --> 178
# Node  334  already present
# 192
# Node  66  already present
# 173
# Adding  334 --> 66
# Node  127  already present
# 171
# Node  159  already present
# 195
# Adding  127 --> 159
# Node  254  already present
# 41
# Node  92  already present
# 164
# Adding  254 --> 92
# Node  26  already present
# 27
# Node  113  already present
# 18
# Adding  26 --> 113
# Node  3  already present
# 38
# Node  200  already present
# 140
# Adding  3 --> 200
# Inserted node  58
# Inserted node  269
# Adding  58 --> 269
# Node  199  already present
# 10
# Node  141  already present
# 61
# Adding  199 --> 141
# Node  170  already present
# 50
# Node  277  already present
# 66
# Adding  170 --> 277
# Node  252  already present
# 114
# Node  297  already present
# 40
# Adding  252 --> 297
# Node  109  already present
# 34
# Node  50  already present
# 212
# Adding  109 --> 50
# Node  56  already present
# 73
# Node  30  already present
# 175
# Adding  56 --> 30
# Node  271  already present
# 55
# Node  185  already present
# 57
# Adding  271 --> 185
# Node  48  already present
# 75
# Inserted node  54
# Adding  48 --> 54
# Node  326  already present
# 159
# Node  140  already present
# 91
# Adding  326 --> 140
# Node  103  already present
# 84
# Node  98  already present
# 33
# Adding  103 --> 98
# Node  64  already present
# 184
# Inserted node  171
# Adding  64 --> 171
# Node  122  already present
# 62
# Node  104  already present
# 127
# Adding  122 --> 104
# Node  56  already present
# 73
# Node  136  already present
# 102
# Adding  56 --> 136
# Node  172  already present
# 87
# Node  16  already present
# 152
# Adding  172 --> 16
# Node  94  already present
# 172
# Node  101  already present
# 190
# Adding  94 --> 101
# Node  271  already present
# 55
# Node  48  already present
# 75
# Adding  271 --> 48
# Node  25  already present
# 17
# Node  104  already present
# 127
# Adding  25 --> 104
# Inserted node  308
# Node  136  already present
# 102
# Adding  308 --> 136
# Node  67  already present
# 98
# Node  290  already present
# 6
# Adding  67 --> 290
# Node  265  already present
# 142
# Node  298  already present
# 26
# Adding  265 --> 298
# Node  285  already present
# 47
# Node  315  already present
# 8
# Adding  285 --> 315
# Node  175  already present
# 189
# Node  143  already present
# 121
# Adding  175 --> 143
# Node  57  already present
# 167
# Node  249  already present
# 186
# Adding  57 --> 249
# Node  236  already present
# 141
# Node  303  already present
# 64
# Adding  236 --> 303
# Node  299  already present
# 60
# Node  1  already present
# 110
# Adding  299 --> 1
# Node  20  already present
# 209
# Node  14  already present
# 120
# Adding  20 --> 14
# Node  326  already present
# 159
# Node  162  already present
# 201
# Adding  326 --> 162
# Node  82  already present
# 19
# Node  98  already present
# 33
# Adding  82 --> 98
# Inserted node  338
# Node  29  already present
# 157
# Adding  338 --> 29
# Node  272  already present
# 82
# Node  211  already present
# 169
# Adding  272 --> 211
# Node  280  already present
# 147
# Node  21  already present
# 135
# Adding  280 --> 21
# Node  204  already present
# 88
# Node  5  already present
# 180
# Adding  204 --> 5
# Node  144  already present
# 1
# Inserted node  151
# Adding  144 --> 151
# Node  84  already present
# 54
# Node  25  already present
# 17
# Adding  84 --> 25
# Node  272  already present
# 82
# Node  72  already present
# 25
# Adding  272 --> 72
# Inserted node  197
# Node  251  already present
# 177
# Adding  197 --> 251
# Node  186  already present
# 122
# Node  128  already present
# 97
# Adding  186 --> 128
# Node  119  already present
# 44
# Inserted node  318
# Adding  119 --> 318
# Inserted node  147
# Inserted node  219
# Adding  147 --> 219
# Node  304  already present
# 174
# Node  322  already present
# 74
# Adding  304 --> 322
# Node  94  already present
# 172
# Node  180  already present
# 94
# Adding  94 --> 180
# Node  304  already present
# 174
# Node  7  already present
# 170
# Adding  304 --> 7
# Node  67  already present
# 98
# Node  79  already present
# 160
# Adding  67 --> 79
# Node  26  already present
# 27
# Node  265  already present
# 142
# Adding  26 --> 265
# Node  224  already present
# 52
# Inserted node  148
# Adding  224 --> 148
# Node  109  already present
# 34
# Node  297  already present
# 40
# Adding  109 --> 297
# Node  67  already present
# 98
# Node  21  already present
# 135
# Adding  67 --> 21
# Node  133  already present
# 104
# Inserted node  183
# Adding  133 --> 183
# Node  80  already present
# 85
# Node  266  already present
# 176
# Adding  80 --> 266
# Inserted node  126
# Node  1  already present
# 110
# Adding  126 --> 1
# Node  81  already present
# 179
# Node  269  already present
# 216
# Adding  81 --> 269
# Node  56  already present
# 73
# Node  63  already present
# 155
# Adding  56 --> 63
# Node  26  already present
# 27
# Node  158  already present
# 128
# Adding  26 --> 158
# Node  304  already present
# 174
# Node  84  already present
# 54
# Adding  304 --> 84
# Node  175  already present
# 189
# Node  99  already present
# 15
# Adding  175 --> 99
# Node  277  already present
# 66
# Inserted node  134
# Adding  277 --> 134
# Node  115  already present
# 119
# Node  2  already present
# 103
# Adding  115 --> 2
# Inserted node  230
# Node  41  already present
# 149
# Adding  230 --> 41
# Node  98  already present
# 33
# Node  331  already present
# 211
# Adding  98 --> 331
# Inserted node  273
# Inserted node  4
# Adding  273 --> 4
# Node  24  already present
# 22
# Node  53  already present
# 163
# Adding  24 --> 53
# Node  238  already present
# 56
# Node  342  already present
# 7
# Adding  238 --> 342
# Node  200  already present
# 140
# Node  223  already present
# 9
# Adding  200 --> 223
# Node  169  already present
# 130
# Node  185  already present
# 57
# Adding  169 --> 185
# Node  109  already present
# 34
# Node  331  already present
# 211
# Adding  109 --> 331
# Node  213  already present
# 71
# Node  231  already present
# 108
# Adding  213 --> 231
# Node  176  already present
# 63
# Node  9  already present
# 65
# Adding  176 --> 9
# Node  271  already present
# 55
# Node  313  already present
# 11
# Adding  271 --> 313
# Node  56  already present
# 73
# Inserted node  59
# Adding  56 --> 59
# Node  116  already present
# 92
# Node  326  already present
# 159
# Adding  116 --> 326
# Node  280  already present
# 147
# Node  185  already present
# 57
# Adding  280 --> 185
# Node  304  already present
# 174
# Node  66  already present
# 173
# Adding  304 --> 66
# Node  199  already present
# 10
# Node  291  already present
# 51
# Adding  199 --> 291
# Node  342  already present
# 7
# Node  13  already present
# 45
# Adding  342 --> 13
# Node  315  already present
# 8
# Inserted node  87
# Adding  315 --> 87
# Node  118  already present
# 199
# Node  13  already present
# 45
# Adding  118 --> 13
# Node  186  already present
# 122
# Node  104  already present
# 127
# Adding  186 --> 104
# Node  238  already present
# 56
# Node  59  already present
# 233
# Adding  238 --> 59
# Node  304  already present
# 174
# Node  172  already present
# 87
# Adding  304 --> 172
# Node  258  already present
# 78
# Node  156  already present
# 109
# Adding  258 --> 156
# Node  119  already present
# 44
# Node  39  already present
# 43
# Adding  119 --> 39
# Node  142  already present
# 70
# Node  123  already present
# 20
# Adding  142 --> 123
# Node  323  already present
# 89
# Node  96  already present
# 181
# Adding  323 --> 96
# Node  53  already present
# 163
# Node  299  already present
# 60
# Adding  53 --> 299
# Node  128  already present
# 97
# Node  334  already present
# 192
# Adding  128 --> 334
# Node  322  already present
# 74
# Node  185  already present
# 57
# Adding  322 --> 185
# Node  280  already present
# 147
# Node  40  already present
# 13
# Adding  280 --> 40
# Node  265  already present
# 142
# Node  331  already present
# 211
# Adding  265 --> 331
# Node  82  already present
# 19
# Node  65  already present
# 148
# Adding  82 --> 65
# Node  53  already present
# 163
# Node  330  already present
# 90
# Adding  53 --> 330
# Node  181  already present
# 113
# Node  306  already present
# 166
# Adding  181 --> 306
# Node  186  already present
# 122
# Node  272  already present
# 82
# Adding  186 --> 272
# Node  9  already present
# 65
# Node  142  already present
# 70
# Adding  9 --> 142
# Node  322  already present
# 74
# Node  126  already present
# 228
# Adding  322 --> 126
# Node  8  already present
# 100
# Inserted node  193
# Adding  8 --> 193
# ---------------------------------------------------------------------------
# URLError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\numpy\lib\_datasource.py in _cache(self, path)
#     414             try:
# --> 415                 openedurl = urlopen(path)
#     416                 f = _open(upath, 'wb')
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     524
# --> 525         response = self._open(req, data)
#     526
#
# ~\Anaconda3\lib\urllib\request.py in _open(self, req, data)
#     547         return self._call_chain(self.handle_open, 'unknown',
# --> 548                                 'unknown_open', req)
#     549
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#
# ~\Anaconda3\lib\urllib\request.py in unknown_open(self, req)
#    1386         type = req.type
# -> 1387         raise URLError('unknown url type: %s' % type)
#    1388
#
# URLError: <urlopen error unknown url type: c>
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-95-e1bd9a70728d> in <module>
#       1 valid_g=Graph()
#       2 load_dataset('C://Users//Admin//Downloads//facebook//Self_Datasets//sample_valid.edges',valid_g)
# ----> 3 node_feat=load_and_shape_input("C://Users//Admin//Downloads//facebook//facebook//0.feat")
#       4
#       5
#
# <ipython-input-68-3471329bfa66> in load_and_shape_input(file_name)
#      35
#      36 def load_and_shape_input(file_name):
# ---> 37     a=np.loadtxt(fname=file_name)
#      38     slice_D =[a[i][1:] for i in range(0,num_of_feat)]
#      39     c=np.asarray(slice_D)
#
# ~\Anaconda3\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#     960             fname = os_fspath(fname)
#     961         if _is_string_like(fname):
# --> 962             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     963             fencoding = getattr(fh, 'encoding', 'latin1')
#     964             fh = iter(fh)
#
# ~\Anaconda3\lib\site-packages\numpy\lib\_datasource.py in open(path, mode, destpath, encoding, newline)
#     264
#     265     ds = DataSource(destpath)
# --> 266     return ds.open(path, mode, encoding=encoding, newline=newline)
#     267
#     268
#
# ~\Anaconda3\lib\site-packages\numpy\lib\_datasource.py in open(self, path, mode, encoding, newline)
#     614
#     615         # NOTE: _findfile will fail on a new file opened for writing.
# --> 616         found = self._findfile(path)
#     617         if found:
#     618             _fname, ext = self._splitzipext(found)
#
# ~\Anaconda3\lib\site-packages\numpy\lib\_datasource.py in _findfile(self, path)
#     453             if self.exists(name):
#     454                 if self._isurl(name):
# --> 455                     name = self._cache(name)
#     456                 return name
#     457         return None
#
# ~\Anaconda3\lib\site-packages\numpy\lib\_datasource.py in _cache(self, path)
#     421                     openedurl.close()
#     422             except URLError:
# --> 423                 raise URLError("URL not found: %s" % path)
#     424         else:
#     425             shutil.copyfile(path, upath)
#
# URLError: <urlopen error URL not found: C://Users//Admin//Downloads//facebook//facebook//0.feat>

# %%
x_positive=make_class_arrays(g,1)
x_negative=make_class_arrays(not_g,1)
# Out:
# eachTuple= ('194', '196')
# eachTuple= ('194', '302')
# eachTuple= ('194', '101')
# eachTuple= ('194', '92')
# eachTuple= ('194', '1')
# eachTuple= ('194', '266')
# eachTuple= ('194', '242')
# eachTuple= ('194', '80')
# eachTuple= ('194', '24')
# eachTuple= ('194', '187')
# eachTuple= ('196', '285')
# eachTuple= ('196', '249')
# eachTuple= ('196', '92')
# eachTuple= ('196', '346')
# eachTuple= ('196', '204')
# eachTuple= ('196', '266')
# eachTuple= ('252', '67')
# eachTuple= ('252', '122')
# eachTuple= ('252', '188')
# eachTuple= ('252', '291')
# eachTuple= ('252', '170')
# eachTuple= ('252', '9')
# eachTuple= ('252', '285')
# eachTuple= ('252', '21')
# eachTuple= ('252', '261')
# eachTuple= ('252', '280')
# eachTuple= ('252', '169')
# eachTuple= ('252', '313')
# eachTuple= ('252', '25')
# eachTuple= ('252', '239')
# eachTuple= ('252', '55')
# eachTuple= ('252', '324')
# eachTuple= ('252', '199')
# eachTuple= ('252', '238')
# eachTuple= ('252', '315')
# eachTuple= ('252', '265')
# eachTuple= ('252', '236')
# eachTuple= ('252', '200')
# eachTuple= ('252', '104')
# eachTuple= ('252', '65')
# eachTuple= ('252', '82')
# eachTuple= ('252', '66')
# eachTuple= ('252', '304')
# eachTuple= ('252', '118')
# eachTuple= ('252', '119')
# eachTuple= ('252', '332')
# eachTuple= ('252', '325')
# eachTuple= ('252', '342')
# eachTuple= ('252', '29')
# eachTuple= ('252', '308')
# eachTuple= ('252', '59')
# eachTuple= ('252', '250')
# eachTuple= ('252', '345')
# eachTuple= ('67', '186')
# eachTuple= ('67', '122')
# eachTuple= ('67', '9')
# eachTuple= ('67', '285')
# eachTuple= ('67', '334')
# eachTuple= ('67', '109')
# eachTuple= ('67', '313')
# eachTuple= ('67', '25')
# eachTuple= ('67', '239')
# eachTuple= ('67', '55')
# eachTuple= ('67', '156')
# eachTuple= ('67', '272')
# eachTuple= ('67', '40')
# eachTuple= ('67', '98')
# eachTuple= ('67', '72')
# eachTuple= ('67', '323')
# eachTuple= ('67', '161')
# eachTuple= ('67', '104')
# eachTuple= ('67', '223')
# eachTuple= ('67', '344')
# eachTuple= ('67', '69')
# eachTuple= ('67', '213')
# eachTuple= ('67', '325')
# eachTuple= ('67', '10')
# eachTuple= ('67', '185')
# eachTuple= ('67', '158')
# eachTuple= ('67', '113')
# eachTuple= ('67', '123')
# eachTuple= ('67', '134')
# eachTuple= ('67', '303')
# eachTuple= ('67', '45')
# eachTuple= ('17', '41')
# eachTuple= ('17', '115')
# eachTuple= ('17', '310')
# eachTuple= ('17', '116')
# eachTuple= ('17', '137')
# eachTuple= ('17', '19')
# eachTuple= ('17', '312')
# eachTuple= ('17', '214')
# eachTuple= ('17', '140')
# eachTuple= ('17', '144')
# eachTuple= ('41', '115')
# eachTuple= ('41', '310')
# eachTuple= ('41', '111')
# eachTuple= ('41', '93')
# eachTuple= ('41', '226')
# eachTuple= ('41', '137')
# eachTuple= ('41', '19')
# eachTuple= ('41', '14')
# eachTuple= ('41', '144')
# eachTuple= ('41', '243')
# eachTuple= ('186', '122')
# eachTuple= ('186', '188')
# eachTuple= ('186', '170')
# eachTuple= ('186', '9')
# eachTuple= ('186', '203')
# eachTuple= ('186', '21')
# eachTuple= ('186', '271')
# eachTuple= ('186', '55')
# eachTuple= ('186', '199')
# eachTuple= ('186', '56')
# eachTuple= ('186', '323')
# eachTuple= ('186', '322')
# eachTuple= ('186', '223')
# eachTuple= ('186', '26')
# eachTuple= ('186', '331')
# eachTuple= ('186', '325')
# eachTuple= ('186', '113')
# eachTuple= ('186', '123')
# eachTuple= ('186', '303')
# eachTuple= ('186', '341')
# eachTuple= ('186', '59')
# eachTuple= ('186', '45')
# eachTuple= ('186', '221')
# eachTuple= ('186', '345')
# eachTuple= ('122', '188')
# eachTuple= ('122', '142')
# eachTuple= ('122', '9')
# eachTuple= ('122', '271')
# eachTuple= ('122', '280')
# eachTuple= ('122', '169')
# eachTuple= ('122', '128')
# eachTuple= ('122', '239')
# eachTuple= ('122', '55')
# eachTuple= ('122', '277')
# eachTuple= ('122', '281')
# eachTuple= ('122', '272')
# eachTuple= ('122', '274')
# eachTuple= ('122', '284')
# eachTuple= ('122', '56')
# eachTuple= ('122', '98')
# eachTuple= ('122', '323')
# eachTuple= ('122', '322')
# eachTuple= ('122', '161')
# eachTuple= ('122', '200')
# eachTuple= ('122', '344')
# eachTuple= ('122', '119')
# eachTuple= ('122', '332')
# eachTuple= ('122', '325')
# eachTuple= ('122', '251')
# eachTuple= ('122', '5')
# eachTuple= ('122', '248')
# eachTuple= ('122', '276')
# eachTuple= ('122', '235')
# eachTuple= ('122', '45')
# eachTuple= ('122', '345')
# eachTuple= ('188', '291')
# eachTuple= ('188', '170')
# eachTuple= ('188', '142')
# eachTuple= ('188', '9')
# eachTuple= ('188', '285')
# eachTuple= ('188', '21')
# eachTuple= ('188', '334')
# eachTuple= ('188', '239')
# eachTuple= ('188', '156')
# eachTuple= ('188', '208')
# eachTuple= ('188', '30')
# eachTuple= ('188', '274')
# eachTuple= ('188', '315')
# eachTuple= ('188', '165')
# eachTuple= ('188', '223')
# eachTuple= ('188', '13')
# eachTuple= ('188', '75')
# eachTuple= ('188', '3')
# eachTuple= ('188', '119')
# eachTuple= ('188', '185')
# eachTuple= ('188', '113')
# eachTuple= ('188', '341')
# eachTuple= ('188', '79')
# eachTuple= ('291', '271')
# eachTuple= ('291', '169')
# eachTuple= ('291', '7')
# eachTuple= ('291', '315')
# eachTuple= ('291', '329')
# eachTuple= ('291', '339')
# eachTuple= ('291', '31')
# eachTuple= ('291', '56')
# eachTuple= ('291', '98')
# eachTuple= ('291', '232')
# eachTuple= ('291', '332')
# eachTuple= ('291', '10')
# eachTuple= ('291', '168')
# eachTuple= ('291', '231')
# eachTuple= ('291', '258')
# eachTuple= ('291', '129')
# eachTuple= ('291', '60')
# eachTuple= ('291', '87')
# eachTuple= ('302', '101')
# eachTuple= ('302', '53')
# eachTuple= ('302', '48')
# eachTuple= ('302', '180')
# eachTuple= ('302', '94')
# eachTuple= ('302', '299')
# eachTuple= ('302', '330')
# eachTuple= ('302', '204')
# eachTuple= ('302', '24')
# eachTuple= ('302', '57')
# eachTuple= ('101', '92')
# eachTuple= ('101', '53')
# eachTuple= ('101', '299')
# eachTuple= ('101', '242')
# eachTuple= ('101', '254')
# eachTuple= ('101', '187')
# eachTuple= ('170', '142')
# eachTuple= ('170', '285')
# eachTuple= ('170', '21')
# eachTuple= ('170', '334')
# eachTuple= ('170', '271')
# eachTuple= ('170', '313')
# eachTuple= ('170', '128')
# eachTuple= ('170', '25')
# eachTuple= ('170', '176')
# eachTuple= ('170', '55')
# eachTuple= ('170', '274')
# eachTuple= ('170', '56')
# eachTuple= ('170', '98')
# eachTuple= ('170', '323')
# eachTuple= ('170', '322')
# eachTuple= ('170', '200')
# eachTuple= ('170', '223')
# eachTuple= ('170', '82')
# eachTuple= ('170', '26')
# eachTuple= ('170', '332')
# eachTuple= ('170', '85')
# eachTuple= ('170', '341')
# eachTuple= ('170', '250')
# eachTuple= ('142', '285')
# eachTuple= ('142', '334')
# eachTuple= ('142', '40')
# eachTuple= ('142', '315')
# eachTuple= ('142', '322')
# eachTuple= ('142', '161')
# eachTuple= ('142', '200')
# eachTuple= ('142', '104')
# eachTuple= ('142', '66')
# eachTuple= ('142', '10')
# eachTuple= ('142', '134')
# eachTuple= ('142', '45')
# eachTuple= ('142', '345')
# eachTuple= ('9', '203')
# eachTuple= ('9', '128')
# eachTuple= ('9', '141')
# eachTuple= ('9', '25')
# eachTuple= ('9', '148')
# eachTuple= ('9', '156')
# eachTuple= ('9', '199')
# eachTuple= ('9', '133')
# eachTuple= ('9', '315')
# eachTuple= ('9', '224')
# eachTuple= ('9', '329')
# eachTuple= ('9', '72')
# eachTuple= ('9', '323')
# eachTuple= ('9', '161')
# eachTuple= ('9', '200')
# eachTuple= ('9', '232')
# eachTuple= ('9', '75')
# eachTuple= ('9', '3')
# eachTuple= ('9', '66')
# eachTuple= ('9', '69')
# eachTuple= ('9', '185')
# eachTuple= ('9', '342')
# eachTuple= ('9', '134')
# eachTuple= ('9', '85')
# eachTuple= ('9', '276')
# eachTuple= ('9', '231')
# eachTuple= ('9', '297')
# eachTuple= ('9', '295')
# eachTuple= ('9', '79')
# eachTuple= ('203', '285')
# eachTuple= ('203', '21')
# eachTuple= ('203', '334')
# eachTuple= ('203', '261')
# eachTuple= ('203', '109')
# eachTuple= ('203', '313')
# eachTuple= ('203', '128')
# eachTuple= ('203', '25')
# eachTuple= ('203', '239')
# eachTuple= ('203', '277')
# eachTuple= ('203', '324')
# eachTuple= ('203', '199')
# eachTuple= ('203', '272')
# eachTuple= ('203', '238')
# eachTuple= ('203', '40')
# eachTuple= ('203', '265')
# eachTuple= ('203', '48')
# eachTuple= ('203', '98')
# eachTuple= ('203', '200')
# eachTuple= ('203', '104')
# eachTuple= ('203', '65')
# eachTuple= ('203', '82')
# eachTuple= ('203', '26')
# eachTuple= ('203', '118')
# eachTuple= ('203', '325')
# eachTuple= ('203', '113')
# eachTuple= ('203', '342')
# eachTuple= ('203', '29')
# eachTuple= ('203', '341')
# eachTuple= ('203', '268')
# eachTuple= ('203', '59')
# eachTuple= ('285', '261')
# eachTuple= ('285', '109')
# eachTuple= ('285', '313')
# eachTuple= ('285', '117')
# eachTuple= ('285', '277')
# eachTuple= ('285', '211')
# eachTuple= ('285', '208')
# eachTuple= ('285', '272')
# eachTuple= ('285', '323')
# eachTuple= ('285', '200')
# eachTuple= ('285', '232')
# eachTuple= ('285', '304')
# eachTuple= ('285', '213')
# eachTuple= ('285', '332')
# eachTuple= ('285', '10')
# eachTuple= ('285', '185')
# eachTuple= ('285', '113')
# eachTuple= ('285', '221')
# eachTuple= ('285', '60')
# eachTuple= ('285', '246')
# eachTuple= ('21', '197')
# eachTuple= ('21', '334')
# eachTuple= ('21', '136')
# eachTuple= ('21', '239')
# eachTuple= ('21', '277')
# eachTuple= ('21', '281')
# eachTuple= ('21', '274')
# eachTuple= ('21', '40')
# eachTuple= ('21', '56')
# eachTuple= ('21', '98')
# eachTuple= ('21', '165')
# eachTuple= ('21', '161')
# eachTuple= ('21', '200')
# eachTuple= ('21', '232')
# eachTuple= ('21', '13')
# eachTuple= ('21', '88')
# eachTuple= ('21', '26')
# eachTuple= ('21', '304')
# eachTuple= ('21', '123')
# eachTuple= ('21', '134')
# eachTuple= ('21', '121')
# eachTuple= ('21', '159')
# eachTuple= ('21', '39')
# eachTuple= ('21', '235')
# eachTuple= ('21', '308')
# eachTuple= ('21', '108')
# eachTuple= ('21', '297')
# eachTuple= ('21', '212')
# eachTuple= ('21', '105')
# eachTuple= ('21', '345')
# eachTuple= ('197', '281')
# eachTuple= ('197', '329')
# eachTuple= ('197', '135')
# eachTuple= ('197', '309')
# eachTuple= ('197', '36')
# eachTuple= ('197', '159')
# eachTuple= ('197', '127')
# eachTuple= ('197', '184')
# eachTuple= ('334', '229')
# eachTuple= ('334', '339')
# eachTuple= ('334', '26')
# eachTuple= ('334', '123')
# eachTuple= ('334', '134')
# eachTuple= ('334', '308')
# eachTuple= ('249', '92')
# eachTuple= ('249', '53')
# eachTuple= ('249', '315')
# eachTuple= ('249', '180')
# eachTuple= ('249', '330')
# eachTuple= ('249', '204')
# eachTuple= ('249', '266')
# eachTuple= ('249', '242')
# eachTuple= ('249', '80')
# eachTuple= ('249', '187')
# eachTuple= ('271', '261')
# eachTuple= ('271', '109')
# eachTuple= ('271', '280')
# eachTuple= ('271', '128')
# eachTuple= ('271', '141')
# eachTuple= ('271', '148')
# eachTuple= ('271', '176')
# eachTuple= ('271', '277')
# eachTuple= ('271', '30')
# eachTuple= ('271', '133')
# eachTuple= ('271', '224')
# eachTuple= ('271', '265')
# eachTuple= ('271', '98')
# eachTuple= ('271', '72')
# eachTuple= ('271', '322')
# eachTuple= ('271', '161')
# eachTuple= ('271', '200')
# eachTuple= ('271', '223')
# eachTuple= ('271', '82')
# eachTuple= ('271', '119')
# eachTuple= ('271', '325')
# eachTuple= ('271', '172')
# eachTuple= ('271', '85')
# eachTuple= ('271', '276')
# eachTuple= ('271', '268')
# eachTuple= ('271', '297')
# eachTuple= ('271', '79')
# eachTuple= ('261', '148')
# eachTuple= ('261', '55')
# eachTuple= ('261', '211')
# eachTuple= ('261', '238')
# eachTuple= ('261', '224')
# eachTuple= ('261', '62')
# eachTuple= ('261', '223')
# eachTuple= ('261', '65')
# eachTuple= ('261', '118')
# eachTuple= ('261', '325')
# eachTuple= ('261', '342')
# eachTuple= ('261', '268')
# eachTuple= ('261', '63')
# eachTuple= ('136', '125')
# eachTuple= ('136', '324')
# eachTuple= ('136', '339')
# eachTuple= ('136', '322')
# eachTuple= ('136', '304')
# eachTuple= ('136', '87')
# eachTuple= ('125', '169')
# eachTuple= ('125', '119')
# eachTuple= ('109', '169')
# eachTuple= ('109', '148')
# eachTuple= ('109', '56')
# eachTuple= ('109', '104')
# eachTuple= ('109', '119')
# eachTuple= ('109', '332')
# eachTuple= ('109', '325')
# eachTuple= ('109', '314')
# eachTuple= ('280', '169')
# eachTuple= ('280', '141')
# eachTuple= ('280', '25')
# eachTuple= ('280', '277')
# eachTuple= ('280', '272')
# eachTuple= ('280', '315')
# eachTuple= ('280', '31')
# eachTuple= ('280', '98')
# eachTuple= ('280', '323')
# eachTuple= ('280', '200')
# eachTuple= ('280', '3')
# eachTuple= ('280', '26')
# eachTuple= ('280', '304')
# eachTuple= ('280', '119')
# eachTuple= ('280', '332')
# eachTuple= ('280', '105')
# eachTuple= ('169', '128')
# eachTuple= ('169', '25')
# eachTuple= ('169', '239')
# eachTuple= ('169', '277')
# eachTuple= ('169', '40')
# eachTuple= ('169', '56')
# eachTuple= ('169', '236')
# eachTuple= ('169', '165')
# eachTuple= ('169', '113')
# eachTuple= ('169', '106')
# eachTuple= ('169', '121')
# eachTuple= ('169', '248')
# eachTuple= ('169', '257')
# eachTuple= ('169', '103')
# eachTuple= ('169', '318')
# eachTuple= ('313', '128')
# eachTuple= ('313', '239')
# eachTuple= ('313', '211')
# eachTuple= ('313', '339')
# eachTuple= ('313', '56')
# eachTuple= ('313', '82')
# eachTuple= ('313', '118')
# eachTuple= ('313', '325')
# eachTuple= ('313', '314')
# eachTuple= ('313', '146')
# eachTuple= ('313', '63')
# eachTuple= ('128', '211')
# eachTuple= ('128', '315')
# eachTuple= ('128', '56')
# eachTuple= ('128', '98')
# eachTuple= ('128', '104')
# eachTuple= ('128', '223')
# eachTuple= ('128', '26')
# eachTuple= ('128', '119')
# eachTuple= ('128', '172')
# eachTuple= ('141', '25')
# eachTuple= ('141', '38')
# eachTuple= ('141', '40')
# eachTuple= ('141', '236')
# eachTuple= ('141', '72')
# eachTuple= ('141', '304')
# eachTuple= ('141', '276')
# eachTuple= ('141', '257')
# eachTuple= ('141', '258')
# eachTuple= ('25', '239')
# eachTuple= ('25', '199')
# eachTuple= ('25', '272')
# eachTuple= ('25', '224')
# eachTuple= ('25', '56')
# eachTuple= ('25', '236')
# eachTuple= ('25', '323')
# eachTuple= ('25', '336')
# eachTuple= ('25', '200')
# eachTuple= ('25', '94')
# eachTuple= ('25', '88')
# eachTuple= ('25', '119')
# eachTuple= ('25', '331')
# eachTuple= ('25', '325')
# eachTuple= ('25', '51')
# eachTuple= ('25', '283')
# eachTuple= ('25', '257')
# eachTuple= ('25', '103')
# eachTuple= ('25', '221')
# eachTuple= ('25', '79')
# eachTuple= ('25', '246')
# eachTuple= ('25', '76')
# eachTuple= ('25', '73')
# eachTuple= ('343', '115')
# eachTuple= ('343', '2')
# eachTuple= ('343', '111')
# eachTuple= ('343', '226')
# eachTuple= ('343', '14')
# eachTuple= ('343', '312')
# eachTuple= ('343', '214')
# eachTuple= ('343', '144')
# eachTuple= ('343', '333')
# eachTuple= ('343', '162')
# eachTuple= ('115', '28')
# eachTuple= ('115', '116')
# eachTuple= ('115', '137')
# eachTuple= ('115', '20')
# eachTuple= ('115', '140')
# eachTuple= ('115', '144')
# eachTuple= ('115', '262')
# eachTuple= ('115', '192')
# eachTuple= ('148', '229')
# eachTuple= ('148', '176')
# eachTuple= ('148', '339')
# eachTuple= ('148', '98')
# eachTuple= ('148', '82')
# eachTuple= ('148', '185')
# eachTuple= ('148', '113')
# eachTuple= ('148', '146')
# eachTuple= ('229', '119')
# eachTuple= ('229', '190')
# eachTuple= ('7', '347')
# eachTuple= ('7', '38')
# eachTuple= ('7', '315')
# eachTuple= ('7', '31')
# eachTuple= ('7', '65')
# eachTuple= ('7', '22')
# eachTuple= ('7', '103')
# eachTuple= ('7', '340')
# eachTuple= ('7', '308')
# eachTuple= ('7', '129')
# eachTuple= ('7', '246')
# eachTuple= ('347', '339')
# eachTuple= ('347', '168')
# eachTuple= ('347', '129')
# eachTuple= ('176', '239')
# eachTuple= ('176', '26')
# eachTuple= ('176', '85')
# eachTuple= ('176', '290')
# eachTuple= ('239', '55')
# eachTuple= ('239', '277')
# eachTuple= ('239', '211')
# eachTuple= ('239', '272')
# eachTuple= ('239', '238')
# eachTuple= ('239', '62')
# eachTuple= ('239', '72')
# eachTuple= ('239', '323')
# eachTuple= ('239', '232')
# eachTuple= ('239', '13')
# eachTuple= ('239', '26')
# eachTuple= ('239', '118')
# eachTuple= ('239', '213')
# eachTuple= ('239', '119')
# eachTuple= ('239', '325')
# eachTuple= ('239', '123')
# eachTuple= ('239', '338')
# eachTuple= ('239', '60')
# eachTuple= ('239', '212')
# eachTuple= ('306', '4')
# eachTuple= ('306', '275')
# eachTuple= ('306', '218')
# eachTuple= ('306', '195')
# eachTuple= ('306', '273')
# eachTuple= ('4', '218')
# eachTuple= ('4', '181')
# eachTuple= ('117', '38')
# eachTuple= ('117', '77')
# eachTuple= ('117', '231')
# eachTuple= ('38', '339')
# eachTuple= ('38', '322')
# eachTuple= ('38', '332')
# eachTuple= ('55', '277')
# eachTuple= ('55', '104')
# eachTuple= ('55', '26')
# eachTuple= ('55', '185')
# eachTuple= ('55', '123')
# eachTuple= ('277', '324')
# eachTuple= ('277', '294')
# eachTuple= ('277', '208')
# eachTuple= ('277', '272')
# eachTuple= ('277', '40')
# eachTuple= ('277', '339')
# eachTuple= ('277', '56')
# eachTuple= ('277', '98')
# eachTuple= ('277', '323')
# eachTuple= ('277', '200')
# eachTuple= ('277', '104')
# eachTuple= ('277', '13')
# eachTuple= ('277', '325')
# eachTuple= ('277', '10')
# eachTuple= ('277', '120')
# eachTuple= ('277', '50')
# eachTuple= ('277', '172')
# eachTuple= ('277', '248')
# eachTuple= ('277', '159')
# eachTuple= ('277', '22')
# eachTuple= ('277', '308')
# eachTuple= ('277', '311')
# eachTuple= ('277', '105')
# eachTuple= ('324', '329')
# eachTuple= ('324', '200')
# eachTuple= ('324', '118')
# eachTuple= ('324', '213')
# eachTuple= ('324', '119')
# eachTuple= ('324', '331')
# eachTuple= ('324', '22')
# eachTuple= ('324', '340')
# eachTuple= ('156', '272')
# eachTuple= ('281', '272')
# eachTuple= ('281', '135')
# eachTuple= ('281', '284')
# eachTuple= ('281', '309')
# eachTuple= ('281', '139')
# eachTuple= ('281', '320')
# eachTuple= ('281', '159')
# eachTuple= ('281', '127')
# eachTuple= ('281', '184')
# eachTuple= ('92', '346')
# eachTuple= ('92', '299')
# eachTuple= ('92', '330')
# eachTuple= ('92', '266')
# eachTuple= ('92', '242')
# eachTuple= ('92', '80')
# eachTuple= ('92', '57')
# eachTuple= ('211', '199')
# eachTuple= ('211', '238')
# eachTuple= ('211', '315')
# eachTuple= ('211', '265')
# eachTuple= ('211', '98')
# eachTuple= ('211', '223')
# eachTuple= ('211', '13')
# eachTuple= ('211', '331')
# eachTuple= ('211', '342')
# eachTuple= ('211', '268')
# eachTuple= ('211', '59')
# eachTuple= ('95', '147')
# eachTuple= ('95', '89')
# eachTuple= ('95', '327')
# eachTuple= ('147', '89')
# eachTuple= ('147', '6')
# eachTuple= ('199', '40')
# eachTuple= ('199', '315')
# eachTuple= ('199', '265')
# eachTuple= ('199', '56')
# eachTuple= ('199', '72')
# eachTuple= ('199', '322')
# eachTuple= ('199', '161')
# eachTuple= ('199', '200')
# eachTuple= ('199', '232')
# eachTuple= ('199', '223')
# eachTuple= ('199', '82')
# eachTuple= ('199', '26')
# eachTuple= ('199', '119')
# eachTuple= ('199', '325')
# eachTuple= ('199', '134')
# eachTuple= ('199', '172')
# eachTuple= ('199', '231')
# eachTuple= ('77', '294')
# eachTuple= ('77', '40')
# eachTuple= ('77', '332')
# eachTuple= ('77', '231')
# eachTuple= ('2', '326')
# eachTuple= ('272', '40')
# eachTuple= ('272', '329')
# eachTuple= ('272', '98')
# eachTuple= ('272', '75')
# eachTuple= ('272', '320')
# eachTuple= ('272', '159')
# eachTuple= ('272', '257')
# eachTuple= ('272', '184')
# eachTuple= ('238', '98')
# eachTuple= ('238', '13')
# eachTuple= ('238', '82')
# eachTuple= ('238', '118')
# eachTuple= ('238', '325')
# eachTuple= ('238', '222')
# eachTuple= ('238', '106')
# eachTuple= ('30', '329')
# eachTuple= ('30', '48')
# eachTuple= ('30', '322')
# eachTuple= ('30', '213')
# eachTuple= ('30', '178')
# eachTuple= ('30', '73')
# eachTuple= ('274', '40')
# eachTuple= ('274', '185')
# eachTuple= ('274', '85')
# eachTuple= ('274', '341')
# eachTuple= ('40', '315')
# eachTuple= ('40', '265')
# eachTuple= ('40', '322')
# eachTuple= ('40', '200')
# eachTuple= ('40', '232')
# eachTuple= ('40', '213')
# eachTuple= ('40', '332')
# eachTuple= ('40', '325')
# eachTuple= ('40', '113')
# eachTuple= ('40', '307')
# eachTuple= ('40', '258')
# eachTuple= ('40', '298')
# eachTuple= ('53', '48')
# eachTuple= ('53', '54')
# eachTuple= ('53', '346')
# eachTuple= ('53', '88')
# eachTuple= ('53', '204')
# eachTuple= ('53', '266')
# eachTuple= ('53', '260')
# eachTuple= ('53', '332')
# eachTuple= ('53', '317')
# eachTuple= ('53', '242')
# eachTuple= ('53', '248')
# eachTuple= ('53', '130')
# eachTuple= ('91', '201')
# eachTuple= ('91', '8')
# eachTuple= ('91', '245')
# eachTuple= ('91', '193')
# eachTuple= ('91', '264')
# eachTuple= ('201', '259')
# eachTuple= ('8', '110')
# eachTuple= ('133', '315')
# eachTuple= ('133', '236')
# eachTuple= ('133', '322')
# eachTuple= ('133', '232')
# eachTuple= ('133', '1')
# eachTuple= ('133', '26')
# eachTuple= ('133', '96')
# eachTuple= ('315', '329')
# eachTuple= ('315', '339')
# eachTuple= ('315', '236')
# eachTuple= ('315', '1')
# eachTuple= ('315', '26')
# eachTuple= ('315', '304')
# eachTuple= ('315', '121')
# eachTuple= ('315', '5')
# eachTuple= ('315', '80')
# eachTuple= ('315', '257')
# eachTuple= ('315', '132')
# eachTuple= ('315', '246')
# eachTuple= ('227', '143')
# eachTuple= ('227', '23')
# eachTuple= ('227', '102')
# eachTuple= ('227', '19')
# eachTuple= ('227', '177')
# eachTuple= ('227', '225')
# eachTuple= ('227', '296')
# eachTuple= ('227', '86')
# eachTuple= ('227', '131')
# eachTuple= ('143', '35')
# eachTuple= ('28', '310')
# eachTuple= ('28', '226')
# eachTuple= ('28', '140')
# eachTuple= ('28', '326')
# eachTuple= ('310', '111')
# eachTuple= ('310', '167')
# eachTuple= ('310', '337')
# eachTuple= ('84', '224')
# eachTuple= ('84', '265')
# eachTuple= ('84', '237')
# eachTuple= ('84', '236')
# eachTuple= ('84', '82')
# eachTuple= ('84', '51')
# eachTuple= ('84', '83')
# eachTuple= ('224', '236')
# eachTuple= ('224', '322')
# eachTuple= ('224', '200')
# eachTuple= ('224', '232')
# eachTuple= ('224', '26')
# eachTuple= ('224', '213')
# eachTuple= ('224', '332')
# eachTuple= ('329', '322')
# eachTuple= ('329', '204')
# eachTuple= ('329', '332')
# eachTuple= ('329', '106')
# eachTuple= ('329', '172')
# eachTuple= ('329', '231')
# eachTuple= ('329', '269')
# eachTuple= ('339', '31')
# eachTuple= ('339', '158')
# eachTuple= ('339', '103')
# eachTuple= ('339', '129')
# eachTuple= ('339', '87')
# eachTuple= ('339', '246')
# eachTuple= ('31', '200')
# eachTuple= ('31', '304')
# eachTuple= ('31', '168')
# eachTuple= ('31', '51')
# eachTuple= ('31', '338')
# eachTuple= ('31', '308')
# eachTuple= ('31', '129')
# eachTuple= ('265', '98')
# eachTuple= ('265', '118')
# eachTuple= ('265', '325')
# eachTuple= ('265', '342')
# eachTuple= ('265', '172')
# eachTuple= ('265', '248')
# eachTuple= ('265', '311')
# eachTuple= ('135', '284')
# eachTuple= ('135', '36')
# eachTuple= ('135', '251')
# eachTuple= ('135', '320')
# eachTuple= ('135', '127')
# eachTuple= ('135', '184')
# eachTuple= ('284', '320')
# eachTuple= ('284', '159')
# eachTuple= ('62', '56')
# eachTuple= ('62', '236')
# eachTuple= ('62', '161')
# eachTuple= ('62', '200')
# eachTuple= ('62', '96')
# eachTuple= ('62', '276')
# eachTuple= ('62', '318')
# eachTuple= ('56', '98')
# eachTuple= ('56', '72')
# eachTuple= ('56', '323')
# eachTuple= ('56', '322')
# eachTuple= ('56', '161')
# eachTuple= ('56', '207')
# eachTuple= ('56', '104')
# eachTuple= ('56', '223')
# eachTuple= ('56', '75')
# eachTuple= ('56', '88')
# eachTuple= ('56', '118')
# eachTuple= ('56', '331')
# eachTuple= ('56', '325')
# eachTuple= ('56', '222')
# eachTuple= ('56', '185')
# eachTuple= ('56', '113')
# eachTuple= ('56', '342')
# eachTuple= ('56', '134')
# eachTuple= ('56', '172')
# eachTuple= ('56', '303')
# eachTuple= ('56', '276')
# eachTuple= ('56', '60')
# eachTuple= ('56', '298')
# eachTuple= ('56', '290')
# eachTuple= ('48', '180')
# eachTuple= ('48', '88')
# eachTuple= ('48', '299')
# eachTuple= ('48', '320')
# eachTuple= ('48', '130')
# eachTuple= ('111', '93')
# eachTuple= ('111', '137')
# eachTuple= ('111', '44')
# eachTuple= ('111', '214')
# eachTuple= ('111', '20')
# eachTuple= ('111', '279')
# eachTuple= ('93', '167')
# eachTuple= ('93', '337')
# eachTuple= ('23', '237')
# eachTuple= ('23', '116')
# eachTuple= ('23', '230')
# eachTuple= ('23', '51')
# eachTuple= ('23', '83')
# eachTuple= ('23', '124')
# eachTuple= ('23', '99')
# eachTuple= ('23', '190')
# eachTuple= ('236', '322')
# eachTuple= ('236', '200')
# eachTuple= ('236', '13')
# eachTuple= ('236', '88')
# eachTuple= ('236', '69')
# eachTuple= ('236', '213')
# eachTuple= ('236', '276')
# eachTuple= ('236', '257')
# eachTuple= ('236', '318')
# eachTuple= ('236', '314')
# eachTuple= ('236', '105')
# eachTuple= ('98', '104')
# eachTuple= ('98', '223')
# eachTuple= ('98', '26')
# eachTuple= ('98', '118')
# eachTuple= ('98', '325')
# eachTuple= ('98', '113')
# eachTuple= ('98', '342')
# eachTuple= ('98', '172')
# eachTuple= ('98', '59')
# eachTuple= ('165', '72')
# eachTuple= ('165', '200')
# eachTuple= ('165', '113')
# eachTuple= ('165', '342')
# eachTuple= ('165', '121')
# eachTuple= ('72', '200')
# eachTuple= ('72', '3')
# eachTuple= ('72', '26')
# eachTuple= ('72', '113')
# eachTuple= ('72', '172')
# eachTuple= ('72', '212')
# eachTuple= ('116', '226')
# eachTuple= ('116', '14')
# eachTuple= ('116', '214')
# eachTuple= ('116', '162')
# eachTuple= ('323', '200')
# eachTuple= ('323', '75')
# eachTuple= ('323', '248')
# eachTuple= ('323', '341')
# eachTuple= ('323', '308')
# eachTuple= ('323', '297')
# eachTuple= ('54', '119')
# eachTuple= ('54', '27')
# eachTuple= ('346', '180')
# eachTuple= ('346', '204')
# eachTuple= ('346', '266')
# eachTuple= ('346', '242')
# eachTuple= ('346', '300')
# eachTuple= ('346', '184')
# eachTuple= ('346', '254')
# eachTuple= ('346', '187')
# eachTuple= ('180', '204')
# eachTuple= ('180', '266')
# eachTuple= ('180', '242')
# eachTuple= ('180', '80')
# eachTuple= ('180', '24')
# eachTuple= ('180', '187')
# eachTuple= ('322', '161')
# eachTuple= ('322', '200')
# eachTuple= ('322', '232')
# eachTuple= ('322', '1')
# eachTuple= ('322', '75')
# eachTuple= ('322', '88')
# eachTuple= ('322', '213')
# eachTuple= ('322', '85')
# eachTuple= ('322', '303')
# eachTuple= ('322', '276')
# eachTuple= ('322', '308')
# eachTuple= ('322', '250')
# eachTuple= ('322', '45')
# eachTuple= ('322', '297')
# eachTuple= ('322', '130')
# eachTuple= ('322', '87')
# eachTuple= ('161', '118')
# eachTuple= ('161', '39')
# eachTuple= ('161', '308')
# eachTuple= ('161', '314')
# eachTuple= ('161', '87')
# eachTuple= ('336', '88')
# eachTuple= ('200', '104')
# eachTuple= ('200', '232')
# eachTuple= ('200', '75')
# eachTuple= ('200', '26')
# eachTuple= ('200', '119')
# eachTuple= ('200', '325')
# eachTuple= ('200', '185')
# eachTuple= ('200', '113')
# eachTuple= ('200', '248')
# eachTuple= ('200', '276')
# eachTuple= ('200', '39')
# eachTuple= ('200', '297')
# eachTuple= ('200', '79')
# eachTuple= ('104', '26')
# eachTuple= ('104', '332')
# eachTuple= ('104', '325')
# eachTuple= ('104', '123')
# eachTuple= ('104', '45')
# eachTuple= ('104', '295')
# eachTuple= ('232', '26')
# eachTuple= ('232', '172')
# eachTuple= ('1', '88')
# eachTuple= ('94', '299')
# eachTuple= ('94', '242')
# eachTuple= ('94', '320')
# eachTuple= ('94', '80')
# eachTuple= ('94', '300')
# eachTuple= ('94', '254')
# eachTuple= ('94', '24')
# eachTuple= ('94', '187')
# eachTuple= ('223', '13')
# eachTuple= ('223', '26')
# eachTuple= ('223', '325')
# eachTuple= ('223', '342')
# eachTuple= ('223', '246')
# eachTuple= ('65', '13')
# eachTuple= ('65', '118')
# eachTuple= ('13', '172')
# eachTuple= ('13', '59')
# eachTuple= ('75', '304')
# eachTuple= ('75', '258')
# eachTuple= ('88', '164')
# eachTuple= ('3', '26')
# eachTuple= ('3', '283')
# eachTuple= ('3', '85')
# eachTuple= ('3', '228')
# eachTuple= ('344', '257')
# eachTuple= ('344', '212')
# eachTuple= ('299', '330')
# eachTuple= ('299', '254')
# eachTuple= ('299', '24')
# eachTuple= ('299', '187')
# eachTuple= ('330', '242')
# eachTuple= ('330', '80')
# eachTuple= ('330', '254')
# eachTuple= ('204', '242')
# eachTuple= ('204', '254')
# eachTuple= ('204', '130')
# eachTuple= ('204', '57')
# eachTuple= ('82', '119')
# eachTuple= ('82', '331')
# eachTuple= ('82', '325')
# eachTuple= ('82', '222')
# eachTuple= ('82', '172')
# eachTuple= ('82', '29')
# eachTuple= ('82', '231')
# eachTuple= ('82', '16')
# eachTuple= ('82', '59')
# eachTuple= ('26', '66')
# eachTuple= ('26', '304')
# eachTuple= ('26', '332')
# eachTuple= ('26', '325')
# eachTuple= ('26', '185')
# eachTuple= ('26', '134')
# eachTuple= ('26', '257')
# eachTuple= ('26', '308')
# eachTuple= ('26', '295')
# eachTuple= ('26', '298')
# eachTuple= ('66', '134')
# eachTuple= ('66', '308')
# eachTuple= ('64', '217')
# eachTuple= ('64', '119')
# eachTuple= ('64', '100')
# eachTuple= ('217', '119')
# eachTuple= ('217', '189')
# eachTuple= ('217', '100')
# eachTuple= ('266', '24')
# eachTuple= ('260', '160')
# eachTuple= ('260', '126')
# eachTuple= ('304', '69')
# eachTuple= ('304', '332')
# eachTuple= ('304', '325')
# eachTuple= ('304', '168')
# eachTuple= ('304', '257')
# eachTuple= ('304', '341')
# eachTuple= ('304', '212')
# eachTuple= ('304', '246')
# eachTuple= ('69', '105')
# eachTuple= ('118', '331')
# eachTuple= ('118', '325')
# eachTuple= ('118', '222')
# eachTuple= ('118', '342')
# eachTuple= ('118', '283')
# eachTuple= ('118', '172')
# eachTuple= ('118', '29')
# eachTuple= ('118', '268')
# eachTuple= ('118', '59')
# eachTuple= ('213', '332')
# eachTuple= ('213', '5')
# eachTuple= ('213', '303')
# eachTuple= ('213', '80')
# eachTuple= ('213', '340')
# eachTuple= ('213', '130')
# eachTuple= ('213', '57')
# eachTuple= ('213', '87')
# eachTuple= ('213', '246')
# eachTuple= ('119', '171')
# eachTuple= ('119', '189')
# eachTuple= ('119', '342')
# eachTuple= ('119', '50')
# eachTuple= ('119', '27')
# eachTuple= ('119', '297')
# eachTuple= ('119', '105')
# eachTuple= ('119', '146')
# eachTuple= ('119', '150')
# eachTuple= ('119', '269')
# eachTuple= ('171', '107')
# eachTuple= ('332', '10')
# eachTuple= ('332', '106')
# eachTuple= ('332', '16')
# eachTuple= ('189', '100')
# eachTuple= ('189', '150')
# eachTuple= ('331', '73')
# eachTuple= ('230', '214')
# eachTuple= ('230', '307')
# eachTuple= ('230', '253')
# eachTuple= ('325', '172')
# eachTuple= ('325', '268')
# eachTuple= ('325', '59')
# eachTuple= ('325', '311')
# eachTuple= ('309', '36')
# eachTuple= ('309', '251')
# eachTuple= ('309', '320')
# eachTuple= ('137', '32')
# eachTuple= ('137', '312')
# eachTuple= ('137', '214')
# eachTuple= ('137', '167')
# eachTuple= ('137', '140')
# eachTuple= ('137', '326')
# eachTuple= ('137', '337')
# eachTuple= ('137', '243')
# eachTuple= ('32', '167')
# eachTuple= ('32', '337')
# eachTuple= ('317', '146')
# eachTuple= ('36', '251')
# eachTuple= ('36', '320')
# eachTuple= ('36', '108')
# eachTuple= ('185', '22')
# eachTuple= ('185', '103')
# eachTuple= ('185', '290')
# eachTuple= ('168', '22')
# eachTuple= ('242', '158')
# eachTuple= ('242', '80')
# eachTuple= ('242', '254')
# eachTuple= ('242', '57')
# eachTuple= ('158', '113')
# eachTuple= ('158', '5')
# eachTuple= ('158', '22')
# eachTuple= ('158', '132')
# eachTuple= ('113', '342')
# eachTuple= ('113', '50')
# eachTuple= ('113', '132')
# eachTuple= ('51', '83')
# eachTuple= ('342', '59')
# eachTuple= ('106', '29')
# eachTuple= ('283', '228')
# eachTuple= ('123', '318')
# eachTuple= ('233', '256')
# eachTuple= ('134', '248')
# eachTuple= ('134', '132')
# eachTuple= ('251', '139')
# eachTuple= ('50', '314')
# eachTuple= ('174', '293')
# eachTuple= ('174', '19')
# eachTuple= ('174', '112')
# eachTuple= ('19', '289')
# eachTuple= ('19', '312')
# eachTuple= ('19', '214')
# eachTuple= ('19', '112')
# eachTuple= ('19', '89')
# eachTuple= ('19', '319')
# eachTuple= ('19', '138')
# eachTuple= ('175', '321')
# eachTuple= ('175', '177')
# eachTuple= ('175', '46')
# eachTuple= ('175', '263')
# eachTuple= ('175', '68')
# eachTuple= ('175', '296')
# eachTuple= ('175', '86')
# eachTuple= ('177', '46')
# eachTuple= ('177', '68')
# eachTuple= ('177', '225')
# eachTuple= ('177', '86')
# eachTuple= ('177', '131')
# eachTuple= ('121', '206')
# eachTuple= ('121', '39')
# eachTuple= ('172', '159')
# eachTuple= ('172', '103')
# eachTuple= ('172', '231')
# eachTuple= ('149', '14')
# eachTuple= ('149', '312')
# eachTuple= ('149', '20')
# eachTuple= ('14', '312')
# eachTuple= ('14', '144')
# eachTuple= ('312', '44')
# eachTuple= ('312', '214')
# eachTuple= ('312', '144')
# eachTuple= ('312', '220')
# eachTuple= ('312', '326')
# eachTuple= ('312', '151')
# eachTuple= ('29', '16')
# eachTuple= ('214', '333')
# eachTuple= ('139', '320')
# eachTuple= ('320', '159')
# eachTuple= ('320', '80')
# eachTuple= ('320', '127')
# eachTuple= ('320', '108')
# eachTuple= ('320', '57')
# eachTuple= ('5', '187')
# eachTuple= ('5', '316')
# eachTuple= ('20', '326')
# eachTuple= ('167', '243')
# eachTuple= ('85', '258')
# eachTuple= ('263', '99')
# eachTuple= ('263', '296')
# eachTuple= ('303', '132')
# eachTuple= ('303', '45')
# eachTuple= ('80', '57')
# eachTuple= ('80', '187')
# eachTuple= ('22', '308')
# eachTuple= ('257', '258')
# eachTuple= ('257', '130')
# eachTuple= ('257', '295')
# eachTuple= ('231', '178')
# eachTuple= ('39', '105')
# eachTuple= ('275', '78')
# eachTuple= ('275', '273')
# eachTuple= ('275', '328')
# eachTuple= ('78', '218')
# eachTuple= ('78', '328')
# eachTuple= ('262', '220')
# eachTuple= ('300', '130')
# eachTuple= ('258', '295')
# eachTuple= ('100', '163')
# eachTuple= ('259', '110')
# eachTuple= ('33', '42')
# eachTuple= ('308', '87')
# eachTuple= ('89', '319')
# eachTuple= ('89', '327')
# eachTuple= ('319', '219')
# eachTuple= ('127', '108')
# eachTuple= ('59', '250')
# eachTuple= ('68', '225')
# eachTuple= ('45', '221')
# eachTuple= ('45', '345')
# eachTuple= ('184', '57')
# eachTuple= ('49', '241')
# eachTuple= ('49', '255')
# eachTuple= ('218', '195')
# eachTuple= ('218', '273')
# eachTuple= ('218', '181')
# eachTuple= ('195', '181')
# eachTuple= ('24', '57')
# eachTuple= ('24', '187')
# eachTuple= ('130', '73')
# eachTuple= ('130', '191')
# eachTuple= ('278', '225')
# eachTuple= ('278', '99')
# eachTuple= ('278', '86')
# eachTuple= ('225', '131')
# eachTuple= ('99', '296')
# eachTuple= ('212', '295')
# eachTuple= ('333', '162')
# eachTuple= ('87', '246')
# eachTuple= ('166', '202')
# eachTuple= ('166', '198')
# eachTuple= ('126', '73')
# eachTuple= ('253', '182')
# eachTuple= ('181', '152')
# eachTuple= ('282', '244')
# eachTuple= ('192', '52')
# eachTuple= ('192', '205')
# eachTuple= ('157', '155')
# eachTuple= ('301', '194')
# eachTuple= ('301', '267')
# eachTuple= ('301', '272')
# eachTuple= ('301', '23')
# eachTuple= ('301', '30')
# eachTuple= ('301', '263')
# eachTuple= ('301', '189')
# eachTuple= ('301', '318')
# eachTuple= ('301', '27')
# eachTuple= ('194', '266')
# eachTuple= ('194', '267')
# eachTuple= ('194', '129')
# eachTuple= ('194', '40')
# eachTuple= ('194', '311')
# eachTuple= ('194', '214')
# eachTuple= ('194', '271')
# eachTuple= ('265', '173')
# eachTuple= ('265', '266')
# eachTuple= ('265', '275')
# eachTuple= ('265', '154')
# eachTuple= ('265', '317')
# eachTuple= ('265', '29')
# eachTuple= ('265', '130')
# eachTuple= ('265', '239')
# eachTuple= ('265', '179')
# eachTuple= ('173', '228')
# eachTuple= ('173', '59')
# eachTuple= ('173', '21')
# eachTuple= ('173', '240')
# eachTuple= ('173', '323')
# eachTuple= ('173', '200')
# eachTuple= ('173', '12')
# eachTuple= ('173', '52')
# eachTuple= ('173', '248')
# eachTuple= ('89', '307')
# eachTuple= ('89', '101')
# eachTuple= ('89', '251')
# eachTuple= ('89', '14')
# eachTuple= ('89', '97')
# eachTuple= ('89', '264')
# eachTuple= ('89', '300')
# eachTuple= ('307', '10')
# eachTuple= ('307', '117')
# eachTuple= ('307', '7')
# eachTuple= ('307', '241')
# eachTuple= ('307', '286')
# eachTuple= ('293', '213')
# eachTuple= ('293', '112')
# eachTuple= ('293', '153')
# eachTuple= ('293', '278')
# eachTuple= ('293', '82')
# eachTuple= ('293', '324')
# eachTuple= ('293', '124')
# eachTuple= ('293', '229')
# eachTuple= ('293', '7')
# eachTuple= ('293', '164')
# eachTuple= ('213', '107')
# eachTuple= ('213', '246')
# eachTuple= ('213', '297')
# eachTuple= ('213', '182')
# eachTuple= ('213', '269')
# eachTuple= ('213', '198')
# eachTuple= ('174', '273')
# eachTuple= ('174', '186')
# eachTuple= ('174', '296')
# eachTuple= ('174', '200')
# eachTuple= ('174', '229')
# eachTuple= ('174', '256')
# eachTuple= ('174', '86')
# eachTuple= ('174', '69')
# eachTuple= ('174', '91')
# eachTuple= ('174', '137')
# eachTuple= ('174', '57')
# eachTuple= ('273', '259')
# eachTuple= ('273', '200')
# eachTuple= ('101', '188')
# eachTuple= ('101', '177')
# eachTuple= ('101', '330')
# eachTuple= ('101', '82')
# eachTuple= ('101', '59')
# eachTuple= ('101', '323')
# eachTuple= ('101', '206')
# eachTuple= ('101', '100')
# eachTuple= ('101', '227')
# eachTuple= ('188', '160')
# eachTuple= ('188', '132')
# eachTuple= ('188', '322')
# eachTuple= ('188', '84')
# eachTuple= ('188', '100')
# eachTuple= ('188', '40')
# eachTuple= ('188', '311')
# eachTuple= ('188', '176')
# eachTuple= ('188', '27')
# eachTuple= ('112', '160')
# eachTuple= ('112', '54')
# eachTuple= ('112', '45')
# eachTuple= ('112', '82')
# eachTuple= ('112', '170')
# eachTuple= ('112', '182')
# eachTuple= ('112', '75')
# eachTuple= ('112', '190')
# eachTuple= ('112', '313')
# eachTuple= ('112', '27')
# eachTuple= ('160', '153')
# eachTuple= ('160', '191')
# eachTuple= ('160', '250')
# eachTuple= ('160', '326')
# eachTuple= ('160', '245')
# eachTuple= ('160', '125')
# eachTuple= ('160', '298')
# eachTuple= ('266', '46')
# eachTuple= ('266', '68')
# eachTuple= ('266', '108')
# eachTuple= ('266', '104')
# eachTuple= ('46', '193')
# eachTuple= ('46', '151')
# eachTuple= ('46', '108')
# eachTuple= ('46', '62')
# eachTuple= ('46', '150')
# eachTuple= ('46', '25')
# eachTuple= ('46', '304')
# eachTuple= ('153', '267')
# eachTuple= ('153', '76')
# eachTuple= ('153', '251')
# eachTuple= ('153', '169')
# eachTuple= ('153', '81')
# eachTuple= ('153', '72')
# eachTuple= ('153', '114')
# eachTuple= ('153', '214')
# eachTuple= ('153', '48')
# eachTuple= ('267', '19')
# eachTuple= ('267', '154')
# eachTuple= ('267', '140')
# eachTuple= ('267', '148')
# eachTuple= ('267', '22')
# eachTuple= ('267', '258')
# eachTuple= ('267', '104')
# eachTuple= ('267', '121')
# eachTuple= ('267', '288')
# eachTuple= ('267', '147')
# eachTuple= ('267', '49')
# eachTuple= ('267', '176')
# eachTuple= ('267', '156')
# eachTuple= ('191', '193')
# eachTuple= ('191', '136')
# eachTuple= ('191', '291')
# eachTuple= ('191', '218')
# eachTuple= ('191', '235')
# eachTuple= ('191', '268')
# eachTuple= ('191', '37')
# eachTuple= ('191', '115')
# eachTuple= ('193', '140')
# eachTuple= ('193', '30')
# eachTuple= ('193', '34')
# eachTuple= ('193', '121')
# eachTuple= ('193', '283')
# eachTuple= ('193', '49')
# eachTuple= ('193', '292')
# eachTuple= ('193', '230')
# eachTuple= ('177', '233')
# eachTuple= ('177', '255')
# eachTuple= ('177', '264')
# eachTuple= ('177', '201')
# eachTuple= ('177', '98')
# eachTuple= ('177', '29')
# eachTuple= ('177', '288')
# eachTuple= ('177', '164')
# eachTuple= ('233', '296')
# eachTuple= ('233', '251')
# eachTuple= ('233', '32')
# eachTuple= ('233', '83')
# eachTuple= ('233', '288')
# eachTuple= ('233', '41')
# eachTuple= ('233', '261')
# eachTuple= ('77', '19')
# eachTuple= ('77', '131')
# eachTuple= ('77', '84')
# eachTuple= ('77', '145')
# eachTuple= ('77', '300')
# eachTuple= ('77', '315')
# eachTuple= ('19', '330')
# eachTuple= ('19', '226')
# eachTuple= ('19', '263')
# eachTuple= ('19', '220')
# eachTuple= ('19', '79')
# eachTuple= ('19', '36')
# eachTuple= ('19', '137')
# eachTuple= ('19', '57')
# eachTuple= ('54', '316')
# eachTuple= ('54', '64')
# eachTuple= ('54', '33')
# eachTuple= ('54', '34')
# eachTuple= ('54', '138')
# eachTuple= ('54', '187')
# eachTuple= ('54', '80')
# eachTuple= ('54', '184')
# eachTuple= ('316', '151')
# eachTuple= ('316', '282')
# eachTuple= ('316', '61')
# eachTuple= ('316', '200')
# eachTuple= ('316', '158')
# eachTuple= ('316', '20')
# eachTuple= ('221', '151')
# eachTuple= ('221', '45')
# eachTuple= ('221', '251')
# eachTuple= ('221', '85')
# eachTuple= ('221', '200')
# eachTuple= ('221', '329')
# eachTuple= ('221', '24')
# eachTuple= ('221', '52')
# eachTuple= ('221', '80')
# eachTuple= ('221', '215')
# eachTuple= ('221', '143')
# eachTuple= ('151', '268')
# eachTuple= ('151', '211')
# eachTuple= ('151', '208')
# eachTuple= ('151', '212')
# eachTuple= ('151', '37')
# eachTuple= ('151', '16')
# eachTuple= ('151', '142')
# eachTuple= ('151', '318')
# eachTuple= ('1', '328')
# eachTuple= ('1', '167')
# eachTuple= ('1', '113')
# eachTuple= ('1', '185')
# eachTuple= ('1', '288')
# eachTuple= ('1', '103')
# eachTuple= ('1', '66')
# eachTuple= ('1', '239')
# eachTuple= ('1', '31')
# eachTuple= ('1', '302')
# eachTuple= ('328', '255')
# eachTuple= ('328', '16')
# eachTuple= ('328', '178')
# eachTuple= ('217', '64')
# eachTuple= ('217', '5')
# eachTuple= ('217', '167')
# eachTuple= ('217', '37')
# eachTuple= ('64', '323')
# eachTuple= ('64', '297')
# eachTuple= ('64', '289')
# eachTuple= ('64', '165')
# eachTuple= ('64', '187')
# eachTuple= ('9', '76')
# eachTuple= ('9', '47')
# eachTuple= ('9', '268')
# eachTuple= ('9', '63')
# eachTuple= ('9', '195')
# eachTuple= ('9', '320')
# eachTuple= ('9', '229')
# eachTuple= ('9', '100')
# eachTuple= ('9', '125')
# eachTuple= ('9', '214')
# eachTuple= ('76', '161')
# eachTuple= ('76', '90')
# eachTuple= ('76', '329')
# eachTuple= ('76', '52')
# eachTuple= ('76', '29')
# eachTuple= ('76', '236')
# eachTuple= ('225', '172')
# eachTuple= ('225', '23')
# eachTuple= ('225', '83')
# eachTuple= ('225', '252')
# eachTuple= ('225', '257')
# eachTuple= ('225', '178')
# eachTuple= ('225', '145')
# eachTuple= ('172', '39')
# eachTuple= ('172', '228')
# eachTuple= ('172', '211')
# eachTuple= ('172', '252')
# eachTuple= ('172', '92')
# eachTuple= ('172', '260')
# eachTuple= ('172', '298')
# eachTuple= ('159', '18')
# eachTuple= ('159', '203')
# eachTuple= ('159', '245')
# eachTuple= ('159', '207')
# eachTuple= ('18', '122')
# eachTuple= ('18', '258')
# eachTuple= ('18', '120')
# eachTuple= ('18', '199')
# eachTuple= ('18', '306')
# eachTuple= ('18', '318')
# eachTuple= ('18', '310')
# eachTuple= ('18', '286')
# eachTuple= ('107', '278')
# eachTuple= ('107', '272')
# eachTuple= ('107', '38')
# eachTuple= ('107', '69')
# eachTuple= ('107', '119')
# eachTuple= ('107', '88')
# eachTuple= ('278', '117')
# eachTuple= ('278', '24')
# eachTuple= ('278', '222')
# eachTuple= ('278', '214')
# eachTuple= ('278', '292')
# eachTuple= ('278', '315')
# eachTuple= ('197', '134')
# eachTuple= ('197', '171')
# eachTuple= ('197', '79')
# eachTuple= ('197', '270')
# eachTuple= ('197', '182')
# eachTuple= ('197', '75')
# eachTuple= ('197', '142')
# eachTuple= ('197', '230')
# eachTuple= ('134', '169')
# eachTuple= ('134', '192')
# eachTuple= ('134', '220')
# eachTuple= ('134', '8')
# eachTuple= ('134', '41')
# eachTuple= ('134', '321')
# eachTuple= ('134', '223')
# eachTuple= ('134', '35')
# eachTuple= ('134', '331')
# eachTuple= ('134', '88')
# eachTuple= ('275', '51')
# eachTuple= ('275', '205')
# eachTuple= ('275', '144')
# eachTuple= ('275', '324')
# eachTuple= ('128', '87')
# eachTuple= ('128', '228')
# eachTuple= ('128', '12')
# eachTuple= ('128', '285')
# eachTuple= ('128', '6')
# eachTuple= ('128', '175')
# eachTuple= ('128', '137')
# eachTuple= ('87', '296')
# eachTuple= ('87', '272')
# eachTuple= ('87', '274')
# eachTuple= ('250', '51')
# eachTuple= ('250', '39')
# eachTuple= ('250', '133')
# eachTuple= ('250', '235')
# eachTuple= ('250', '23')
# eachTuple= ('250', '108')
# eachTuple= ('250', '24')
# eachTuple= ('250', '248')
# eachTuple= ('250', '96')
# eachTuple= ('51', '234')
# eachTuple= ('51', '297')
# eachTuple= ('51', '329')
# eachTuple= ('51', '220')
# eachTuple= ('51', '129')
# eachTuple= ('51', '8')
# eachTuple= ('132', '5')
# eachTuple= ('132', '270')
# eachTuple= ('132', '183')
# eachTuple= ('132', '257')
# eachTuple= ('132', '119')
# eachTuple= ('132', '78')
# eachTuple= ('5', '251')
# eachTuple= ('5', '52')
# eachTuple= ('5', '285')
# eachTuple= ('5', '65')
# eachTuple= ('5', '313')
# eachTuple= ('39', '167')
# eachTuple= ('39', '135')
# eachTuple= ('39', '68')
# eachTuple= ('39', '238')
# eachTuple= ('39', '210')
# eachTuple= ('39', '247')
# eachTuple= ('39', '326')
# eachTuple= ('39', '300')
# eachTuple= ('39', '315')
# eachTuple= ('167', '72')
# eachTuple= ('167', '321')
# eachTuple= ('167', '222')
# eachTuple= ('167', '141')
# eachTuple= ('167', '292')
# eachTuple= ('139', '154')
# eachTuple= ('139', '13')
# eachTuple= ('139', '144')
# eachTuple= ('139', '12')
# eachTuple= ('139', '182')
# eachTuple= ('139', '31')
# eachTuple= ('154', '240')
# eachTuple= ('154', '55')
# eachTuple= ('154', '318')
# eachTuple= ('154', '27')
# eachTuple= ('330', '33')
# eachTuple= ('330', '93')
# eachTuple= ('330', '176')
# eachTuple= ('330', '31')
# eachTuple= ('33', '210')
# eachTuple= ('33', '90')
# eachTuple= ('33', '23')
# eachTuple= ('33', '58')
# eachTuple= ('33', '206')
# eachTuple= ('33', '320')
# eachTuple= ('33', '212')
# eachTuple= ('33', '119')
# eachTuple= ('131', '10')
# eachTuple= ('131', '133')
# eachTuple= ('131', '68')
# eachTuple= ('131', '251')
# eachTuple= ('131', '34')
# eachTuple= ('131', '129')
# eachTuple= ('131', '66')
# eachTuple= ('131', '73')
# eachTuple= ('131', '56')
# eachTuple= ('131', '57')
# eachTuple= ('131', '261')
# eachTuple= ('10', '186')
# eachTuple= ('10', '234')
# eachTuple= ('10', '126')
# eachTuple= ('10', '165')
# eachTuple= ('10', '155')
# eachTuple= ('10', '223')
# eachTuple= ('10', '271')
# eachTuple= ('135', '161')
# eachTuple= ('135', '296')
# eachTuple= ('135', '272')
# eachTuple= ('135', '41')
# eachTuple= ('135', '180')
# eachTuple= ('135', '42')
# eachTuple= ('161', '232')
# eachTuple= ('161', '189')
# eachTuple= ('161', '149')
# eachTuple= ('133', '237')
# eachTuple= ('133', '235')
# eachTuple= ('133', '294')
# eachTuple= ('133', '245')
# eachTuple= ('133', '189')
# eachTuple= ('133', '164')
# eachTuple= ('237', '200')
# eachTuple= ('237', '215')
# eachTuple= ('237', '91')
# eachTuple= ('136', '47')
# eachTuple= ('136', '255')
# eachTuple= ('136', '124')
# eachTuple= ('136', '26')
# eachTuple= ('136', '138')
# eachTuple= ('136', '166')
# eachTuple= ('136', '190')
# eachTuple= ('136', '271')
# eachTuple= ('136', '88')
# eachTuple= ('47', '85')
# eachTuple= ('47', '263')
# eachTuple= ('47', '65')
# eachTuple= ('47', '326')
# eachTuple= ('47', '283')
# eachTuple= ('45', '262')
# eachTuple= ('45', '240')
# eachTuple= ('45', '14')
# eachTuple= ('45', '38')
# eachTuple= ('45', '91')
# eachTuple= ('262', '26')
# eachTuple= ('262', '41')
# eachTuple= ('312', '280')
# eachTuple= ('312', '82')
# eachTuple= ('312', '284')
# eachTuple= ('312', '14')
# eachTuple= ('312', '235')
# eachTuple= ('312', '12')
# eachTuple= ('312', '263')
# eachTuple= ('312', '16')
# eachTuple= ('280', '8')
# eachTuple= ('280', '279')
# eachTuple= ('280', '283')
# eachTuple= ('280', '292')
# eachTuple= ('228', '68')
# eachTuple= ('228', '148')
# eachTuple= ('228', '15')
# eachTuple= ('228', '149')
# eachTuple= ('228', '75')
# eachTuple= ('228', '115')
# eachTuple= ('68', '219')
# eachTuple= ('68', '140')
# eachTuple= ('68', '288')
# eachTuple= ('68', '214')
# eachTuple= ('68', '156')
# eachTuple= ('68', '204')
# eachTuple= ('68', '78')
# eachTuple= ('255', '85')
# eachTuple= ('255', '34')
# eachTuple= ('255', '195')
# eachTuple= ('255', '231')
# eachTuple= ('255', '152')
# eachTuple= ('255', '143')
# eachTuple= ('82', '30')
# eachTuple= ('82', '83')
# eachTuple= ('82', '3')
# eachTuple= ('82', '152')
# eachTuple= ('82', '332')
# eachTuple= ('186', '296')
# eachTuple= ('186', '185')
# eachTuple= ('186', '125')
# eachTuple= ('186', '75')
# eachTuple= ('186', '184')
# eachTuple= ('291', '246')
# eachTuple= ('291', '168')
# eachTuple= ('291', '61')
# eachTuple= ('291', '209')
# eachTuple= ('291', '285')
# eachTuple= ('291', '73')
# eachTuple= ('291', '27')
# eachTuple= ('246', '240')
# eachTuple= ('246', '117')
# eachTuple= ('246', '169')
# eachTuple= ('246', '104')
# eachTuple= ('246', '100')
# eachTuple= ('246', '290')
# eachTuple= ('246', '270')
# eachTuple= ('246', '321')
# eachTuple= ('246', '239')
# eachTuple= ('246', '44')
# eachTuple= ('246', '164')
# eachTuple= ('244', '317')
# eachTuple= ('244', '297')
# eachTuple= ('244', '272')
# eachTuple= ('244', '220')
# eachTuple= ('244', '165')
# eachTuple= ('244', '130')
# eachTuple= ('244', '150')
# eachTuple= ('244', '332')
# eachTuple= ('317', '240')
# eachTuple= ('317', '206')
# eachTuple= ('59', '296')
# eachTuple= ('59', '34')
# eachTuple= ('59', '320')
# eachTuple= ('59', '201')
# eachTuple= ('59', '40')
# eachTuple= ('59', '303')
# eachTuple= ('59', '27')
# eachTuple= ('296', '29')
# eachTuple= ('296', '40')
# eachTuple= ('296', '253')
# eachTuple= ('296', '163')
# eachTuple= ('203', '276')
# eachTuple= ('203', '116')
# eachTuple= ('203', '329')
# eachTuple= ('203', '37')
# eachTuple= ('203', '41')
# eachTuple= ('203', '178')
# eachTuple= ('203', '184')
# eachTuple= ('276', '195')
# eachTuple= ('276', '231')
# eachTuple= ('276', '48')
# eachTuple= ('276', '105')
# eachTuple= ('251', '238')
# eachTuple= ('251', '247')
# eachTuple= ('251', '231')
# eachTuple= ('251', '156')
# eachTuple= ('251', '109')
# eachTuple= ('251', '332')
# eachTuple= ('21', '240')
# eachTuple= ('21', '235')
# eachTuple= ('21', '206')
# eachTuple= ('21', '192')
# eachTuple= ('21', '146')
# eachTuple= ('21', '187')
# eachTuple= ('21', '166')
# eachTuple= ('21', '196')
# eachTuple= ('21', '162')
# eachTuple= ('240', '117')
# eachTuple= ('240', '209')
# eachTuple= ('240', '201')
# eachTuple= ('240', '222')
# eachTuple= ('238', '168')
# eachTuple= ('238', '234')
# eachTuple= ('238', '219')
# eachTuple= ('238', '74')
# eachTuple= ('238', '72')
# eachTuple= ('238', '171')
# eachTuple= ('238', '249')
# eachTuple= ('238', '147')
# eachTuple= ('238', '86')
# eachTuple= ('168', '99')
# eachTuple= ('168', '90')
# eachTuple= ('168', '129')
# eachTuple= ('168', '223')
# eachTuple= ('168', '149')
# eachTuple= ('168', '31')
# eachTuple= ('168', '60')
# eachTuple= ('168', '315')
# eachTuple= ('99', '170')
# eachTuple= ('99', '235')
# eachTuple= ('99', '144')
# eachTuple= ('99', '288')
# eachTuple= ('99', '239')
# eachTuple= ('170', '268')
# eachTuple= ('170', '303')
# eachTuple= ('170', '300')
# eachTuple= ('170', '196')
# eachTuple= ('113', '234')
# eachTuple= ('113', '72')
# eachTuple= ('323', '234')
# eachTuple= ('323', '171')
# eachTuple= ('323', '93')
# eachTuple= ('323', '0')
# eachTuple= ('323', '73')
# eachTuple= ('234', '226')
# eachTuple= ('234', '8')
# eachTuple= ('234', '28')
# eachTuple= ('234', '199')
# eachTuple= ('234', '223')
# eachTuple= ('284', '102')
# eachTuple= ('284', '202')
# eachTuple= ('284', '163')
# eachTuple= ('284', '239')
# eachTuple= ('284', '327')
# eachTuple= ('284', '179')
# eachTuple= ('102', '211')
# eachTuple= ('102', '81')
# eachTuple= ('102', '74')
# eachTuple= ('102', '243')
# eachTuple= ('102', '249')
# eachTuple= ('102', '75')
# eachTuple= ('102', '302')
# eachTuple= ('282', '308')
# eachTuple= ('282', '20')
# eachTuple= ('282', '178')
# eachTuple= ('282', '67')
# eachTuple= ('226', '122')
# eachTuple= ('226', '108')
# eachTuple= ('226', '206')
# eachTuple= ('226', '98')
# eachTuple= ('226', '96')
# eachTuple= ('122', '212')
# eachTuple= ('122', '270')
# eachTuple= ('122', '149')
# eachTuple= ('218', '297')
# eachTuple= ('218', '247')
# eachTuple= ('218', '166')
# eachTuple= ('218', '149')
# eachTuple= ('297', '169')
# eachTuple= ('297', '285')
# eachTuple= ('297', '256')
# eachTuple= ('297', '294')
# eachTuple= ('297', '50')
# eachTuple= ('297', '73')
# eachTuple= ('297', '156')
# eachTuple= ('61', '219')
# eachTuple= ('61', '126')
# eachTuple= ('61', '83')
# eachTuple= ('61', '29')
# eachTuple= ('61', '138')
# eachTuple= ('61', '331')
# eachTuple= ('61', '111')
# eachTuple= ('116', '259')
# eachTuple= ('116', '30')
# eachTuple= ('116', '329')
# eachTuple= ('116', '232')
# eachTuple= ('116', '129')
# eachTuple= ('116', '26')
# eachTuple= ('116', '165')
# eachTuple= ('116', '156')
# eachTuple= ('259', '129')
# eachTuple= ('259', '79')
# eachTuple= ('259', '252')
# eachTuple= ('259', '303')
# eachTuple= ('259', '239')
# eachTuple= ('259', '49')
# eachTuple= ('14', '200')
# eachTuple= ('14', '93')
# eachTuple= ('14', '231')
# eachTuple= ('85', '272')
# eachTuple= ('85', '74')
# eachTuple= ('85', '71')
# eachTuple= ('85', '287')
# eachTuple= ('85', '149')
# eachTuple= ('85', '327')
# eachTuple= ('272', '52')
# eachTuple= ('272', '2')
# eachTuple= ('272', '245')
# eachTuple= ('272', '178')
# eachTuple= ('272', '318')
# eachTuple= ('205', '13')
# eachTuple= ('205', '146')
# eachTuple= ('205', '300')
# eachTuple= ('13', '108')
# eachTuple= ('13', '324')
# eachTuple= ('13', '114')
# eachTuple= ('13', '28')
# eachTuple= ('13', '249')
# eachTuple= ('13', '86')
# eachTuple= ('13', '231')
# eachTuple= ('13', '300')
# eachTuple= ('13', '3')
# eachTuple= ('13', '57')
# eachTuple= ('289', '235')
# eachTuple= ('289', '144')
# eachTuple= ('289', '79')
# eachTuple= ('289', '182')
# eachTuple= ('289', '88')
# eachTuple= ('289', '162')
# eachTuple= ('235', '63')
# eachTuple= ('235', '55')
# eachTuple= ('235', '247')
# eachTuple= ('235', '222')
# eachTuple= ('235', '75')
# eachTuple= ('235', '150')
# eachTuple= ('235', '304')
# eachTuple= ('235', '260')
# eachTuple= ('117', '100')
# eachTuple= ('117', '130')
# eachTuple= ('210', '319')
# eachTuple= ('210', '169')
# eachTuple= ('210', '66')
# eachTuple= ('210', '150')
# eachTuple= ('210', '286')
# eachTuple= ('210', '91')
# eachTuple= ('319', '84')
# eachTuple= ('319', '308')
# eachTuple= ('319', '81')
# eachTuple= ('319', '74')
# eachTuple= ('319', '207')
# eachTuple= ('319', '4')
# eachTuple= ('219', '65')
# eachTuple= ('219', '183')
# eachTuple= ('219', '147')
# eachTuple= ('219', '0')
# eachTuple= ('219', '106')
# eachTuple= ('219', '179')
# eachTuple= ('90', '63')
# eachTuple= ('90', '206')
# eachTuple= ('90', '264')
# eachTuple= ('90', '2')
# eachTuple= ('90', '180')
# eachTuple= ('90', '145')
# eachTuple= ('268', '200')
# eachTuple= ('268', '192')
# eachTuple= ('268', '189')
# eachTuple= ('268', '38')
# eachTuple= ('268', '53')
# eachTuple= ('200', '97')
# eachTuple= ('200', '26')
# eachTuple= ('200', '253')
# eachTuple= ('140', '63')
# eachTuple= ('140', '110')
# eachTuple= ('140', '258')
# eachTuple= ('140', '71')
# eachTuple= ('140', '294')
# eachTuple= ('140', '125')
# eachTuple= ('140', '310')
# eachTuple= ('140', '313')
# eachTuple= ('63', '247')
# eachTuple= ('63', '95')
# eachTuple= ('63', '182')
# eachTuple= ('63', '141')
# eachTuple= ('144', '23')
# eachTuple= ('144', '324')
# eachTuple= ('144', '129')
# eachTuple= ('144', '86')
# eachTuple= ('23', '12')
# eachTuple= ('23', '320')
# eachTuple= ('23', '147')
# eachTuple= ('23', '60')
# eachTuple= ('30', '211')
# eachTuple= ('30', '264')
# eachTuple= ('30', '285')
# eachTuple= ('30', '114')
# eachTuple= ('30', '98')
# eachTuple= ('30', '184')
# eachTuple= ('211', '258')
# eachTuple= ('211', '320')
# eachTuple= ('211', '248')
# eachTuple= ('211', '318')
# eachTuple= ('211', '292')
# eachTuple= ('211', '310')
# eachTuple= ('211', '315')
# eachTuple= ('34', '79')
# eachTuple= ('34', '95')
# eachTuple= ('34', '15')
# eachTuple= ('34', '311')
# eachTuple= ('34', '321')
# eachTuple= ('34', '35')
# eachTuple= ('34', '231')
# eachTuple= ('108', '158')
# eachTuple= ('108', '97')
# eachTuple= ('108', '100')
# eachTuple= ('108', '126')
# eachTuple= ('108', '253')
# eachTuple= ('108', '287')
# eachTuple= ('108', '187')
# eachTuple= ('108', '118')
# eachTuple= ('158', '322')
# eachTuple= ('158', '253')
# eachTuple= ('158', '163')
# eachTuple= ('158', '292')
# eachTuple= ('158', '230')
# eachTuple= ('322', '58')
# eachTuple= ('322', '28')
# eachTuple= ('322', '152')
# eachTuple= ('58', '74')
# eachTuple= ('58', '264')
# eachTuple= ('58', '253')
# eachTuple= ('58', '257')
# eachTuple= ('58', '27')
# eachTuple= ('58', '260')
# eachTuple= ('169', '263')
# eachTuple= ('169', '40')
# eachTuple= ('169', '252')
# eachTuple= ('169', '223')
# eachTuple= ('169', '156')
# eachTuple= ('169', '96')
# eachTuple= ('169', '109')
# eachTuple= ('97', '308')
# eachTuple= ('97', '208')
# eachTuple= ('97', '95')
# eachTuple= ('97', '120')
# eachTuple= ('97', '130')
# eachTuple= ('97', '215')
# eachTuple= ('148', '209')
# eachTuple= ('148', '252')
# eachTuple= ('148', '247')
# eachTuple= ('148', '48')
# eachTuple= ('209', '110')
# eachTuple= ('209', '62')
# eachTuple= ('209', '321')
# eachTuple= ('209', '147')
# eachTuple= ('209', '239')
# eachTuple= ('202', '195')
# eachTuple= ('195', '41')
# eachTuple= ('195', '166')
# eachTuple= ('110', '32')
# eachTuple= ('110', '55')
# eachTuple= ('110', '300')
# eachTuple= ('110', '42')
# eachTuple= ('110', '332')
# eachTuple= ('32', '84')
# eachTuple= ('32', '98')
# eachTuple= ('32', '40')
# eachTuple= ('32', '141')
# eachTuple= ('32', '281')
# eachTuple= ('32', '318')
# eachTuple= ('32', '152')
# eachTuple= ('32', '292')
# eachTuple= ('32', '78')
# eachTuple= ('62', '22')
# eachTuple= ('62', '308')
# eachTuple= ('62', '208')
# eachTuple= ('62', '220')
# eachTuple= ('62', '178')
# eachTuple= ('62', '49')
# eachTuple= ('62', '17')
# eachTuple= ('22', '306')
# eachTuple= ('22', '25')
# eachTuple= ('258', '74')
# eachTuple= ('258', '187')
# eachTuple= ('258', '38')
# eachTuple= ('258', '105')
# eachTuple= ('299', '329')
# eachTuple= ('299', '121')
# eachTuple= ('299', '50')
# eachTuple= ('329', '37')
# eachTuple= ('329', '182')
# eachTuple= ('329', '91')
# eachTuple= ('104', '72')
# eachTuple= ('104', '16')
# eachTuple= ('104', '166')
# eachTuple= ('104', '214')
# eachTuple= ('84', '24')
# eachTuple= ('84', '91')
# eachTuple= ('24', '80')
# eachTuple= ('24', '42')
# eachTuple= ('308', '263')
# eachTuple= ('324', '220')
# eachTuple= ('324', '100')
# eachTuple= ('324', '243')
# eachTuple= ('324', '190')
# eachTuple= ('324', '57')
# eachTuple= ('12', '206')
# eachTuple= ('12', '253')
# eachTuple= ('12', '36')
# eachTuple= ('121', '264')
# eachTuple= ('121', '224')
# eachTuple= ('232', '247')
# eachTuple= ('232', '249')
# eachTuple= ('232', '44')
# eachTuple= ('232', '164')
# eachTuple= ('206', '83')
# eachTuple= ('206', '306')
# eachTuple= ('192', '185')
# eachTuple= ('192', '79')
# eachTuple= ('192', '126')
# eachTuple= ('192', '20')
# eachTuple= ('192', '223')
# eachTuple= ('192', '182')
# eachTuple= ('192', '3')
# eachTuple= ('192', '310')
# eachTuple= ('192', '179')
# eachTuple= ('192', '314')
# eachTuple= ('185', '93')
# eachTuple= ('185', '321')
# eachTuple= ('185', '66')
# eachTuple= ('81', '74')
# eachTuple= ('81', '264')
# eachTuple= ('81', '229')
# eachTuple= ('81', '83')
# eachTuple= ('81', '231')
# eachTuple= ('74', '50')
# eachTuple= ('74', '145')
# eachTuple= ('74', '302')
# eachTuple= ('52', '220')
# eachTuple= ('52', '290')
# eachTuple= ('52', '103')
# eachTuple= ('52', '326')
# eachTuple= ('52', '127')
# eachTuple= ('52', '44')
# eachTuple= ('52', '35')
# eachTuple= ('52', '88')
# eachTuple= ('264', '69')
# eachTuple= ('264', '152')
# eachTuple= ('208', '126')
# eachTuple= ('208', '75')
# eachTuple= ('208', '123')
# eachTuple= ('208', '286')
# eachTuple= ('263', '212')
# eachTuple= ('263', '86')
# eachTuple= ('263', '44')
# eachTuple= ('263', '109')
# eachTuple= ('220', '124')
# eachTuple= ('220', '298')
# eachTuple= ('124', '239')
# eachTuple= ('124', '325')
# eachTuple= ('124', '123')
# eachTuple= ('124', '27')
# eachTuple= ('146', '171')
# eachTuple= ('146', '165')
# eachTuple= ('146', '125')
# eachTuple= ('146', '48')
# eachTuple= ('146', '196')
# eachTuple= ('72', '295')
# eachTuple= ('72', '207')
# eachTuple= ('72', '279')
# eachTuple= ('72', '3')
# eachTuple= ('72', '318')
# eachTuple= ('72', '152')
# eachTuple= ('72', '78')
# eachTuple= ('212', '295')
# eachTuple= ('212', '114')
# eachTuple= ('212', '41')
# eachTuple= ('212', '187')
# eachTuple= ('212', '315')
# eachTuple= ('295', '79')
# eachTuple= ('295', '165')
# eachTuple= ('295', '178')
# eachTuple= ('295', '239')
# eachTuple= ('295', '11')
# eachTuple= ('70', '285')
# eachTuple= ('70', '326')
# eachTuple= ('285', '309')
# eachTuple= ('285', '127')
# eachTuple= ('71', '114')
# eachTuple= ('71', '40')
# eachTuple= ('71', '2')
# eachTuple= ('71', '75')
# eachTuple= ('114', '171')
# eachTuple= ('114', '6')
# eachTuple= ('114', '103')
# eachTuple= ('114', '91')
# eachTuple= ('129', '227')
# eachTuple= ('129', '8')
# eachTuple= ('129', '41')
# eachTuple= ('129', '86')
# eachTuple= ('129', '123')
# eachTuple= ('129', '94')
# eachTuple= ('129', '179')
# eachTuple= ('129', '162')
# eachTuple= ('37', '245')
# eachTuple= ('37', '142')
# eachTuple= ('309', '201')
# eachTuple= ('309', '171')
# eachTuple= ('309', '98')
# eachTuple= ('309', '41')
# eachTuple= ('309', '106')
# eachTuple= ('201', '243')
# eachTuple= ('201', '80')
# eachTuple= ('201', '230')
# eachTuple= ('229', '73')
# eachTuple= ('229', '241')
# eachTuple= ('229', '141')
# eachTuple= ('229', '281')
# eachTuple= ('229', '286')
# eachTuple= ('171', '53')
# eachTuple= ('100', '130')
# eachTuple= ('100', '86')
# eachTuple= ('16', '230')
# eachTuple= ('16', '304')
# eachTuple= ('290', '15')
# eachTuple= ('290', '249')
# eachTuple= ('290', '277')
# eachTuple= ('26', '321')
# eachTuple= ('26', '306')
# eachTuple= ('26', '164')
# eachTuple= ('26', '96')
# eachTuple= ('98', '227')
# eachTuple= ('98', '73')
# eachTuple= ('227', '288')
# eachTuple= ('227', '187')
# eachTuple= ('227', '53')
# eachTuple= ('227', '332')
# eachTuple= ('79', '126')
# eachTuple= ('79', '55')
# eachTuple= ('79', '11')
# eachTuple= ('79', '176')
# eachTuple= ('79', '271')
# eachTuple= ('126', '242')
# eachTuple= ('126', '137')
# eachTuple= ('256', '43')
# eachTuple= ('256', '143')
# eachTuple= ('8', '7')
# eachTuple= ('8', '38')
# eachTuple= ('8', '224')
# eachTuple= ('83', '181')
# eachTuple= ('83', '42')
# eachTuple= ('165', '40')
# eachTuple= ('165', '241')
# eachTuple= ('165', '305')
# eachTuple= ('165', '313')
# eachTuple= ('29', '294')
# eachTuple= ('29', '326')
# eachTuple= ('29', '73')
# eachTuple= ('29', '239')
# eachTuple= ('29', '310')
# eachTuple= ('29', '17')
# eachTuple= ('294', '311')
# eachTuple= ('294', '231')
# eachTuple= ('294', '3')
# eachTuple= ('55', '247')
# eachTuple= ('55', '7')
# eachTuple= ('55', '315')
# eachTuple= ('138', '222')
# eachTuple= ('138', '215')
# eachTuple= ('138', '314')
# eachTuple= ('40', '147')
# eachTuple= ('40', '180')
# eachTuple= ('40', '149')
# eachTuple= ('40', '269')
# eachTuple= ('2', '181')
# eachTuple= ('2', '6')
# eachTuple= ('2', '254')
# eachTuple= ('181', '245')
# eachTuple= ('181', '189')
# eachTuple= ('181', '145')
# eachTuple= ('181', '236')
# eachTuple= ('181', '261')
# eachTuple= ('288', '327')
# eachTuple= ('288', '271')
# eachTuple= ('252', '207')
# eachTuple= ('252', '327')
# eachTuple= ('252', '42')
# eachTuple= ('252', '304')
# eachTuple= ('252', '302')
# eachTuple= ('248', '28')
# eachTuple= ('248', '157')
# eachTuple= ('28', '103')
# eachTuple= ('253', '287')
# eachTuple= ('253', '127')
# eachTuple= ('253', '279')
# eachTuple= ('253', '327')
# eachTuple= ('253', '286')
# eachTuple= ('287', '103')
# eachTuple= ('287', '214')
# eachTuple= ('287', '94')
# eachTuple= ('247', '300')
# eachTuple= ('36', '6')
# eachTuple= ('36', '321')
# eachTuple= ('36', '66')
# eachTuple= ('36', '73')
# eachTuple= ('36', '11')
# eachTuple= ('36', '215')
# eachTuple= ('6', '73')
# eachTuple= ('6', '141')
# eachTuple= ('6', '60')
# eachTuple= ('95', '41')
# eachTuple= ('95', '283')
# eachTuple= ('95', '150')
# eachTuple= ('95', '184')
# eachTuple= ('41', '207')
# eachTuple= ('41', '283')
# eachTuple= ('41', '176')
# eachTuple= ('41', '111')
# eachTuple= ('41', '196')
# eachTuple= ('187', '20')
# eachTuple= ('187', '65')
# eachTuple= ('187', '216')
# eachTuple= ('187', '300')
# eachTuple= ('187', '204')
# eachTuple= ('187', '105')
# eachTuple= ('20', '216')
# eachTuple= ('20', '78')
# eachTuple= ('65', '163')
# eachTuple= ('65', '180')
# eachTuple= ('7', '175')
# eachTuple= ('7', '93')
# eachTuple= ('7', '249')
# eachTuple= ('7', '103')
# eachTuple= ('7', '155')
# eachTuple= ('7', '35')
# eachTuple= ('175', '44')
# eachTuple= ('175', '176')
# eachTuple= ('175', '3')
# eachTuple= ('175', '315')
# eachTuple= ('175', '215')
# eachTuple= ('175', '298')
# eachTuple= ('93', '326')
# eachTuple= ('93', '147')
# eachTuple= ('93', '156')
# eachTuple= ('93', '286')
# eachTuple= ('15', '149')
# eachTuple= ('15', '53')
# eachTuple= ('15', '142')
# eachTuple= ('15', '179')
# eachTuple= ('243', '11')
# eachTuple= ('243', '318')
# eachTuple= ('311', '223')
# eachTuple= ('311', '75')
# eachTuple= ('311', '286')
# eachTuple= ('311', '184')
# eachTuple= ('120', '300')
# eachTuple= ('183', '157')
# eachTuple= ('183', '204')
# eachTuple= ('183', '331')
# eachTuple= ('157', '155')
# eachTuple= ('157', '25')
# eachTuple= ('157', '215')
# eachTuple= ('157', '260')
# eachTuple= ('157', '162')
# eachTuple= ('249', '326')
# eachTuple= ('249', '50')
# eachTuple= ('249', '0')
# eachTuple= ('249', '325')
# eachTuple= ('249', '43')
# eachTuple= ('249', '292')
# eachTuple= ('103', '245')
# eachTuple= ('163', '326')
# eachTuple= ('163', '94')
# eachTuple= ('163', '302')
# eachTuple= ('326', '147')
# eachTuple= ('326', '69')
# eachTuple= ('326', '327')
# eachTuple= ('326', '224')
# eachTuple= ('326', '27')
# eachTuple= ('147', '242')
# eachTuple= ('147', '331')
# eachTuple= ('147', '94')
# eachTuple= ('147', '105')
# eachTuple= ('50', '127')
# eachTuple= ('50', '137')
# eachTuple= ('130', '86')
# eachTuple= ('130', '141')
# eachTuple= ('130', '11')
# eachTuple= ('155', '118')
# eachTuple= ('155', '257')
# eachTuple= ('155', '305')
# eachTuple= ('155', '198')
# eachTuple= ('118', '292')
# eachTuple= ('118', '196')
# eachTuple= ('303', '0')
# eachTuple= ('303', '241')
# eachTuple= ('303', '38')
# eachTuple= ('303', '176')
# eachTuple= ('303', '43')
# eachTuple= ('66', '96')
# eachTuple= ('66', '111')
# eachTuple= ('257', '142')
# eachTuple= ('180', '242')
# eachTuple= ('180', '315')
# eachTuple= ('199', '56')
# eachTuple= ('223', '254')
# eachTuple= ('223', '190')
# eachTuple= ('182', '38')
# eachTuple= ('182', '327')
# eachTuple= ('207', '281')
# eachTuple= ('207', '310')
# eachTuple= ('222', '4')
# eachTuple= ('189', '150')
# eachTuple= ('189', '304')
# eachTuple= ('189', '137')
# eachTuple= ('241', '145')
# eachTuple= ('241', '179')
# eachTuple= ('241', '271')
# eachTuple= ('145', '67')
# eachTuple= ('145', '286')
# eachTuple= ('145', '143')
# eachTuple= ('279', '164')
# eachTuple= ('279', '236')
# eachTuple= ('38', '179')
# eachTuple= ('254', '166')
# eachTuple= ('254', '49')
# eachTuple= ('166', '261')
# eachTuple= ('86', '286')
# eachTuple= ('86', '269')
# eachTuple= ('149', '96')
# eachTuple= ('149', '137')
# eachTuple= ('283', '119')
# eachTuple= ('283', '92')
# eachTuple= ('141', '91')
# eachTuple= ('44', '105')
# eachTuple= ('125', '11')
# eachTuple= ('125', '315')
# eachTuple= ('11', '305')
# eachTuple= ('11', '96')
# eachTuple= ('242', '119')
# eachTuple= ('242', '314')
# eachTuple= ('35', '216')
# eachTuple= ('75', '53')
# eachTuple= ('75', '4')
# eachTuple= ('49', '318')
# eachTuple= ('306', '109')
# eachTuple= ('150', '31')
# eachTuple= ('150', '27')
# eachTuple= ('142', '190')
# eachTuple= ('67', '106')
# eachTuple= ('106', '94')
# eachTuple= ('69', '176')
# eachTuple= ('69', '179')
# eachTuple= ('216', '25')
# eachTuple= ('327', '123')
# eachTuple= ('327', '60')
# eachTuple= ('327', '196')
# eachTuple= ('327', '27')
# eachTuple= ('224', '215')
# eachTuple= ('224', '298')
# eachTuple= ('214', '281')
# eachTuple= ('214', '310')
# eachTuple= ('214', '260')
# eachTuple= ('281', '271')
# eachTuple= ('325', '111')
# eachTuple= ('325', '105')
# eachTuple= ('176', '305')
# eachTuple= ('176', '318')
# eachTuple= ('176', '236')
# eachTuple= ('305', '190')
# eachTuple= ('305', '332')
# eachTuple= ('318', '152')
# eachTuple= ('318', '43')
# eachTuple= ('152', '156')
# eachTuple= ('152', '230')
# eachTuple= ('152', '274')
# eachTuple= ('43', '269')
# eachTuple= ('43', '56')
# eachTuple= ('96', '304')
# eachTuple= ('190', '314')
# eachTuple= ('123', '88')
# eachTuple= ('310', '277')
# eachTuple= ('286', '4')
# eachTuple= ('315', '313')
# eachTuple= ('313', '196')
# eachTuple= ('94', '314')
# eachTuple= ('179', '304')
# eachTuple= ('179', '198')
# eachTuple= ('105', '91')
# eachTuple= ('105', '88')
# eachTuple= ('196', '314')
# eachTuple= ('91', '298')
# eachTuple= ('271', '143')
# eachTuple= ('269', '57')
# eachTuple= ('17', '56')
# eachTuple= ('302', '332')

# %%
print(x_positive.shape)
print(x_negative.shape)
# Out:
# (1259, 224)
# (1248, 224)

# %%
valid_x_positive=make_class_arrays(valid_g,1)
valid_x_negative=make_class_arrays(valid_not_g,1)
# Out:
# eachTuple= ('23', '144')
# eachTuple= ('23', '240')
# eachTuple= ('144', '326')
# eachTuple= ('144', '151')
# eachTuple= ('6', '95')
# eachTuple= ('6', '89')
# eachTuple= ('95', '319')
# eachTuple= ('296', '68')
# eachTuple= ('290', '342')
# eachTuple= ('290', '67')
# eachTuple= ('342', '123')
# eachTuple= ('342', '13')
# eachTuple= ('342', '238')
# eachTuple= ('342', '122')
# eachTuple= ('342', '21')
# eachTuple= ('315', '223')
# eachTuple= ('315', '313')
# eachTuple= ('315', '98')
# eachTuple= ('315', '285')
# eachTuple= ('315', '170')
# eachTuple= ('315', '224')
# eachTuple= ('315', '185')
# eachTuple= ('315', '105')
# eachTuple= ('315', '213')
# eachTuple= ('315', '87')
# eachTuple= ('223', '252')
# eachTuple= ('223', '200')
# eachTuple= ('223', '265')
# eachTuple= ('199', '313')
# eachTuple= ('199', '113')
# eachTuple= ('199', '291')
# eachTuple= ('199', '238')
# eachTuple= ('199', '141')
# eachTuple= ('199', '62')
# eachTuple= ('199', '222')
# eachTuple= ('313', '60')
# eachTuple= ('313', '13')
# eachTuple= ('313', '271')
# eachTuple= ('313', '172')
# eachTuple= ('317', '40')
# eachTuple= ('40', '239')
# eachTuple= ('40', '271')
# eachTuple= ('40', '280')
# eachTuple= ('239', '261')
# eachTuple= ('239', '285')
# eachTuple= ('239', '141')
# eachTuple= ('239', '303')
# eachTuple= ('239', '322')
# eachTuple= ('239', '231')
# eachTuple= ('239', '186')
# eachTuple= ('239', '344')
# eachTuple= ('99', '225')
# eachTuple= ('99', '102')
# eachTuple= ('99', '175')
# eachTuple= ('99', '227')
# eachTuple= ('225', '143')
# eachTuple= ('25', '113')
# eachTuple= ('25', '26')
# eachTuple= ('25', '98')
# eachTuple= ('25', '39')
# eachTuple= ('25', '84')
# eachTuple= ('25', '277')
# eachTuple= ('25', '104')
# eachTuple= ('25', '158')
# eachTuple= ('25', '332')
# eachTuple= ('25', '65')
# eachTuple= ('113', '26')
# eachTuple= ('113', '261')
# eachTuple= ('113', '142')
# eachTuple= ('113', '252')
# eachTuple= ('82', '123')
# eachTuple= ('82', '98')
# eachTuple= ('82', '261')
# eachTuple= ('82', '158')
# eachTuple= ('82', '169')
# eachTuple= ('82', '65')
# eachTuple= ('82', '211')
# eachTuple= ('82', '268')
# eachTuple= ('123', '26')
# eachTuple= ('123', '98')
# eachTuple= ('123', '122')
# eachTuple= ('123', '142')
# eachTuple= ('60', '158')
# eachTuple= ('24', '346')
# eachTuple= ('24', '242')
# eachTuple= ('24', '53')
# eachTuple= ('346', '330')
# eachTuple= ('346', '1')
# eachTuple= ('346', '130')
# eachTuple= ('346', '320')
# eachTuple= ('346', '127')
# eachTuple= ('346', '94')
# eachTuple= ('72', '298')
# eachTuple= ('72', '329')
# eachTuple= ('72', '272')
# eachTuple= ('72', '132')
# eachTuple= ('298', '265')
# eachTuple= ('26', '248')
# eachTuple= ('26', '297')
# eachTuple= ('26', '142')
# eachTuple= ('26', '172')
# eachTuple= ('26', '323')
# eachTuple= ('26', '252')
# eachTuple= ('26', '69')
# eachTuple= ('26', '158')
# eachTuple= ('26', '236')
# eachTuple= ('26', '265')
# eachTuple= ('310', '243')
# eachTuple= ('310', '14')
# eachTuple= ('278', '131')
# eachTuple= ('278', '177')
# eachTuple= ('278', '46')
# eachTuple= ('131', '143')
# eachTuple= ('98', '261')
# eachTuple= ('98', '285')
# eachTuple= ('98', '141')
# eachTuple= ('98', '62')
# eachTuple= ('98', '258')
# eachTuple= ('98', '103')
# eachTuple= ('98', '331')
# eachTuple= ('109', '295')
# eachTuple= ('109', '297')
# eachTuple= ('109', '13')
# eachTuple= ('109', '303')
# eachTuple= ('109', '323')
# eachTuple= ('109', '186')
# eachTuple= ('109', '331')
# eachTuple= ('109', '50')
# eachTuple= ('295', '156')
# eachTuple= ('345', '261')
# eachTuple= ('345', '303')
# eachTuple= ('345', '213')
# eachTuple= ('345', '322')
# eachTuple= ('261', '122')
# eachTuple= ('261', '56')
# eachTuple= ('261', '314')
# eachTuple= ('261', '16')
# eachTuple= ('3', '274')
# eachTuple= ('3', '67')
# eachTuple= ('3', '200')
# eachTuple= ('297', '122')
# eachTuple= ('297', '67')
# eachTuple= ('297', '252')
# eachTuple= ('297', '65')
# eachTuple= ('254', '302')
# eachTuple= ('254', '196')
# eachTuple= ('254', '92')
# eachTuple= ('302', '242')
# eachTuple= ('302', '266')
# eachTuple= ('302', '187')
# eachTuple= ('39', '119')
# eachTuple= ('39', '141')
# eachTuple= ('39', '257')
# eachTuple= ('119', '13')
# eachTuple= ('119', '329')
# eachTuple= ('119', '185')
# eachTuple= ('119', '132')
# eachTuple= ('119', '325')
# eachTuple= ('119', '318')
# eachTuple= ('13', '56')
# eachTuple= ('13', '118')
# eachTuple= ('329', '184')
# eachTuple= ('285', '103')
# eachTuple= ('111', '337')
# eachTuple= ('111', '326')
# eachTuple= ('170', '185')
# eachTuple= ('170', '9')
# eachTuple= ('170', '277')
# eachTuple= ('170', '62')
# eachTuple= ('170', '260')
# eachTuple= ('291', '224')
# eachTuple= ('291', '280')
# eachTuple= ('224', '141')
# eachTuple= ('224', '62')
# eachTuple= ('224', '67')
# eachTuple= ('224', '188')
# eachTuple= ('224', '148')
# eachTuple= ('276', '84')
# eachTuple= ('84', '31')
# eachTuple= ('84', '304')
# eachTuple= ('271', '238')
# eachTuple= ('271', '185')
# eachTuple= ('271', '48')
# eachTuple= ('271', '104')
# eachTuple= ('271', '63')
# eachTuple= ('238', '59')
# eachTuple= ('185', '322')
# eachTuple= ('185', '169')
# eachTuple= ('185', '280')
# eachTuple= ('185', '79')
# eachTuple= ('73', '299')
# eachTuple= ('73', '88')
# eachTuple= ('299', '180')
# eachTuple= ('299', '1')
# eachTuple= ('299', '300')
# eachTuple= ('299', '53')
# eachTuple= ('141', '122')
# eachTuple= ('141', '272')
# eachTuple= ('141', '133')
# eachTuple= ('122', '176')
# eachTuple= ('122', '62')
# eachTuple= ('122', '136')
# eachTuple= ('122', '156')
# eachTuple= ('122', '104')
# eachTuple= ('176', '9')
# eachTuple= ('303', '178')
# eachTuple= ('303', '88')
# eachTuple= ('303', '236')
# eachTuple= ('9', '277')
# eachTuple= ('9', '142')
# eachTuple= ('9', '322')
# eachTuple= ('9', '258')
# eachTuple= ('9', '280')
# eachTuple= ('277', '213')
# eachTuple= ('277', '204')
# eachTuple= ('277', '134')
# eachTuple= ('62', '142')
# eachTuple= ('62', '341')
# eachTuple= ('36', '284')
# eachTuple= ('284', '309')
# eachTuple= ('142', '56')
# eachTuple= ('142', '203')
# eachTuple= ('142', '323')
# eachTuple= ('142', '158')
# eachTuple= ('213', '178')
# eachTuple= ('213', '56')
# eachTuple= ('213', '204')
# eachTuple= ('213', '128')
# eachTuple= ('213', '136')
# eachTuple= ('213', '231')
# eachTuple= ('213', '96')
# eachTuple= ('178', '272')
# eachTuple= ('178', '88')
# eachTuple= ('56', '272')
# eachTuple= ('56', '136')
# eachTuple= ('56', '341')
# eachTuple= ('56', '252')
# eachTuple= ('56', '132')
# eachTuple= ('56', '212')
# eachTuple= ('56', '221')
# eachTuple= ('56', '200')
# eachTuple= ('56', '63')
# eachTuple= ('56', '66')
# eachTuple= ('56', '30')
# eachTuple= ('56', '59')
# eachTuple= ('322', '48')
# eachTuple= ('322', '67')
# eachTuple= ('322', '21')
# eachTuple= ('322', '304')
# eachTuple= ('322', '126')
# eachTuple= ('48', '330')
# eachTuple= ('48', '332')
# eachTuple= ('48', '57')
# eachTuple= ('48', '54')
# eachTuple= ('343', '19')
# eachTuple= ('343', '41')
# eachTuple= ('19', '293')
# eachTuple= ('19', '175')
# eachTuple= ('258', '161')
# eachTuple= ('258', '156')
# eachTuple= ('203', '332')
# eachTuple= ('203', '304')
# eachTuple= ('312', '226')
# eachTuple= ('312', '140')
# eachTuple= ('312', '2')
# eachTuple= ('312', '41')
# eachTuple= ('312', '162')
# eachTuple= ('226', '14')
# eachTuple= ('226', '333')
# eachTuple= ('226', '20')
# eachTuple= ('272', '186')
# eachTuple= ('272', '236')
# eachTuple= ('272', '211')
# eachTuple= ('272', '304')
# eachTuple= ('103', '323')
# eachTuple= ('103', '252')
# eachTuple= ('80', '173')
# eachTuple= ('80', '88')
# eachTuple= ('80', '300')
# eachTuple= ('80', '266')
# eachTuple= ('172', '16')
# eachTuple= ('172', '29')
# eachTuple= ('172', '211')
# eachTuple= ('172', '304')
# eachTuple= ('204', '94')
# eachTuple= ('204', '5')
# eachTuple= ('323', '96')
# eachTuple= ('330', '53')
# eachTuple= ('330', '266')
# eachTuple= ('140', '41')
# eachTuple= ('140', '326')
# eachTuple= ('116', '28')
# eachTuple= ('116', '326')
# eachTuple= ('28', '149')
# eachTuple= ('180', '94')
# eachTuple= ('180', '5')
# eachTuple= ('161', '252')
# eachTuple= ('196', '67')
# eachTuple= ('128', '186')
# eachTuple= ('128', '334')
# eachTuple= ('67', '75')
# eachTuple= ('67', '21')
# eachTuple= ('67', '265')
# eachTuple= ('67', '280')
# eachTuple= ('67', '79')
# eachTuple= ('67', '304')
# eachTuple= ('8', '245')
# eachTuple= ('8', '201')
# eachTuple= ('8', '193')
# eachTuple= ('136', '7')
# eachTuple= ('136', '146')
# eachTuple= ('136', '308')
# eachTuple= ('2', '115')
# eachTuple= ('133', '188')
# eachTuple= ('133', '183')
# eachTuple= ('259', '264')
# eachTuple= ('264', '110')
# eachTuple= ('231', '29')
# eachTuple= ('1', '126')
# eachTuple= ('78', '181')
# eachTuple= ('181', '306')
# eachTuple= ('252', '334')
# eachTuple= ('132', '45')
# eachTuple= ('212', '104')
# eachTuple= ('115', '14')
# eachTuple= ('115', '214')
# eachTuple= ('14', '20')
# eachTuple= ('143', '175')
# eachTuple= ('143', '321')
# eachTuple= ('186', '88')
# eachTuple= ('186', '104')
# eachTuple= ('300', '320')
# eachTuple= ('158', '304')
# eachTuple= ('332', '208')
# eachTuple= ('332', '324')
# eachTuple= ('184', '21')
# eachTuple= ('150', '163')
# eachTuple= ('150', '100')
# eachTuple= ('150', '64')
# eachTuple= ('260', '339')
# eachTuple= ('21', '280')
# eachTuple= ('200', '304')
# eachTuple= ('200', '118')
# eachTuple= ('265', '331')
# eachTuple= ('327', '319')
# eachTuple= ('41', '230')
# eachTuple= ('108', '281')
# eachTuple= ('108', '57')
# eachTuple= ('108', '251')
# eachTuple= ('108', '159')
# eachTuple= ('29', '338')
# eachTuple= ('326', '162')
# eachTuple= ('83', '237')
# eachTuple= ('53', '92')
# eachTuple= ('328', '306')
# eachTuple= ('57', '249')
# eachTuple= ('7', '304')
# eachTuple= ('127', '159')
# eachTuple= ('94', '101')
# eachTuple= ('66', '304')
# eachTuple= ('66', '334')
# eachTuple= ('304', '30')
# eachTuple= ('251', '197')
# eachTuple= ('286', '81')
# eachTuple= ('81', '269')
# eachTuple= ('64', '171')
# eachTuple= ('194', '249')
# eachTuple= ('249', '101')
# eachTuple= ('175', '227')
# eachTuple= ('149', '162')
# eachTuple= ('27', '324')
# eachTuple= ('307', '71')
# eachTuple= ('120', '247')
# eachTuple= ('331', '50')
# eachTuple= ('58', '269')
# eachTuple= ('147', '219')
# eachTuple= ('273', '4')
# eachTuple= ('29', '300')
# eachTuple= ('300', '76')
# eachTuple= ('300', '114')
# eachTuple= ('308', '284')
# eachTuple= ('308', '153')
# eachTuple= ('308', '208')
# eachTuple= ('308', '221')
# eachTuple= ('308', '291')
# eachTuple= ('115', '305')
# eachTuple= ('115', '313')
# eachTuple= ('115', '183')
# eachTuple= ('305', '193')
# eachTuple= ('305', '24')
# eachTuple= ('234', '214')
# eachTuple= ('234', '72')
# eachTuple= ('234', '85')
# eachTuple= ('214', '309')
# eachTuple= ('326', '76')
# eachTuple= ('326', '293')
# eachTuple= ('326', '213')
# eachTuple= ('76', '138')
# eachTuple= ('76', '206')
# eachTuple= ('110', '92')
# eachTuple= ('110', '190')
# eachTuple= ('110', '62')
# eachTuple= ('110', '18')
# eachTuple= ('110', '289')
# eachTuple= ('92', '156')
# eachTuple= ('92', '49')
# eachTuple= ('92', '47')
# eachTuple= ('92', '36')
# eachTuple= ('70', '302')
# eachTuple= ('70', '309')
# eachTuple= ('277', '108')
# eachTuple= ('277', '286')
# eachTuple= ('108', '219')
# eachTuple= ('108', '146')
# eachTuple= ('108', '142')
# eachTuple= ('153', '199')
# eachTuple= ('153', '120')
# eachTuple= ('153', '47')
# eachTuple= ('199', '228')
# eachTuple= ('199', '126')
# eachTuple= ('199', '190')
# eachTuple= ('199', '193')
# eachTuple= ('199', '82')
# eachTuple= ('199', '322')
# eachTuple= ('196', '243')
# eachTuple= ('243', '35')
# eachTuple= ('243', '295')
# eachTuple= ('264', '235')
# eachTuple= ('264', '129')
# eachTuple= ('264', '80')
# eachTuple= ('264', '297')
# eachTuple= ('235', '215')
# eachTuple= ('235', '103')
# eachTuple= ('235', '19')
# eachTuple= ('330', '45')
# eachTuple= ('330', '152')
# eachTuple= ('45', '244')
# eachTuple= ('45', '275')
# eachTuple= ('273', '35')
# eachTuple= ('35', '22')
# eachTuple= ('35', '232')
# eachTuple= ('228', '62')
# eachTuple= ('126', '17')
# eachTuple= ('194', '271')
# eachTuple= ('194', '174')
# eachTuple= ('194', '47')
# eachTuple= ('271', '184')
# eachTuple= ('271', '138')
# eachTuple= ('267', '249')
# eachTuple= ('267', '289')
# eachTuple= ('249', '213')
# eachTuple= ('314', '251')
# eachTuple= ('251', '9')
# eachTuple= ('251', '178')
# eachTuple= ('251', '179')
# eachTuple= ('130', '278')
# eachTuple= ('130', '4')
# eachTuple= ('130', '74')
# eachTuple= ('278', '105')
# eachTuple= ('295', '97')
# eachTuple= ('295', '327')
# eachTuple= ('295', '318')
# eachTuple= ('97', '138')
# eachTuple= ('97', '154')
# eachTuple= ('230', '292')
# eachTuple= ('230', '40')
# eachTuple= ('230', '247')
# eachTuple= ('230', '24')
# eachTuple= ('292', '310')
# eachTuple= ('292', '178')
# eachTuple= ('148', '124')
# eachTuple= ('148', '21')
# eachTuple= ('148', '121')
# eachTuple= ('223', '290')
# eachTuple= ('223', '233')
# eachTuple= ('290', '50')
# eachTuple= ('290', '226')
# eachTuple= ('290', '318')
# eachTuple= ('290', '161')
# eachTuple= ('287', '190')
# eachTuple= ('287', '122')
# eachTuple= ('287', '265')
# eachTuple= ('287', '322')
# eachTuple= ('287', '0')
# eachTuple= ('190', '217')
# eachTuple= ('190', '181')
# eachTuple= ('219', '298')
# eachTuple= ('184', '163')
# eachTuple= ('184', '289')
# eachTuple= ('184', '48')
# eachTuple= ('184', '167')
# eachTuple= ('163', '135')
# eachTuple= ('122', '310')
# eachTuple= ('310', '96')
# eachTuple= ('310', '109')
# eachTuple= ('177', '17')
# eachTuple= ('177', '266')
# eachTuple= ('177', '67')
# eachTuple= ('17', '103')
# eachTuple= ('17', '262')
# eachTuple= ('17', '268')
# eachTuple= ('17', '32')
# eachTuple= ('193', '55')
# eachTuple= ('215', '55')
# eachTuple= ('217', '289')
# eachTuple= ('217', '49')
# eachTuple= ('217', '255')
# eachTuple= ('174', '286')
# eachTuple= ('174', '95')
# eachTuple= ('174', '274')
# eachTuple= ('138', '125')
# eachTuple= ('20', '283')
# eachTuple= ('20', '39')
# eachTuple= ('20', '322')
# eachTuple= ('20', '4')
# eachTuple= ('20', '298')
# eachTuple= ('283', '165')
# eachTuple= ('283', '143')
# eachTuple= ('283', '331')
# eachTuple= ('317', '170')
# eachTuple= ('317', '59')
# eachTuple= ('170', '114')
# eachTuple= ('170', '298')
# eachTuple= ('192', '205')
# eachTuple= ('192', '286')
# eachTuple= ('192', '117')
# eachTuple= ('205', '240')
# eachTuple= ('205', '155')
# eachTuple= ('82', '129')
# eachTuple= ('82', '257')
# eachTuple= ('129', '67')
# eachTuple= ('135', '201')
# eachTuple= ('119', '125')
# eachTuple= ('125', '209')
# eachTuple= ('21', '275')
# eachTuple= ('23', '149')
# eachTuple= ('23', '117')
# eachTuple= ('23', '123')
# eachTuple= ('23', '69')
# eachTuple= ('23', '239')
# eachTuple= ('149', '117')
# eachTuple= ('22', '286')
# eachTuple= ('22', '114')
# eachTuple= ('22', '324')
# eachTuple= ('72', '329')
# eachTuple= ('9', '266')
# eachTuple= ('9', '67')
# eachTuple= ('265', '78')
# eachTuple= ('62', '79')
# eachTuple= ('62', '312')
# eachTuple= ('62', '46')
# eachTuple= ('62', '55')
# eachTuple= ('79', '187')
# eachTuple= ('79', '323')
# eachTuple= ('79', '134')
# eachTuple= ('79', '298')
# eachTuple= ('296', '316')
# eachTuple= ('296', '73')
# eachTuple= ('316', '38')
# eachTuple= ('316', '301')
# eachTuple= ('316', '146')
# eachTuple= ('166', '229')
# eachTuple= ('166', '313')
# eachTuple= ('166', '66')
# eachTuple= ('229', '211')
# eachTuple= ('229', '186')
# eachTuple= ('211', '222')
# eachTuple= ('211', '28')
# eachTuple= ('131', '224')
# eachTuple= ('224', '117')
# eachTuple= ('224', '241')
# eachTuple= ('224', '5')
# eachTuple= ('224', '301')
# eachTuple= ('14', '26')
# eachTuple= ('26', '241')
# eachTuple= ('26', '157')
# eachTuple= ('128', '258')
# eachTuple= ('128', '89')
# eachTuple= ('128', '146')
# eachTuple= ('258', '289')
# eachTuple= ('50', '114')
# eachTuple= ('50', '121')
# eachTuple= ('114', '216')
# eachTuple= ('313', '202')
# eachTuple= ('113', '103')
# eachTuple= ('113', '197')
# eachTuple= ('103', '140')
# eachTuple= ('117', '100')
# eachTuple= ('117', '99')
# eachTuple= ('117', '123')
# eachTuple= ('117', '279')
# eachTuple= ('100', '89')
# eachTuple= ('100', '221')
# eachTuple= ('100', '32')
# eachTuple= ('175', '262')
# eachTuple= ('185', '280')
# eachTuple= ('280', '268')
# eachTuple= ('280', '90')
# eachTuple= ('280', '311')
# eachTuple= ('280', '191')
# eachTuple= ('280', '44')
# eachTuple= ('280', '318')
# eachTuple= ('30', '127')
# eachTuple= ('30', '186')
# eachTuple= ('30', '321')
# eachTuple= ('127', '178')
# eachTuple= ('127', '289')
# eachTuple= ('127', '15')
# eachTuple= ('198', '218')
# eachTuple= ('218', '39')
# eachTuple= ('218', '85')
# eachTuple= ('218', '158')
# eachTuple= ('218', '143')
# eachTuple= ('60', '39')
# eachTuple= ('60', '293')
# eachTuple= ('60', '167')
# eachTuple= ('268', '242')
# eachTuple= ('95', '6')
# eachTuple= ('8', '71')
# eachTuple= ('71', '294')
# eachTuple= ('89', '312')
# eachTuple= ('89', '73')
# eachTuple= ('312', '109')
# eachTuple= ('121', '13')
# eachTuple= ('288', '136')
# eachTuple= ('288', '226')
# eachTuple= ('288', '179')
# eachTuple= ('288', '107')
# eachTuple= ('40', '81')
# eachTuple= ('40', '181')
# eachTuple= ('81', '12')
# eachTuple= ('3', '96')
# eachTuple= ('96', '59')
# eachTuple= ('96', '111')
# eachTuple= ('325', '85')
# eachTuple= ('325', '16')
# eachTuple= ('85', '86')
# eachTuple= ('85', '142')
# eachTuple= ('270', '140')
# eachTuple= ('270', '90')
# eachTuple= ('285', '247')
# eachTuple= ('59', '281')
# eachTuple= ('18', '13')
# eachTuple= ('18', '157')
# eachTuple= ('320', '195')
# eachTuple= ('195', '162')
# eachTuple= ('227', '203')
# eachTuple= ('227', '37')
# eachTuple= ('213', '233')
# eachTuple= ('213', '245')
# eachTuple= ('64', '315')
# eachTuple= ('64', '99')
# eachTuple= ('64', '245')
# eachTuple= ('186', '220')
# eachTuple= ('186', '15')
# eachTuple= ('186', '43')
# eachTuple= ('63', '206')
# eachTuple= ('63', '49')
# eachTuple= ('206', '38')
# eachTuple= ('206', '86')
# eachTuple= ('206', '176')
# eachTuple= ('206', '42')
# eachTuple= ('240', '90')
# eachTuple= ('1', '327')
# eachTuple= ('327', '238')
# eachTuple= ('289', '91')
# eachTuple= ('181', '294')
# eachTuple= ('181', '301')
# eachTuple= ('181', '242')
# eachTuple= ('78', '147')
# eachTuple= ('99', '2')
# eachTuple= ('99', '84')
# eachTuple= ('2', '179')
# eachTuple= ('2', '147')
# eachTuple= ('93', '294')
# eachTuple= ('93', '34')
# eachTuple= ('226', '171')
# eachTuple= ('6', '282')
# eachTuple= ('6', '179')
# eachTuple= ('282', '106')
# eachTuple= ('171', '208')
# eachTuple= ('171', '189')
# eachTuple= ('171', '291')
# eachTuple= ('246', '101')
# eachTuple= ('246', '307')
# eachTuple= ('158', '65')
# eachTuple= ('104', '61')
# eachTuple= ('104', '5')
# eachTuple= ('61', '154')
# eachTuple= ('61', '179')
# eachTuple= ('212', '10')
# eachTuple= ('10', '47')
# eachTuple= ('233', '25')
# eachTuple= ('220', '146')
# eachTuple= ('220', '143')
# eachTuple= ('188', '73')
# eachTuple= ('188', '307')
# eachTuple= ('323', '209')
# eachTuple= ('323', '321')
# eachTuple= ('56', '109')
# eachTuple= ('154', '183')
# eachTuple= ('38', '209')
# eachTuple= ('38', '183')
# eachTuple= ('134', '307')
# eachTuple= ('107', '68')
# eachTuple= ('324', '254')
# eachTuple= ('241', '88')
# eachTuple= ('5', '37')
# eachTuple= ('75', '105')
# eachTuple= ('105', '42')
# eachTuple= ('66', '253')
# eachTuple= ('66', '257')
# eachTuple= ('253', '7')
# eachTuple= ('253', '151')
# eachTuple= ('201', '260')
# eachTuple= ('311', '25')
# eachTuple= ('311', '297')
# eachTuple= ('311', '169')
# eachTuple= ('210', '86')
# eachTuple= ('210', '299')
# eachTuple= ('86', '297')
# eachTuple= ('191', '112')
# eachTuple= ('191', '58')
# eachTuple= ('65', '204')
# eachTuple= ('44', '183')
# eachTuple= ('143', '272')
# eachTuple= ('176', '225')
# eachTuple= ('147', '94')
# eachTuple= ('147', '152')
# eachTuple= ('7', '164')
# eachTuple= ('318', '34')
# eachTuple= ('156', '83')
# eachTuple= ('222', '116')
# eachTuple= ('321', '204')
# eachTuple= ('197', '102')
# eachTuple= ('112', '132')
# eachTuple= ('275', '31')
# eachTuple= ('145', '52')
# eachTuple= ('145', '106')
# eachTuple= ('254', '157')
# eachTuple= ('162', '144')
# eachTuple= ('139', '279')
# eachTuple= ('263', '332')
# eachTuple= ('263', '231')
# eachTuple= ('281', '106')
# eachTuple= ('225', '74')
# eachTuple= ('225', '248')
# eachTuple= ('47', '36')
# eachTuple= ('34', '256')
# eachTuple= ('142', '41')
# eachTuple= ('31', '53')
# eachTuple= ('276', '111')
# eachTuple= ('276', '160')

# %%
print(valid_x_positive.shape)
print(valid_x_negative.shape)
# Out:
# (377, 224)
# (375, 224)

# %%
y_positive=np.full(shape=(x_positive.shape[0],1),fill_value=1.0)
y_negative=np.full(shape=(x_negative.shape[0],1),fill_value=0.0)

# %%
print(y_positive.shape)
print(y_negative.shape)
# Out:
# (1259, 1)
# (1248, 1)

# %%
valid_y_positive=np.full(shape=(valid_x_positive.shape[0],1),fill_value=1.0)
valid_y_negative=np.full(shape=(valid_x_negative.shape[0],1),fill_value=0.0)

# %%
print(valid_x_positive.shape)
print(valid_x_negative.shape)
print(valid_y_positive.shape)
print(valid_y_negative.shape)
# Out:
# (377, 224)
# (375, 224)
# (377, 1)
# (375, 1)

# %%
print(valid_y_positive.shape)
# Out:
# (377, 1)

# %%
train_X=np.append(x_positive,x_negative,axis=0)
train_Y=np.append(y_positive,y_negative,axis=0)

valid_X=np.append(valid_x_positive,valid_x_negative,axis=0)
valid_Y=np.append(valid_y_positive,valid_y_negative,axis=0)

# %%
print(type(x_positive))
print(valid_X.shape)
print(type(x_negative))
print(valid_Y.shape)
print(type(y_positive))
print(y_positive.shape)
print(train_X.shape)
print(1592+1748)
# Out:
# <class 'numpy.ndarray'>
# (752, 224)
# <class 'numpy.ndarray'>
# (752, 1)
# <class 'numpy.ndarray'>
# (1259, 1)
# (2507, 224)
# 3340

# %%
from sklearn import linear_model
reg = linear_model.Ridge (alpha = .5)

# %%
# clf.fit(digits.data[:-1], digits.target[:-1])  
reg.fit(X=train_X[:-1],y=train_Y[:-1])
# Out:
# Ridge(alpha=0.5, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
reg.predict(train_X[-1:])
# Out:
# array([[0.85750531]])

# %%
len(reg.predict(valid_X))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ba225b550b5b> in <module>
# ----> 1 len(reg.predict(valid_X))
#
# NameError: name 'reg' is not defined

# %%
np.mean((reg.predict(valid_X)-valid_Y)**2)
# Out:
# 0.20420687500451054

# %%
from sklearn.metrics import log_loss
log_loss(valid_Y,reg.predict(valid_X))
# print(0.01)
# Out:
# 0.8773267303548229

# %%
from sklearn import svm
clf_svm = svm.SVC()
clf_svm.fit(X=train_X[:-1],y=train_Y[:-1])
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
from sklearn.metrics import log_loss
log_loss(valid_Y,clf_svm.predict(valid_X))
# Out:
# 9.73709223282874
